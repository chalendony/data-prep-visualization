# %% [markdown]
# # Imputing Categorical Using DataWig
#
# Before you include Datawig in your operational pipeline, you can evaluation its performance on a data set that you are familar with.
#
# Prediction are made on a single column at a time, and you can receive output on the probability of each prediction.

# %% [markdown]
# # Python Imports

# %%
# %config IPCompleter.greedy=True
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelBinarizer
pd.set_option('display.max_columns', 125)
import quilt
from scripts.preprocess import percent_missing, as_dict
from string import Template
import missingno as msno
import impyute
import datawig
from sklearn.metrics import f1_score, classification_report

# %%
# load data from local repository, once per session
from quilt.data.avare import homecredit

# %% [markdown]
# # Validate Data Types
#
# We manually assign the types to each variable and override the data typed in the pandas dataframe.

# %%
description = pd.read_csv('data/new_data_description_file.csv')
description.head()
# Out:
#                      Row             Table     Type
# 0             SK_ID_PREV  POS_CASH_balance   object
# 1             SK_ID_CURR  POS_CASH_balance   object
# 2         MONTHS_BALANCE  POS_CASH_balance  float64
# 3         CNT_INSTALMENT  POS_CASH_balance  float64
# 4  CNT_INSTALMENT_FUTURE  POS_CASH_balance  float64

# %% [markdown]
# ## Override Inferred Data Types (Single Table)
#
# TODO: check Datawig code to see data types are used.
#
# We are concerned with the data types because we have to choose the correct data encoding before passing the data to Datawig.

# %%
table = 'previous_application'
df = homecredit[table]()

python_cat_dtype = 'object'
python_num_dtype = 'float64'

    
condtable = description.Table == table
condcat = description.Type == python_cat_dtype
condnum = description.Type == python_num_dtype
        
catcols = description.loc[(condtable & condcat),'Row'].values.tolist()
numcols = description.loc[(condtable & condnum),'Row'].values.tolist()
    
df[catcols] = df[catcols].astype(python_cat_dtype) 
df[numcols] = df[numcols].astype(python_num_dtype)

# %% [markdown]
# ## Select Subset for Analysis
#
# We will create a subset __without__ nulls, then split the data into a training and test set.
#
# The test set will allow us to measure the performance.

# %%
# drop empty columns
dropcols = ['RATE_INTEREST_PRIVILEGED','RATE_INTEREST_PRIMARY','SK_ID_PREV', 'SK_ID_CURR']
df.drop(dropcols, axis=1, inplace=True)

# drop rows containing null 
df.dropna(axis=0, how='any', inplace=True)

# select random instances
seed = 500
numinstances = 1000
df = df.sample(numinstances,random_state=seed)
#df.info(verbose=True)

# %% [markdown]
# # Strategy Encode Categorical
#
# When validating the data types, go beyond either categorical or numerical so you can
# to choose the appropriate strategy to encode the data.
#
# * [Rule of Thumb for Validating Data Types](https://towardsdatascience.com/7-data-types-a-better-way-to-think-about-data-types-for-machine-learning-939fae99a689)
#
# * [Category Encoders Package](http://contrib.scikit-learn.org/categorical-encoding/index.html])
#
# __Requirements Algorithm:__ when working with Datawig if a nominal  consists of a sequence of integers, the variable will be interpreted as numeric: In our data set, each of the following are impacted:
#
# * HOUR_APPR_PROCESS_START : hours, __ordinal__  (but we encode it as numeric)
# * NFLAG_LAST_APPL_IN_DAY, NFLAG_INSURED_ON_APPROVAL : (0,1) __binary__
# * SELLERPLACE_AREA : 4-digit code for a location, __nomimal__
#
# __Categorical Encoding Strategy__ for this task and algorithm we creat a simple a user-defined encoding for the above mentioned categoricals - map sequence of integers to a string and allows us to see strings as plain text.

# %%
# User-defined Categorical Encoding
prefix = 's_'
df['NFLAG_LAST_APPL_IN_DAY'] =  prefix + df['NFLAG_LAST_APPL_IN_DAY'].astype(str) 
df['SELLERPLACE_AREA'] = prefix + df['SELLERPLACE_AREA'].astype(str) 
df['NFLAG_INSURED_ON_APPROVAL'] = prefix +  df['NFLAG_INSURED_ON_APPROVAL'].astype(str)

# %% [markdown]
# # Train Model

# %%
#%%time
# select a portion of the data for evaluation
df_train, df_test = datawig.utils.random_split(df)

output_column = 'PRODUCT_COMBINATION'
output_path = 'imputer_model' # TODO: file in .gitignore, change path
lst = [*df.columns.values]
lst.remove(output_column)
input_cols = lst


# Initialize a SimpleImputer model
imputer = datawig.SimpleImputer(
    input_columns=lst,  # columns containing information about the column we want to impute
    output_column=output_column,  # the column we'd like to impute values for
    output_path=output_path  # stores model data and metrics 
)

# Fit an imputer model with default list of hyperparameters
imputer.fit_hpo(train_df=df_train)
# Out:
# 2019-05-08 10:28:10,447 [INFO]  Assuming 14 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, HOUR_APPR_PROCESS_START, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-08 10:28:10,449 [INFO]  Assuming 18 string input columns: NAME_YIELD_GROUP, NFLAG_LAST_APPL_IN_DAY, NAME_SELLER_INDUSTRY, NAME_CONTRACT_STATUS, NAME_TYPE_SUITE, NAME_PORTFOLIO, FLAG_LAST_APPL_PER_CONTRACT, CODE_REJECT_REASON, CHANNEL_TYPE, NAME_CONTRACT_TYPE, NAME_CASH_LOAN_PURPOSE, NFLAG_INSURED_ON_APPROVAL, NAME_PAYMENT_TYPE, SELLERPLACE_AREA, WEEKDAY_APPR_PROCESS_START, NAME_CLIENT_TYPE, NAME_GOODS_CATEGORY, NAME_PRODUCT_TYPE
# 2019-05-08 10:28:10,450 [INFO]  Assuming 14 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, HOUR_APPR_PROCESS_START, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-08 10:28:10,451 [INFO]  Assuming 18 string input columns: NAME_YIELD_GROUP, NFLAG_LAST_APPL_IN_DAY, NAME_SELLER_INDUSTRY, NAME_CONTRACT_STATUS, NAME_TYPE_SUITE, NAME_PORTFOLIO, FLAG_LAST_APPL_PER_CONTRACT, CODE_REJECT_REASON, CHANNEL_TYPE, NAME_CONTRACT_TYPE, NAME_CASH_LOAN_PURPOSE, NFLAG_INSURED_ON_APPROVAL, NAME_PAYMENT_TYPE, SELLERPLACE_AREA, WEEKDAY_APPR_PROCESS_START, NAME_CLIENT_TYPE, NAME_GOODS_CATEGORY, NAME_PRODUCT_TYPE
# 2019-05-08 10:28:10,486 [INFO]  Training starts for 1hyperparameter configurations.
# 2019-05-08 10:28:10,488 [INFO]  Fitting hpo iteration 0 with parameters
# 	global:batch_size: 16
# 	global:learning_rate: 0.004
# 	global:weight_decay: 0
# 	global:num_epochs: 25
# 	global:patience: 3
# 	global:final_fc_hidden_units: []
# 	NAME_CONTRACT_TYPE:type: string
# 	NAME_CONTRACT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_TYPE:max_tokens: 32768
# 	NAME_CONTRACT_TYPE:tokens: ['chars']
# 	AMT_ANNUITY:type: numeric
# 	AMT_ANNUITY:normalize: True
# 	AMT_ANNUITY:numeric_latent_dim: 10
# 	AMT_ANNUITY:numeric_hidden_layers: 1
# 	AMT_APPLICATION:type: numeric
# 	AMT_APPLICATION:normalize: True
# 	AMT_APPLICATION:numeric_latent_dim: 10
# 	AMT_APPLICATION:numeric_hidden_layers: 1
# 	AMT_CREDIT:type: numeric
# 	AMT_CREDIT:normalize: True
# 	AMT_CREDIT:numeric_latent_dim: 10
# 	AMT_CREDIT:numeric_hidden_layers: 1
# 	AMT_DOWN_PAYMENT:type: numeric
# 	AMT_DOWN_PAYMENT:normalize: True
# 	AMT_DOWN_PAYMENT:numeric_latent_dim: 10
# 	AMT_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	AMT_GOODS_PRICE:type: numeric
# 	AMT_GOODS_PRICE:normalize: True
# 	AMT_GOODS_PRICE:numeric_latent_dim: 10
# 	AMT_GOODS_PRICE:numeric_hidden_layers: 1
# 	WEEKDAY_APPR_PROCESS_START:type: string
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:words: (1, 3)
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:chars: (1, 5)
# 	WEEKDAY_APPR_PROCESS_START:max_tokens: 32768
# 	WEEKDAY_APPR_PROCESS_START:tokens: ['chars']
# 	HOUR_APPR_PROCESS_START:type: numeric
# 	HOUR_APPR_PROCESS_START:normalize: True
# 	HOUR_APPR_PROCESS_START:numeric_latent_dim: 10
# 	HOUR_APPR_PROCESS_START:numeric_hidden_layers: 1
# 	FLAG_LAST_APPL_PER_CONTRACT:type: string
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:words: (1, 3)
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:chars: (1, 5)
# 	FLAG_LAST_APPL_PER_CONTRACT:max_tokens: 32768
# 	FLAG_LAST_APPL_PER_CONTRACT:tokens: ['chars']
# 	NFLAG_LAST_APPL_IN_DAY:type: string
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:words: (1, 3)
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:chars: (1, 5)
# 	NFLAG_LAST_APPL_IN_DAY:max_tokens: 32768
# 	NFLAG_LAST_APPL_IN_DAY:tokens: ['chars']
# 	RATE_DOWN_PAYMENT:type: numeric
# 	RATE_DOWN_PAYMENT:normalize: True
# 	RATE_DOWN_PAYMENT:numeric_latent_dim: 10
# 	RATE_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	NAME_CASH_LOAN_PURPOSE:type: string
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:words: (1, 3)
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:chars: (1, 5)
# 	NAME_CASH_LOAN_PURPOSE:max_tokens: 32768
# 	NAME_CASH_LOAN_PURPOSE:tokens: ['chars']
# 	NAME_CONTRACT_STATUS:type: string
# 	NAME_CONTRACT_STATUS:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_STATUS:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_STATUS:max_tokens: 32768
# 	NAME_CONTRACT_STATUS:tokens: ['chars']
# 	DAYS_DECISION:type: numeric
# 	DAYS_DECISION:normalize: True
# 	DAYS_DECISION:numeric_latent_dim: 10
# 	DAYS_DECISION:numeric_hidden_layers: 1
# 	NAME_PAYMENT_TYPE:type: string
# 	NAME_PAYMENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PAYMENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PAYMENT_TYPE:max_tokens: 32768
# 	NAME_PAYMENT_TYPE:tokens: ['chars']
# 	CODE_REJECT_REASON:type: string
# 	CODE_REJECT_REASON:ngram_range:words: (1, 3)
# 	CODE_REJECT_REASON:ngram_range:chars: (1, 5)
# 	CODE_REJECT_REASON:max_tokens: 32768
# 	CODE_REJECT_REASON:tokens: ['chars']
# 	NAME_TYPE_SUITE:type: string
# 	NAME_TYPE_SUITE:ngram_range:words: (1, 3)
# 	NAME_TYPE_SUITE:ngram_range:chars: (1, 5)
# 	NAME_TYPE_SUITE:max_tokens: 32768
# 	NAME_TYPE_SUITE:tokens: ['chars']
# 	NAME_CLIENT_TYPE:type: string
# 	NAME_CLIENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CLIENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CLIENT_TYPE:max_tokens: 32768
# 	NAME_CLIENT_TYPE:tokens: ['chars']
# 	NAME_GOODS_CATEGORY:type: string
# 	NAME_GOODS_CATEGORY:ngram_range:words: (1, 3)
# 	NAME_GOODS_CATEGORY:ngram_range:chars: (1, 5)
# 	NAME_GOODS_CATEGORY:max_tokens: 32768
# 	NAME_GOODS_CATEGORY:tokens: ['chars']
# 	NAME_PORTFOLIO:type: string
# 	NAME_PORTFOLIO:ngram_range:words: (1, 3)
# 	NAME_PORTFOLIO:ngram_range:chars: (1, 5)
# 	NAME_PORTFOLIO:max_tokens: 32768
# 	NAME_PORTFOLIO:tokens: ['chars']
# 	NAME_PRODUCT_TYPE:type: string
# 	NAME_PRODUCT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PRODUCT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PRODUCT_TYPE:max_tokens: 32768
# 	NAME_PRODUCT_TYPE:tokens: ['chars']
# 	CHANNEL_TYPE:type: string
# 	CHANNEL_TYPE:ngram_range:words: (1, 3)
# 	CHANNEL_TYPE:ngram_range:chars: (1, 5)
# 	CHANNEL_TYPE:max_tokens: 32768
# 	CHANNEL_TYPE:tokens: ['chars']
# 	SELLERPLACE_AREA:type: string
# 	SELLERPLACE_AREA:ngram_range:words: (1, 3)
# 	SELLERPLACE_AREA:ngram_range:chars: (1, 5)
# 	SELLERPLACE_AREA:max_tokens: 32768
# 	SELLERPLACE_AREA:tokens: ['chars']
# 	NAME_SELLER_INDUSTRY:type: string
# 	NAME_SELLER_INDUSTRY:ngram_range:words: (1, 3)
# 	NAME_SELLER_INDUSTRY:ngram_range:chars: (1, 5)
# 	NAME_SELLER_INDUSTRY:max_tokens: 32768
# 	NAME_SELLER_INDUSTRY:tokens: ['chars']
# 	CNT_PAYMENT:type: numeric
# 	CNT_PAYMENT:normalize: True
# 	CNT_PAYMENT:numeric_latent_dim: 10
# 	CNT_PAYMENT:numeric_hidden_layers: 1
# 	NAME_YIELD_GROUP:type: string
# 	NAME_YIELD_GROUP:ngram_range:words: (1, 3)
# 	NAME_YIELD_GROUP:ngram_range:chars: (1, 5)
# 	NAME_YIELD_GROUP:max_tokens: 32768
# 	NAME_YIELD_GROUP:tokens: ['chars']
# 	DAYS_FIRST_DRAWING:type: numeric
# 	DAYS_FIRST_DRAWING:normalize: True
# 	DAYS_FIRST_DRAWING:numeric_latent_dim: 10
# 	DAYS_FIRST_DRAWING:numeric_hidden_layers: 1
# 	DAYS_FIRST_DUE:type: numeric
# 	DAYS_FIRST_DUE:normalize: True
# 	DAYS_FIRST_DUE:numeric_latent_dim: 10
# 	DAYS_FIRST_DUE:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE_1ST_VERSION:type: numeric
# 	DAYS_LAST_DUE_1ST_VERSION:normalize: True
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_latent_dim: 10
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE:type: numeric
# 	DAYS_LAST_DUE:normalize: True
# 	DAYS_LAST_DUE:numeric_latent_dim: 10
# 	DAYS_LAST_DUE:numeric_hidden_layers: 1
# 	DAYS_TERMINATION:type: numeric
# 	DAYS_TERMINATION:normalize: True
# 	DAYS_TERMINATION:numeric_latent_dim: 10
# 	DAYS_TERMINATION:numeric_hidden_layers: 1
# 	NFLAG_INSURED_ON_APPROVAL:type: string
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:words: (1, 3)
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:chars: (1, 5)
# 	NFLAG_INSURED_ON_APPROVAL:max_tokens: 32768
# 	NFLAG_INSURED_ON_APPROVAL:tokens: ['chars']
# 2019-05-08 10:28:10,498 [INFO]  No output column name provided for ColumnEncoder using PRODUCT_COMBINATION
# 2019-05-08 10:28:10,500 [INFO]  Assuming categorical output column: PRODUCT_COMBINATION
# 2019-05-08 10:28:10,512 [INFO]  Using [[cpu(0)]] as the context for training
# 2019-05-08 10:28:10,514 [INFO]  Fitting label encoder <class 'datawig.column_encoders.CategoricalEncoder'> on 640 rows                             of training data
# 2019-05-08 10:28:10,523 [INFO]  12 most often encountered discrete values:                      ['POS household with interest' 'POS mobile with interest'
#  'POS industry with interest' 'POS household without interest'
#  'Cash Street: high' 'POS other with interest' 'Cash X-Sell: high'
#  'POS industry without interest' 'Cash X-Sell: middle'
#  'POS mobile without interest' 'Cash Street: middle' 'Cash X-Sell: low']
# 2019-05-08 10:28:10,525 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 96 occurrences of value POS industry with interest
# 2019-05-08 10:28:10,526 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 79 occurrences of value POS household without interest
# 2019-05-08 10:28:10,528 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 19 occurrences of value Cash Street: high
# 2019-05-08 10:28:10,530 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 17 occurrences of value POS other with interest
# 2019-05-08 10:28:10,534 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 10 occurrences of value Cash X-Sell: high
# 2019-05-08 10:28:10,536 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 6 occurrences of value POS industry without interest
# 2019-05-08 10:28:10,538 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 4 occurrences of value Cash X-Sell: middle
# 2019-05-08 10:28:10,539 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value POS mobile without interest
# 2019-05-08 10:28:10,541 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value Cash Street: middle
# 2019-05-08 10:28:10,543 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 2 occurrences of value Cash X-Sell: low
# 2019-05-08 10:28:10,547 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-08 10:28:10,549 [INFO]  Dropping 0/640 rows
# 2019-05-08 10:28:10,555 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-08 10:28:10,557 [INFO]  Dropping 0/160 rows
# 2019-05-08 10:28:10,560 [INFO]  Train: 640, Test: 160
# 2019-05-08 10:28:10,562 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_ANNUITY and 640 rows of training data with parameters {'input_columns': ['AMT_ANNUITY'], 'output_column': 'AMT_ANNUITY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,578 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_APPLICATION and 640 rows of training data with parameters {'input_columns': ['AMT_APPLICATION'], 'output_column': 'AMT_APPLICATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,589 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_CREDIT and 640 rows of training data with parameters {'input_columns': ['AMT_CREDIT'], 'output_column': 'AMT_CREDIT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,598 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['AMT_DOWN_PAYMENT'], 'output_column': 'AMT_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,606 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_GOODS_PRICE and 640 rows of training data with parameters {'input_columns': ['AMT_GOODS_PRICE'], 'output_column': 'AMT_GOODS_PRICE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,612 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns HOUR_APPR_PROCESS_START and 640 rows of training data with parameters {'input_columns': ['HOUR_APPR_PROCESS_START'], 'output_column': 'HOUR_APPR_PROCESS_START_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,620 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['RATE_DOWN_PAYMENT'], 'output_column': 'RATE_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,626 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_DECISION and 640 rows of training data with parameters {'input_columns': ['DAYS_DECISION'], 'output_column': 'DAYS_DECISION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,634 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns CNT_PAYMENT and 640 rows of training data with parameters {'input_columns': ['CNT_PAYMENT'], 'output_column': 'CNT_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,647 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DRAWING and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DRAWING'], 'output_column': 'DAYS_FIRST_DRAWING_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,657 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DUE'], 'output_column': 'DAYS_FIRST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,665 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE_1ST_VERSION and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE_1ST_VERSION'], 'output_column': 'DAYS_LAST_DUE_1ST_VERSION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,679 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE'], 'output_column': 'DAYS_LAST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,686 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_TERMINATION and 640 rows of training data with parameters {'input_columns': ['DAYS_TERMINATION'], 'output_column': 'DAYS_TERMINATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-08 10:28:10,693 [INFO]  Building Train Iterator with 640 elements
# 2019-05-08 10:28:10,763 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:10,767 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-08 10:28:10,768 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,775 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,778 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-08 10:28:10,779 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,785 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,790 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-08 10:28:10,791 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,794 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,802 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-08 10:28:10,803 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,810 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,814 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-08 10:28:10,815 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,822 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,843 [INFO]  Data Encoding - Encoded 640 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:10,846 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-08 10:28:10,847 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,853 [INFO]  Data Encoding - Encoded 640 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,862 [INFO]  Data Encoding - Encoded 640 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:10,874 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:10,881 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-08 10:28:10,884 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,892 [INFO]  Data Encoding - Encoded 640 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,901 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:10,920 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:10,923 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-08 10:28:10,925 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:10,929 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:10,994 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,017 [INFO]  Data Encoding - Encoded 640 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,044 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,082 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,109 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,121 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,132 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,162 [INFO]  Data Encoding - Encoded 640 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,177 [INFO]  Data Encoding - Encoded 640 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,214 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,219 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-08 10:28:11,220 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,224 [INFO]  Data Encoding - Encoded 640 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:11,238 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,242 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-08 10:28:11,243 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,248 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:11,254 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-08 10:28:11,257 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,261 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:11,265 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-08 10:28:11,266 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,272 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:11,278 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-08 10:28:11,280 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,284 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:11,288 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-08 10:28:11,289 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,293 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:28:11,315 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:28:11,319 [INFO]  CategoricalEncoder encoding 640 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-08 10:28:11,330 [INFO]  Label Encoding - Encoded 640 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (640, 1) and                             then into shape (640, 1)
# 2019-05-08 10:28:11,333 [INFO]  Building Test Iterator with 160 elements
# 2019-05-08 10:28:11,365 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,371 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-08 10:28:11,372 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,376 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,380 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-08 10:28:11,384 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,389 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,393 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-08 10:28:11,395 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,404 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,409 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-08 10:28:11,410 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,414 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,424 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-08 10:28:11,425 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,429 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,441 [INFO]  Data Encoding - Encoded 160 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,446 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-08 10:28:11,446 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,452 [INFO]  Data Encoding - Encoded 160 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,456 [INFO]  Data Encoding - Encoded 160 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,460 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,467 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-08 10:28:11,470 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,476 [INFO]  Data Encoding - Encoded 160 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,480 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,495 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,502 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-08 10:28:11,504 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,509 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,532 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,539 [INFO]  Data Encoding - Encoded 160 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,552 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,562 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,577 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,586 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,592 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,601 [INFO]  Data Encoding - Encoded 160 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,607 [INFO]  Data Encoding - Encoded 160 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,622 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,627 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-08 10:28:11,628 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,637 [INFO]  Data Encoding - Encoded 160 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,646 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,652 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-08 10:28:11,654 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,659 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,667 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-08 10:28:11,670 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,677 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,685 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-08 10:28:11,688 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,695 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,703 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-08 10:28:11,707 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,713 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,722 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-08 10:28:11,723 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:28:11,729 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:28:11,748 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:28:11,749 [INFO]  CategoricalEncoder encoding 160 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-08 10:28:11,765 [INFO]  Label Encoding - Encoded 160 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (160, 1) and                             then into shape (160, 1)
# 2019-05-08 10:28:11,769 [WARNING]  Test set does not contain any ocurrences of values [Cash X-Sell: low] in column [PRODUCT_COMBINATION], consider using a more representative test set.
# 2019-05-08 10:28:11,770 [INFO]  Concatenating all 32 latent symbols
# 2019-05-08 10:28:11,774 [INFO]  Constructing categorical loss for column PRODUCT_COMBINATION and 12 labels
# 2019-05-08 10:28:11,777 [INFO]  Building output of label <Symbol PRODUCT_COMBINATION> with 13 classes                      (including missing class)
# 2019-05-08 10:28:11,786 [INFO]  Building output symbols
# 2019-05-08 10:28:11,827 [INFO]
# ========== start: fit model
# 2019-05-08 10:28:11,830 [WARNING]  Already bound, ignoring bind()
# 2019-05-08 10:28:16,054 [INFO]  Epoch[0] Batch [0-20]	Speed: 85.37 samples/sec	cross-entropy=1.261912	PRODUCT_COMBINATION-accuracy=0.586310
# 2019-05-08 10:28:19,534 [INFO]  Epoch[0] Train-cross-entropy=0.983716
# 2019-05-08 10:28:19,535 [INFO]  Epoch[0] Train-PRODUCT_COMBINATION-accuracy=0.682813
# 2019-05-08 10:28:19,536 [INFO]  Epoch[0] Time cost=7.689
# 2019-05-08 10:28:19,753 [INFO]  Saved checkpoint to "imputer_model0/model-0000.params"
# 2019-05-08 10:28:21,023 [INFO]  Epoch[0] Validation-cross-entropy=0.590815
# 2019-05-08 10:28:21,024 [INFO]  Epoch[0] Validation-PRODUCT_COMBINATION-accuracy=0.850000
# 2019-05-08 10:28:25,004 [INFO]  Epoch[1] Batch [0-20]	Speed: 84.42 samples/sec	cross-entropy=0.425005	PRODUCT_COMBINATION-accuracy=0.869048
# 2019-05-08 10:28:28,519 [INFO]  Epoch[1] Train-cross-entropy=0.399919
# 2019-05-08 10:28:28,526 [INFO]  Epoch[1] Train-PRODUCT_COMBINATION-accuracy=0.882812
# 2019-05-08 10:28:28,527 [INFO]  Epoch[1] Time cost=7.502
# 2019-05-08 10:28:28,721 [INFO]  Saved checkpoint to "imputer_model0/model-0001.params"
# 2019-05-08 10:28:29,991 [INFO]  Epoch[1] Validation-cross-entropy=0.373925
# 2019-05-08 10:28:29,992 [INFO]  Epoch[1] Validation-PRODUCT_COMBINATION-accuracy=0.893750
# 2019-05-08 10:28:33,852 [INFO]  Epoch[2] Batch [0-20]	Speed: 87.21 samples/sec	cross-entropy=0.274019	PRODUCT_COMBINATION-accuracy=0.910714
# 2019-05-08 10:28:37,437 [INFO]  Epoch[2] Train-cross-entropy=0.271097
# 2019-05-08 10:28:37,438 [INFO]  Epoch[2] Train-PRODUCT_COMBINATION-accuracy=0.918750
# 2019-05-08 10:28:37,439 [INFO]  Epoch[2] Time cost=7.446
# 2019-05-08 10:28:37,638 [INFO]  Saved checkpoint to "imputer_model0/model-0002.params"
# 2019-05-08 10:28:38,924 [INFO]  Epoch[2] Validation-cross-entropy=0.305857
# 2019-05-08 10:28:38,925 [INFO]  Epoch[2] Validation-PRODUCT_COMBINATION-accuracy=0.918750
# 2019-05-08 10:28:42,799 [INFO]  Epoch[3] Batch [0-20]	Speed: 86.93 samples/sec	cross-entropy=0.204759	PRODUCT_COMBINATION-accuracy=0.943452
# 2019-05-08 10:28:46,399 [INFO]  Epoch[3] Train-cross-entropy=0.206948
# 2019-05-08 10:28:46,400 [INFO]  Epoch[3] Train-PRODUCT_COMBINATION-accuracy=0.948438
# 2019-05-08 10:28:46,401 [INFO]  Epoch[3] Time cost=7.475
# 2019-05-08 10:28:46,583 [INFO]  Saved checkpoint to "imputer_model0/model-0003.params"
# 2019-05-08 10:28:47,851 [INFO]  Epoch[3] Validation-cross-entropy=0.273481
# 2019-05-08 10:28:47,852 [INFO]  Epoch[3] Validation-PRODUCT_COMBINATION-accuracy=0.912500
# 2019-05-08 10:28:51,895 [INFO]  Epoch[4] Batch [0-20]	Speed: 83.21 samples/sec	cross-entropy=0.163805	PRODUCT_COMBINATION-accuracy=0.961310
# 2019-05-08 10:28:55,472 [INFO]  Epoch[4] Train-cross-entropy=0.167525
# 2019-05-08 10:28:55,473 [INFO]  Epoch[4] Train-PRODUCT_COMBINATION-accuracy=0.965625
# 2019-05-08 10:28:55,474 [INFO]  Epoch[4] Time cost=7.621
# 2019-05-08 10:28:55,720 [INFO]  Saved checkpoint to "imputer_model0/model-0004.params"
# 2019-05-08 10:28:57,134 [INFO]  Epoch[4] Validation-cross-entropy=0.258362
# 2019-05-08 10:28:57,137 [INFO]  Epoch[4] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-08 10:29:01,122 [INFO]  Epoch[5] Batch [0-20]	Speed: 84.52 samples/sec	cross-entropy=0.136104	PRODUCT_COMBINATION-accuracy=0.964286
# 2019-05-08 10:29:04,649 [INFO]  Epoch[5] Train-cross-entropy=0.140427
# 2019-05-08 10:29:04,651 [INFO]  Epoch[5] Train-PRODUCT_COMBINATION-accuracy=0.970313
# 2019-05-08 10:29:04,652 [INFO]  Epoch[5] Time cost=7.513
# 2019-05-08 10:29:04,840 [INFO]  Saved checkpoint to "imputer_model0/model-0005.params"
# 2019-05-08 10:29:06,167 [INFO]  Epoch[5] Validation-cross-entropy=0.250218
# 2019-05-08 10:29:06,168 [INFO]  Epoch[5] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-08 10:29:10,198 [INFO]  Epoch[6] Batch [0-20]	Speed: 83.83 samples/sec	cross-entropy=0.116285	PRODUCT_COMBINATION-accuracy=0.973214
# 2019-05-08 10:29:13,796 [INFO]  Epoch[6] Train-cross-entropy=0.120806
# 2019-05-08 10:29:13,798 [INFO]  Epoch[6] Train-PRODUCT_COMBINATION-accuracy=0.978125
# 2019-05-08 10:29:13,798 [INFO]  Epoch[6] Time cost=7.629
# 2019-05-08 10:29:13,982 [INFO]  Saved checkpoint to "imputer_model0/model-0006.params"
# 2019-05-08 10:29:15,271 [INFO]  Epoch[6] Validation-cross-entropy=0.245748
# 2019-05-08 10:29:15,272 [INFO]  Epoch[6] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-08 10:29:19,326 [INFO]  Epoch[7] Batch [0-20]	Speed: 82.96 samples/sec	cross-entropy=0.101333	PRODUCT_COMBINATION-accuracy=0.979167
# 2019-05-08 10:29:22,928 [INFO]  Epoch[7] Train-cross-entropy=0.105968
# 2019-05-08 10:29:22,929 [INFO]  Epoch[7] Train-PRODUCT_COMBINATION-accuracy=0.981250
# 2019-05-08 10:29:22,929 [INFO]  Epoch[7] Time cost=7.657
# 2019-05-08 10:29:23,117 [INFO]  Saved checkpoint to "imputer_model0/model-0007.params"
# 2019-05-08 10:29:24,416 [INFO]  Epoch[7] Validation-cross-entropy=0.243887
# 2019-05-08 10:29:24,417 [INFO]  Epoch[7] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-08 10:29:28,530 [INFO]  Epoch[8] Batch [0-20]	Speed: 81.74 samples/sec	cross-entropy=0.089545	PRODUCT_COMBINATION-accuracy=0.982143
# 2019-05-08 10:29:32,232 [INFO]  Epoch[8] Train-cross-entropy=0.094344
# 2019-05-08 10:29:32,233 [INFO]  Epoch[8] Train-PRODUCT_COMBINATION-accuracy=0.985938
# 2019-05-08 10:29:32,235 [INFO]  Epoch[8] Time cost=7.817
# 2019-05-08 10:29:32,427 [INFO]  Saved checkpoint to "imputer_model0/model-0008.params"
# 2019-05-08 10:29:33,721 [INFO]  Epoch[8] Validation-cross-entropy=0.243838
# 2019-05-08 10:29:33,722 [INFO]  Epoch[8] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-08 10:29:37,781 [INFO]  Epoch[9] Batch [0-20]	Speed: 83.00 samples/sec	cross-entropy=0.080025	PRODUCT_COMBINATION-accuracy=0.982143
# 2019-05-08 10:29:41,442 [INFO]  Epoch[9] Train-cross-entropy=0.085010
# 2019-05-08 10:29:41,443 [INFO]  Epoch[9] Train-PRODUCT_COMBINATION-accuracy=0.987500
# 2019-05-08 10:29:41,444 [INFO]  Epoch[9] Time cost=7.721
# 2019-05-08 10:29:41,631 [INFO]  Saved checkpoint to "imputer_model0/model-0009.params"
# 2019-05-08 10:29:42,921 [INFO]  Epoch[9] Validation-cross-entropy=0.244890
# 2019-05-08 10:29:42,922 [INFO]  Epoch[9] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-08 10:29:47,209 [INFO]  Epoch[10] Batch [0-20]	Speed: 78.24 samples/sec	cross-entropy=0.072222	PRODUCT_COMBINATION-accuracy=0.982143
# 2019-05-08 10:29:50,918 [INFO]  Epoch[10] Train-cross-entropy=0.077366
# 2019-05-08 10:29:50,919 [INFO]  Epoch[10] Train-PRODUCT_COMBINATION-accuracy=0.987500
# 2019-05-08 10:29:50,921 [INFO]  Epoch[10] Time cost=7.998
# 2019-05-08 10:29:51,126 [INFO]  Saved checkpoint to "imputer_model0/model-0010.params"
# 2019-05-08 10:29:52,434 [INFO]  No improvement detected for 3 epochs compared to 0.243886886164546 last error obtained: 0.24668995775282382, stopping here
# ...
# 2019-05-08 10:29:56,984 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-08 10:29:56,985 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:56,990 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:29:56,994 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-08 10:29:56,996 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:57,004 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:29:57,009 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-08 10:29:57,011 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:57,018 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-08 10:29:57,027 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-08 10:29:57,028 [INFO]  CategoricalEncoder encoding 160 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-08 10:29:57,038 [INFO]  Label Encoding - Encoded 160 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (160, 1) and                             then into shape (160, 1)
# 2019-05-08 10:29:58,491 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,496 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-08 10:29:58,497 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,502 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,507 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-08 10:29:58,509 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,513 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,519 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-08 10:29:58,521 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,523 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,529 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-08 10:29:58,531 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,536 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,544 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-08 10:29:58,545 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,550 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,567 [INFO]  Data Encoding - Encoded 640 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,572 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-08 10:29:58,572 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,575 [INFO]  Data Encoding - Encoded 640 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,582 [INFO]  Data Encoding - Encoded 640 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,595 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,600 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-08 10:29:58,602 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,606 [INFO]  Data Encoding - Encoded 640 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,617 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,636 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,641 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-08 10:29:58,643 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,648 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,688 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,695 [INFO]  Data Encoding - Encoded 640 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,717 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,732 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,756 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,769 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,777 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,804 [INFO]  Data Encoding - Encoded 640 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,820 [INFO]  Data Encoding - Encoded 640 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,853 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,864 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-08 10:29:58,866 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,872 [INFO]  Data Encoding - Encoded 640 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,887 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,891 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-08 10:29:58,892 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,898 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,903 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-08 10:29:58,905 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,908 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,914 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-08 10:29:58,915 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,920 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,926 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-08 10:29:58,928 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,933 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,940 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-08 10:29:58,941 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:29:58,945 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-08 10:29:58,967 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-08 10:29:58,969 [INFO]  CategoricalEncoder encoding 640 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-08 10:29:58,979 [INFO]  Label Encoding - Encoded 640 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (640, 1) and                             then into shape (640, 1)
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2019-05-08 10:30:04,166 [INFO]  Finished hpo iteration 0
# 2019-05-08 10:30:04,167 [INFO]  Assigning model with highest weighted precision to SimpleImputer object and copying artifacts.
# 2019-05-08 10:30:04,168 [INFO]  Selecting imputer with maximal weighted precision.
# 2019-05-08 10:30:04,251 [INFO]  Output path for loading Imputer imputer_model
# 2019-05-08 10:30:04,257 [INFO]  Loading mxnet model from imputer_model/model

# %% [markdown]
# # Evaluate Performance

# %%
# Impute missing values and return original dataframe with predictions
predictions = imputer.predict(df_test)

predictions.head()

# Calculate f1 score for true vs predicted values
f1 = f1_score(predictions[output_column], predictions[output_column+'_imputed'], average='weighted')

# Print overall classification report
print(classification_report(predictions[output_column], predictions[output_column+'_imputed']))
# Out:
# 2019-05-08 10:32:25,788 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,791 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-08 10:32:25,793 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,796 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,800 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-08 10:32:25,801 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,807 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,816 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-08 10:32:25,818 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,822 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,826 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-08 10:32:25,829 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,834 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,842 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-08 10:32:25,844 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,849 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,862 [INFO]  Data Encoding - Encoded 208 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,871 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-08 10:32:25,872 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,877 [INFO]  Data Encoding - Encoded 208 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,884 [INFO]  Data Encoding - Encoded 208 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,889 [INFO]  Data Encoding - Encoded 208 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,893 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-08 10:32:25,895 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,899 [INFO]  Data Encoding - Encoded 208 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,909 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,919 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,923 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-08 10:32:25,924 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:25,929 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:25,949 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,955 [INFO]  Data Encoding - Encoded 208 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,970 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,979 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:25,994 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,003 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,009 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,025 [INFO]  Data Encoding - Encoded 208 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,033 [INFO]  Data Encoding - Encoded 208 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,052 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,057 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-08 10:32:26,059 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:26,064 [INFO]  Data Encoding - Encoded 208 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:26,074 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,082 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-08 10:32:26,083 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:26,087 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:26,091 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-08 10:32:26,093 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:26,099 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:26,106 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-08 10:32:26,109 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:26,114 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:26,118 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-08 10:32:26,120 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:26,125 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:26,134 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-08 10:32:26,136 [INFO]  Normalizing with StandardScaler
# 2019-05-08 10:32:26,140 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-08 10:32:26,148 [INFO]  Data Encoding - Encoded 208 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-08 10:32:26,149 [INFO]  CategoricalEncoder encoding 208 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-08 10:32:26,158 [INFO]  Label Encoding - Encoded 208 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (208, 1) and                             then into shape (208, 1)
#                                 precision    recall  f1-score   support
#
#              Cash Street: high       0.75      0.75      0.75         4
#              Cash X-Sell: high       0.88      0.88      0.88         8
#            Cash X-Sell: middle       1.00      1.00      1.00         1
#    POS household with interest       0.86      0.99      0.92        76
# POS household without interest       0.95      0.69      0.80        29
#     POS industry with interest       0.93      0.96      0.94        26
#       POS mobile with interest       0.96      0.98      0.97        49
#    POS mobile without interest       0.00      0.00      0.00         2
#        POS other with interest       1.00      0.40      0.57         5
#
#                      micro avg       0.91      0.91      0.91       200
#                      macro avg       0.81      0.74      0.76       200
#                   weighted avg       0.90      0.91      0.90       200
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
predictions[['PRODUCT_COMBINATION', 'PRODUCT_COMBINATION_imputed', 'PRODUCT_COMBINATION_imputed_proba']]
# Out:
#                     PRODUCT_COMBINATION     PRODUCT_COMBINATION_imputed  \
# 265076         POS mobile with interest        POS mobile with interest
# 1529698  POS household without interest     POS household with interest
# 788943      POS household with interest     POS household with interest
# 69679          POS mobile with interest        POS mobile with interest
# 420487       POS industry with interest     POS household with interest
# 231187         POS mobile with interest        POS mobile with interest
# 583942      POS household with interest     POS household with interest
# 1088118  POS household without interest  POS household without interest
# 542793      POS household with interest     POS household with interest
# 1332567     POS household with interest     POS household with interest
# 1334482     POS household with interest     POS household with interest
# 446311      POS household with interest     POS household with interest
# 5772         POS industry with interest      POS industry with interest
# 720903      POS household with interest     POS household with interest
# 729332       POS industry with interest      POS industry with interest
# 426504         POS mobile with interest        POS mobile with interest
# 112127         POS mobile with interest        POS mobile with interest
# 1633721        POS mobile with interest        POS mobile with interest
# 353849         POS mobile with interest        POS mobile with interest
# 1110923        POS mobile with interest        POS mobile with interest
# 1546520  POS household without interest  POS household without interest
# 295893         POS mobile with interest        POS mobile with interest
# 9249                  Cash Street: high               Cash Street: high
# 1081823     POS household with interest     POS household with interest
# 1667804     POS household with interest     POS household with interest
# 263247   POS household without interest  POS household without interest
# 367540   POS household without interest     POS household with interest
# 1173319     POS household with interest     POS household with interest
# 476343      POS household with interest     POS household with interest
# 545170      POS household with interest     POS household with interest
# ...                                 ...                             ...
# 667009      POS household with interest     POS household with interest
# 204712       POS industry with interest      POS industry with interest
# 1057128        POS mobile with interest        POS mobile with interest
# 268581      POS household with interest     POS household with interest
# 1560859     POS household with interest     POS household with interest
# 802869       POS industry with interest      POS industry with interest
# 136412         POS mobile with interest        POS mobile with interest
# 1563106     POS household with interest     POS household with interest
# 602647       POS industry with interest      POS industry with interest
# 437953   POS household without interest     POS household with interest
# 128126      POS household with interest  POS household without interest
# 41550       POS household with interest     POS household with interest
# 1110488     POS household with interest     POS household with interest
# 1322611      POS industry with interest      POS industry with interest
# 753178      POS household with interest     POS household with interest
# 530512         POS mobile with interest        POS mobile with interest
# 1408920     POS household with interest     POS household with interest
# 116647      POS household with interest     POS household with interest
# 785230   POS household without interest  POS household without interest
# 1187632               Cash X-Sell: high               Cash X-Sell: high
# 1508124      POS industry with interest      POS industry with interest
# 1346723        POS mobile with interest        POS mobile with interest
# 777416      POS household with interest     POS household with interest
# 56865       POS household with interest     POS household with interest
# 512439         POS mobile with interest        POS mobile with interest
# 1544638        POS mobile with interest        POS mobile with interest
# 452838                Cash Street: high               Cash Street: high
# 838592       POS industry with interest      POS industry with interest
# 423585                Cash X-Sell: high               Cash X-Sell: high
# 785443         POS mobile with interest        POS mobile with interest
#
#          PRODUCT_COMBINATION_imputed_proba
# 265076                            0.995796
# 1529698                           0.560829
# 788943                            0.991698
# 69679                             0.956910
# 420487                            0.483662
# 231187                            0.925527
# 583942                            0.983383
# 1088118                           0.978934
# 542793                            0.830658
# 1332567                           0.922260
# 1334482                           0.964797
# 446311                            0.922443
# 5772                              0.947835
# 720903                            0.963801
# 729332                            0.995398
# 426504                            0.977163
# 112127                            0.998812
# 1633721                           0.988393
# 353849                            0.949426
# 1110923                           0.989324
# 1546520                           0.957206
# 295893                            0.989342
# 9249                              0.977473
# 1081823                           0.994115
# 1667804                           0.951749
# 263247                            0.976518
# 367540                            0.992234
# 1173319                           0.983880
# 476343                            0.992643
# 545170                            0.523072
# ...                                    ...
# 667009                            0.991989
# 204712                            0.979625
# 1057128                           0.995103
# 268581                            0.987621
# 1560859                           0.996700
# 802869                            0.989507
# 136412                            0.984165
# 1563106                           0.998557
# 602647                            0.993019
# 437953                            0.700193
# 128126                            0.528842
# 41550                             0.993987
# 1110488                           0.997026
# 1322611                           0.995172
# 753178                            0.879323
# 530512                            0.960289
# 1408920                           0.974010
# 116647                            0.916809
# 785230                            0.818001
# 1187632                           0.876777
# 1508124                           0.997428
# 1346723                           0.921395
# 777416                            0.997178
# 56865                             0.991266
# 512439                            0.992381
# 1544638                           0.994775
# 452838                            0.993516
# 838592                            0.998493
# 423585                            0.966127
# 785443                            0.979887
#
# [200 rows x 3 columns]

# %% [markdown]
# # Conclusion
#
# The results don't look to bad on this simple example.
#
# * Try it on another data and see how well it works
# * Practice using a larger sample size, or different column

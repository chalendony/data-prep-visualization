# %% [markdown]
# # Imputing Categorical Using DataWig

# %% [markdown]
# # Python Imports

# %%
# %config IPCompleter.greedy=True
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelBinarizer
pd.set_option('display.max_columns', 125)
import quilt
from scripts.preprocess import percent_missing, align_dataframes, as_dict
from string import Template
import missingno as msno
import impyute
import datawig
from sklearn.metrics import f1_score, classification_report

# %%
from quilt.data.avare import homecredit

# %%
# avoid parens and copy original data
table = 'previous_application'
df = homecredit[table]().copy(deep=True)
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 0                       15                           Y
# 1                       11                           Y
# 2                       11                           Y
# 3                        7                           Y
# 4                        9                           Y
#
#    NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 0                       1                0.0               0.182832
# 1                       1                NaN                    NaN
# 2                       1                NaN                    NaN
# 3                       1                NaN                    NaN
# 4                       1                NaN                    NaN
#
#    RATE_INTEREST_PRIVILEGED NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  \
# 0                  0.867336                    XAP             Approved
# 1                       NaN                    XNA             Approved
# 2                       NaN                    XNA             Approved
# 3                       NaN                    XNA             Approved
# 4                       NaN                Repairs              Refused
#
#    DAYS_DECISION      NAME_PAYMENT_TYPE CODE_REJECT_REASON  NAME_TYPE_SUITE  \
# 0            -73  Cash through the bank                XAP             None
# 1           -164                    XNA                XAP    Unaccompanied
# 2           -301  Cash through the bank                XAP  Spouse, partner
# 3           -512  Cash through the bank                XAP             None
# 4           -781  Cash through the bank                 HC             None
#
#   NAME_CLIENT_TYPE NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  \
# 0         Repeater              Mobile            POS               XNA
# 1         Repeater                 XNA           Cash            x-sell
# 2         Repeater                 XNA           Cash            x-sell
# 3         Repeater                 XNA           Cash            x-sell
# 4         Repeater                 XNA           Cash           walk-in
#
#               CHANNEL_TYPE  SELLERPLACE_AREA NAME_SELLER_INDUSTRY  \
# 0             Country-wide                35         Connectivity
# 1           Contact center                -1                  XNA
# 2  Credit and cash offices                -1                  XNA
# 3  Credit and cash offices                -1                  XNA
# 4  Credit and cash offices                -1                  XNA
#
#    CNT_PAYMENT NAME_YIELD_GROUP       PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  \
# 0         12.0           middle  POS mobile with interest            365243.0
# 1         36.0       low_action          Cash X-Sell: low            365243.0
# 2         12.0             high         Cash X-Sell: high            365243.0
# 3         12.0           middle       Cash X-Sell: middle            365243.0
# 4         24.0             high         Cash Street: high                 NaN
#
#    DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0           -42.0                      300.0          -42.0             -37.0
# 1          -134.0                      916.0       365243.0          365243.0
# 2          -271.0                       59.0       365243.0          365243.0
# 3          -482.0                     -152.0         -182.0            -177.0
# 4             NaN                        NaN            NaN               NaN
#
#    NFLAG_INSURED_ON_APPROVAL
# 0                        0.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        NaN

# %%
# drop keys and empty columns
dropcols = ['RATE_INTEREST_PRIVILEGED','RATE_INTEREST_PRIMARY','SK_ID_PREV', 'SK_ID_CURR']
df.drop(dropcols, axis=1, inplace=True)

# drop rows containing null, also done by datawig?
df.dropna(axis=0, how='any', inplace=True)

# select random instances
seed = 500
numinstances = 1000
df = df.sample(numinstances,random_state=seed)
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 929166 to 1290315
# Data columns (total 33 columns):
# NAME_CONTRACT_TYPE             1000 non-null object
# AMT_ANNUITY                    1000 non-null float64
# AMT_APPLICATION                1000 non-null float64
# AMT_CREDIT                     1000 non-null float64
# AMT_DOWN_PAYMENT               1000 non-null float64
# AMT_GOODS_PRICE                1000 non-null float64
# WEEKDAY_APPR_PROCESS_START     1000 non-null object
# HOUR_APPR_PROCESS_START        1000 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    1000 non-null object
# NFLAG_LAST_APPL_IN_DAY         1000 non-null int64
# RATE_DOWN_PAYMENT              1000 non-null float64
# NAME_CASH_LOAN_PURPOSE         1000 non-null object
# NAME_CONTRACT_STATUS           1000 non-null object
# DAYS_DECISION                  1000 non-null int64
# NAME_PAYMENT_TYPE              1000 non-null object
# CODE_REJECT_REASON             1000 non-null object
# NAME_TYPE_SUITE                1000 non-null object
# NAME_CLIENT_TYPE               1000 non-null object
# NAME_GOODS_CATEGORY            1000 non-null object
# NAME_PORTFOLIO                 1000 non-null object
# NAME_PRODUCT_TYPE              1000 non-null object
# CHANNEL_TYPE                   1000 non-null object
# SELLERPLACE_AREA               1000 non-null int64
# NAME_SELLER_INDUSTRY           1000 non-null object
# CNT_PAYMENT                    1000 non-null float64
# NAME_YIELD_GROUP               1000 non-null object
# PRODUCT_COMBINATION            1000 non-null object
# DAYS_FIRST_DRAWING             1000 non-null float64
# DAYS_FIRST_DUE                 1000 non-null float64
# DAYS_LAST_DUE_1ST_VERSION      1000 non-null float64
# DAYS_LAST_DUE                  1000 non-null float64
# DAYS_TERMINATION               1000 non-null float64
# NFLAG_INSURED_ON_APPROVAL      1000 non-null float64
# dtypes: float64(13), int64(4), object(16)
# memory usage: 265.6+ KB

# %% [markdown]
# # Preprocessing:  Data Types
#
#
# Types are inferred, but this may not be what you expect.  Go beyond either categorical or numerical data type:
#
# * decide how to encode the data
# * performance : Avoid OneHot for high cardinality columns and decision tree-based algorithms.
# * algorithm restrictions
#
#
# Rule of Thumb:
#
# https://towardsdatascience.com/7-data-types-a-better-way-to-think-about-data-types-for-machine-learning-939fae99a689

# %% [markdown]
# ## Assign Data Types

# %%
# assign data types
description = pd.read_excel('data/HomeCredit_columns_description.xlsx', sheet_name='Sheet1',usecols=[2,3,4])
description.head()
# Out:
#                Table                 Row         Type
# 0  application_train          SK_ID_CURR    numerical
# 1  application_train              TARGET  categorical
# 2  application_train  NAME_CONTRACT_TYPE  categorical
# 3  application_train         CODE_GENDER  categorical
# 4  application_train        FLAG_OWN_CAR  categorical

# %%
# rename to python types
python_cat_dtype = 'object'
python_num_dtype = 'float64'

description.replace('categorical', python_cat_dtype, inplace=True)
description.replace('numerical', python_num_dtype, inplace=True)

# type cols
typecols = description[(description.Table == table)]
typecols.head()
# Out:
#                     Table                 Row     Type
# 173  previous_application         SK_ID_PREV   float64
# 174  previous_application          SK_ID_CURR  float64
# 175  previous_application  NAME_CONTRACT_TYPE   object
# 176  previous_application         AMT_ANNUITY  float64
# 177  previous_application     AMT_APPLICATION  float64

# %%
# get target columns 
targetcols = pd.DataFrame(df.columns, columns=['Row'])
targetcols.head()
# Out:
#                   Row
# 0  NAME_CONTRACT_TYPE
# 1         AMT_ANNUITY
# 2     AMT_APPLICATION
# 3          AMT_CREDIT
# 4    AMT_DOWN_PAYMENT

# %%
# join , ensure col correct -  we dont know which cols are present in the description
targetcols = targetcols.merge(typecols, how='left')
targetcols.head()
# Out:
#                   Row                 Table     Type
# 0  NAME_CONTRACT_TYPE  previous_application   object
# 1         AMT_ANNUITY  previous_application  float64
# 2     AMT_APPLICATION  previous_application  float64
# 3          AMT_CREDIT  previous_application  float64
# 4    AMT_DOWN_PAYMENT  previous_application  float64

# %%
# retrieve all columns of same type 
cat = targetcols.loc[(targetcols.Type == python_cat_dtype),'Row'].values.tolist()
num = targetcols.loc[(targetcols.Type == python_num_dtype),'Row'].values.tolist()

print(cat)
#print(num)
#print(len(cat) + len(num))
# Out:
# ['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION', 'NFLAG_INSURED_ON_APPROVAL']

# %%
## batch update types 
df[cat] = df[cat].astype(python_cat_dtype)
df[num] = df[num].astype(python_num_dtype)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 929166 to 1290315
# Data columns (total 33 columns):
# NAME_CONTRACT_TYPE             1000 non-null object
# AMT_ANNUITY                    1000 non-null float64
# AMT_APPLICATION                1000 non-null float64
# AMT_CREDIT                     1000 non-null float64
# AMT_DOWN_PAYMENT               1000 non-null float64
# AMT_GOODS_PRICE                1000 non-null float64
# WEEKDAY_APPR_PROCESS_START     1000 non-null object
# HOUR_APPR_PROCESS_START        1000 non-null float64
# FLAG_LAST_APPL_PER_CONTRACT    1000 non-null object
# NFLAG_LAST_APPL_IN_DAY         1000 non-null object
# RATE_DOWN_PAYMENT              1000 non-null float64
# NAME_CASH_LOAN_PURPOSE         1000 non-null object
# NAME_CONTRACT_STATUS           1000 non-null object
# DAYS_DECISION                  1000 non-null float64
# NAME_PAYMENT_TYPE              1000 non-null object
# CODE_REJECT_REASON             1000 non-null object
# NAME_TYPE_SUITE                1000 non-null object
# NAME_CLIENT_TYPE               1000 non-null object
# NAME_GOODS_CATEGORY            1000 non-null object
# NAME_PORTFOLIO                 1000 non-null object
# NAME_PRODUCT_TYPE              1000 non-null object
# CHANNEL_TYPE                   1000 non-null object
# SELLERPLACE_AREA               1000 non-null object
# NAME_SELLER_INDUSTRY           1000 non-null object
# CNT_PAYMENT                    1000 non-null float64
# NAME_YIELD_GROUP               1000 non-null object
# PRODUCT_COMBINATION            1000 non-null object
# DAYS_FIRST_DRAWING             1000 non-null float64
# DAYS_FIRST_DUE                 1000 non-null float64
# DAYS_LAST_DUE_1ST_VERSION      1000 non-null float64
# DAYS_LAST_DUE                  1000 non-null float64
# DAYS_TERMINATION               1000 non-null float64
# NFLAG_INSURED_ON_APPROVAL      1000 non-null object
# dtypes: float64(14), object(19)
# memory usage: 265.6+ KB

# %% [markdown]
# ## Encode Categorical
#
# * Article : Exploring Category Encoders
# *  https://towardsdatascience.com/smarter-ways-to-encode-categorical-data-for-machine-learning-part-1-of-3-6dca2f71b159
# * Category Encoders Package http://contrib.scikit-learn.org/categorical-encoding/index.html
#
# Take home message: categoricals should look like strings and not numbers . preprocessing feature should be done: example hours are categorical but look like numbers
#
# * boolean flags that are integers
# * HOUR_APPR_PROCESS_START : Hour of day => made it numerical (ordinal)
# * NFLAG_LAST_APPL_IN_DAY : (0,1) one hot encoded
# * SELLERPLACE_AREA : 2097 instances : numeric code represents categorical ***
# * NFLAG_INSURED_ON_APPROVAL : (0,1)
#
#
# User defined encoding : allows me to reverse encoding, hash sequence of integers to a string

# %%
prefix = 's_'
df['NFLAG_LAST_APPL_IN_DAY'] =  prefix + df['NFLAG_LAST_APPL_IN_DAY'].astype(str) 
df['SELLERPLACE_AREA'] = prefix + df['SELLERPLACE_AREA'].astype(str) 
df['NFLAG_INSURED_ON_APPROVAL'] = prefix +  df['NFLAG_INSURED_ON_APPROVAL'].astype(str)

# %% [markdown]
# # Train Model

# %%
# select a portion of the data for evaluation
df_train, df_test = datawig.utils.random_split(df)

input_cols = [*df.columns.values] ## except producte
output_column = 'PRODUCT_COMBINATION'
output_path = 'imputer_model'

# Initialize a SimpleImputer model
imputer = datawig.SimpleImputer(
    input_columns=input_cols,  # columns containing information about the column we want to impute
    output_column='PRODUCT_COMBINATION',  # the column we'd like to impute values for
    output_path=output_path  # stores model data and metrics
)

# Fit an imputer model on the train data
#imputer.fit(train_df=df_train, num_epochs=5)

# Fit an imputer model with default list of hyperparameters
imputer.fit_hpo(train_df=df_train)

# %% [markdown]
# # Evaluate Performance

# %%
# Impute missing values and return original dataframe with predictions
predictions = imputer.predict(df_test)

# Calculate f1 score for true vs predicted values
f1 = f1_score(predictions[output_column], predictions[output_column+'_imputed'], average='weighted')

# Print overall classification report
print(classification_report(predictions[output_column], predictions[output_column+'_imputed']))


# fit an imputer model with customized hyperparameters
#imputer.fit_hpo(
#    train_df=df_train,
#    num_epochs=100,
#    patience=3,
#    learning_rate_candidates=[1e-3, 3e-4, 1e-4]
#)
# Out:
# 2019-05-01 19:08:38,007 [INFO]  Assuming 14 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, HOUR_APPR_PROCESS_START, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-01 19:08:38,009 [INFO]  Assuming 19 string input columns: NAME_PORTFOLIO, NAME_TYPE_SUITE, NAME_CASH_LOAN_PURPOSE, NAME_CONTRACT_STATUS, NAME_PAYMENT_TYPE, NAME_CLIENT_TYPE, NAME_SELLER_INDUSTRY, NAME_GOODS_CATEGORY, NAME_PRODUCT_TYPE, FLAG_LAST_APPL_PER_CONTRACT, SELLERPLACE_AREA, NAME_YIELD_GROUP, CHANNEL_TYPE, PRODUCT_COMBINATION, NAME_CONTRACT_TYPE, NFLAG_INSURED_ON_APPROVAL, CODE_REJECT_REASON, WEEKDAY_APPR_PROCESS_START, NFLAG_LAST_APPL_IN_DAY
# 2019-05-01 19:08:38,010 [INFO]  Assuming 14 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, HOUR_APPR_PROCESS_START, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-01 19:08:38,012 [INFO]  Assuming 19 string input columns: NAME_PORTFOLIO, NAME_TYPE_SUITE, NAME_CASH_LOAN_PURPOSE, NAME_CONTRACT_STATUS, NAME_PAYMENT_TYPE, NAME_CLIENT_TYPE, NAME_SELLER_INDUSTRY, NAME_GOODS_CATEGORY, NAME_PRODUCT_TYPE, FLAG_LAST_APPL_PER_CONTRACT, SELLERPLACE_AREA, NAME_YIELD_GROUP, CHANNEL_TYPE, PRODUCT_COMBINATION, NAME_CONTRACT_TYPE, NFLAG_INSURED_ON_APPROVAL, CODE_REJECT_REASON, WEEKDAY_APPR_PROCESS_START, NFLAG_LAST_APPL_IN_DAY
# 2019-05-01 19:08:38,036 [INFO]  Training starts for 1hyperparameter configurations.
# 2019-05-01 19:08:38,038 [INFO]  Fitting hpo iteration 0 with parameters
# 	global:batch_size: 16
# 	global:learning_rate: 0.004
# 	global:weight_decay: 0
# 	global:num_epochs: 25
# 	global:patience: 3
# 	global:final_fc_hidden_units: []
# 	NAME_CONTRACT_TYPE:type: string
# 	NAME_CONTRACT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_TYPE:max_tokens: 32768
# 	NAME_CONTRACT_TYPE:tokens: ['chars']
# 	AMT_ANNUITY:type: numeric
# 	AMT_ANNUITY:normalize: True
# 	AMT_ANNUITY:numeric_latent_dim: 10
# 	AMT_ANNUITY:numeric_hidden_layers: 1
# 	AMT_APPLICATION:type: numeric
# 	AMT_APPLICATION:normalize: True
# 	AMT_APPLICATION:numeric_latent_dim: 10
# 	AMT_APPLICATION:numeric_hidden_layers: 1
# 	AMT_CREDIT:type: numeric
# 	AMT_CREDIT:normalize: True
# 	AMT_CREDIT:numeric_latent_dim: 10
# 	AMT_CREDIT:numeric_hidden_layers: 1
# 	AMT_DOWN_PAYMENT:type: numeric
# 	AMT_DOWN_PAYMENT:normalize: True
# 	AMT_DOWN_PAYMENT:numeric_latent_dim: 10
# 	AMT_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	AMT_GOODS_PRICE:type: numeric
# 	AMT_GOODS_PRICE:normalize: True
# 	AMT_GOODS_PRICE:numeric_latent_dim: 10
# 	AMT_GOODS_PRICE:numeric_hidden_layers: 1
# 	WEEKDAY_APPR_PROCESS_START:type: string
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:words: (1, 3)
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:chars: (1, 5)
# 	WEEKDAY_APPR_PROCESS_START:max_tokens: 32768
# 	WEEKDAY_APPR_PROCESS_START:tokens: ['chars']
# 	HOUR_APPR_PROCESS_START:type: numeric
# 	HOUR_APPR_PROCESS_START:normalize: True
# 	HOUR_APPR_PROCESS_START:numeric_latent_dim: 10
# 	HOUR_APPR_PROCESS_START:numeric_hidden_layers: 1
# 	FLAG_LAST_APPL_PER_CONTRACT:type: string
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:words: (1, 3)
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:chars: (1, 5)
# 	FLAG_LAST_APPL_PER_CONTRACT:max_tokens: 32768
# 	FLAG_LAST_APPL_PER_CONTRACT:tokens: ['chars']
# 	NFLAG_LAST_APPL_IN_DAY:type: string
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:words: (1, 3)
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:chars: (1, 5)
# 	NFLAG_LAST_APPL_IN_DAY:max_tokens: 32768
# 	NFLAG_LAST_APPL_IN_DAY:tokens: ['chars']
# 	RATE_DOWN_PAYMENT:type: numeric
# 	RATE_DOWN_PAYMENT:normalize: True
# 	RATE_DOWN_PAYMENT:numeric_latent_dim: 10
# 	RATE_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	NAME_CASH_LOAN_PURPOSE:type: string
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:words: (1, 3)
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:chars: (1, 5)
# 	NAME_CASH_LOAN_PURPOSE:max_tokens: 32768
# 	NAME_CASH_LOAN_PURPOSE:tokens: ['chars']
# 	NAME_CONTRACT_STATUS:type: string
# 	NAME_CONTRACT_STATUS:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_STATUS:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_STATUS:max_tokens: 32768
# 	NAME_CONTRACT_STATUS:tokens: ['chars']
# 	DAYS_DECISION:type: numeric
# 	DAYS_DECISION:normalize: True
# 	DAYS_DECISION:numeric_latent_dim: 10
# 	DAYS_DECISION:numeric_hidden_layers: 1
# 	NAME_PAYMENT_TYPE:type: string
# 	NAME_PAYMENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PAYMENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PAYMENT_TYPE:max_tokens: 32768
# 	NAME_PAYMENT_TYPE:tokens: ['chars']
# 	CODE_REJECT_REASON:type: string
# 	CODE_REJECT_REASON:ngram_range:words: (1, 3)
# 	CODE_REJECT_REASON:ngram_range:chars: (1, 5)
# 	CODE_REJECT_REASON:max_tokens: 32768
# 	CODE_REJECT_REASON:tokens: ['chars']
# 	NAME_TYPE_SUITE:type: string
# 	NAME_TYPE_SUITE:ngram_range:words: (1, 3)
# 	NAME_TYPE_SUITE:ngram_range:chars: (1, 5)
# 	NAME_TYPE_SUITE:max_tokens: 32768
# 	NAME_TYPE_SUITE:tokens: ['chars']
# 	NAME_CLIENT_TYPE:type: string
# 	NAME_CLIENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CLIENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CLIENT_TYPE:max_tokens: 32768
# 	NAME_CLIENT_TYPE:tokens: ['chars']
# 	NAME_GOODS_CATEGORY:type: string
# 	NAME_GOODS_CATEGORY:ngram_range:words: (1, 3)
# 	NAME_GOODS_CATEGORY:ngram_range:chars: (1, 5)
# 	NAME_GOODS_CATEGORY:max_tokens: 32768
# 	NAME_GOODS_CATEGORY:tokens: ['chars']
# 	NAME_PORTFOLIO:type: string
# 	NAME_PORTFOLIO:ngram_range:words: (1, 3)
# 	NAME_PORTFOLIO:ngram_range:chars: (1, 5)
# 	NAME_PORTFOLIO:max_tokens: 32768
# 	NAME_PORTFOLIO:tokens: ['chars']
# 	NAME_PRODUCT_TYPE:type: string
# 	NAME_PRODUCT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PRODUCT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PRODUCT_TYPE:max_tokens: 32768
# 	NAME_PRODUCT_TYPE:tokens: ['chars']
# 	CHANNEL_TYPE:type: string
# 	CHANNEL_TYPE:ngram_range:words: (1, 3)
# 	CHANNEL_TYPE:ngram_range:chars: (1, 5)
# 	CHANNEL_TYPE:max_tokens: 32768
# 	CHANNEL_TYPE:tokens: ['chars']
# 	SELLERPLACE_AREA:type: string
# 	SELLERPLACE_AREA:ngram_range:words: (1, 3)
# 	SELLERPLACE_AREA:ngram_range:chars: (1, 5)
# 	SELLERPLACE_AREA:max_tokens: 32768
# 	SELLERPLACE_AREA:tokens: ['chars']
# 	NAME_SELLER_INDUSTRY:type: string
# 	NAME_SELLER_INDUSTRY:ngram_range:words: (1, 3)
# 	NAME_SELLER_INDUSTRY:ngram_range:chars: (1, 5)
# 	NAME_SELLER_INDUSTRY:max_tokens: 32768
# 	NAME_SELLER_INDUSTRY:tokens: ['chars']
# 	CNT_PAYMENT:type: numeric
# 	CNT_PAYMENT:normalize: True
# 	CNT_PAYMENT:numeric_latent_dim: 10
# 	CNT_PAYMENT:numeric_hidden_layers: 1
# 	NAME_YIELD_GROUP:type: string
# 	NAME_YIELD_GROUP:ngram_range:words: (1, 3)
# 	NAME_YIELD_GROUP:ngram_range:chars: (1, 5)
# 	NAME_YIELD_GROUP:max_tokens: 32768
# 	NAME_YIELD_GROUP:tokens: ['chars']
# 	PRODUCT_COMBINATION:type: string
# 	PRODUCT_COMBINATION:ngram_range:words: (1, 3)
# 	PRODUCT_COMBINATION:ngram_range:chars: (1, 5)
# 	PRODUCT_COMBINATION:max_tokens: 32768
# 	PRODUCT_COMBINATION:tokens: ['chars']
# 	DAYS_FIRST_DRAWING:type: numeric
# 	DAYS_FIRST_DRAWING:normalize: True
# 	DAYS_FIRST_DRAWING:numeric_latent_dim: 10
# 	DAYS_FIRST_DRAWING:numeric_hidden_layers: 1
# 	DAYS_FIRST_DUE:type: numeric
# 	DAYS_FIRST_DUE:normalize: True
# 	DAYS_FIRST_DUE:numeric_latent_dim: 10
# 	DAYS_FIRST_DUE:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE_1ST_VERSION:type: numeric
# 	DAYS_LAST_DUE_1ST_VERSION:normalize: True
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_latent_dim: 10
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE:type: numeric
# 	DAYS_LAST_DUE:normalize: True
# 	DAYS_LAST_DUE:numeric_latent_dim: 10
# 	DAYS_LAST_DUE:numeric_hidden_layers: 1
# 	DAYS_TERMINATION:type: numeric
# 	DAYS_TERMINATION:normalize: True
# 	DAYS_TERMINATION:numeric_latent_dim: 10
# 	DAYS_TERMINATION:numeric_hidden_layers: 1
# 	NFLAG_INSURED_ON_APPROVAL:type: string
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:words: (1, 3)
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:chars: (1, 5)
# 	NFLAG_INSURED_ON_APPROVAL:max_tokens: 32768
# 	NFLAG_INSURED_ON_APPROVAL:tokens: ['chars']
# 2019-05-01 19:08:38,052 [INFO]  No output column name provided for ColumnEncoder using PRODUCT_COMBINATION
# 2019-05-01 19:08:38,055 [INFO]  Assuming categorical output column: PRODUCT_COMBINATION
# 2019-05-01 19:08:38,065 [INFO]  Using [[cpu(0)]] as the context for training
# 2019-05-01 19:08:38,067 [INFO]  Fitting label encoder <class 'datawig.column_encoders.CategoricalEncoder'> on 640 rows                             of training data
# 2019-05-01 19:08:38,075 [INFO]  12 most often encountered discrete values:                      ['POS household with interest' 'POS mobile with interest'
#  'POS industry with interest' 'POS household without interest'
#  'Cash Street: high' 'POS other with interest' 'Cash X-Sell: high'
#  'POS industry without interest' 'Cash X-Sell: middle'
#  'Cash Street: middle' 'POS mobile without interest' 'Cash X-Sell: low']
# 2019-05-01 19:08:38,077 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 96 occurrences of value POS industry with interest
# 2019-05-01 19:08:38,078 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 79 occurrences of value POS household without interest
# 2019-05-01 19:08:38,080 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 19 occurrences of value Cash Street: high
# 2019-05-01 19:08:38,082 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 17 occurrences of value POS other with interest
# 2019-05-01 19:08:38,083 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 10 occurrences of value Cash X-Sell: high
# 2019-05-01 19:08:38,085 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 6 occurrences of value POS industry without interest
# 2019-05-01 19:08:38,087 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 4 occurrences of value Cash X-Sell: middle
# 2019-05-01 19:08:38,089 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value Cash Street: middle
# 2019-05-01 19:08:38,090 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value POS mobile without interest
# 2019-05-01 19:08:38,092 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 2 occurrences of value Cash X-Sell: low
# 2019-05-01 19:08:38,096 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 19:08:38,098 [INFO]  Dropping 0/640 rows
# 2019-05-01 19:08:38,103 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 19:08:38,106 [INFO]  Dropping 0/160 rows
# 2019-05-01 19:08:38,109 [INFO]  Train: 640, Test: 160
# 2019-05-01 19:08:38,110 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_ANNUITY and 640 rows of training data with parameters {'input_columns': ['AMT_ANNUITY'], 'output_column': 'AMT_ANNUITY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,119 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_APPLICATION and 640 rows of training data with parameters {'input_columns': ['AMT_APPLICATION'], 'output_column': 'AMT_APPLICATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,128 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_CREDIT and 640 rows of training data with parameters {'input_columns': ['AMT_CREDIT'], 'output_column': 'AMT_CREDIT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,137 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['AMT_DOWN_PAYMENT'], 'output_column': 'AMT_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,147 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_GOODS_PRICE and 640 rows of training data with parameters {'input_columns': ['AMT_GOODS_PRICE'], 'output_column': 'AMT_GOODS_PRICE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,156 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns HOUR_APPR_PROCESS_START and 640 rows of training data with parameters {'input_columns': ['HOUR_APPR_PROCESS_START'], 'output_column': 'HOUR_APPR_PROCESS_START_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,169 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['RATE_DOWN_PAYMENT'], 'output_column': 'RATE_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,179 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_DECISION and 640 rows of training data with parameters {'input_columns': ['DAYS_DECISION'], 'output_column': 'DAYS_DECISION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,190 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns CNT_PAYMENT and 640 rows of training data with parameters {'input_columns': ['CNT_PAYMENT'], 'output_column': 'CNT_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,199 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DRAWING and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DRAWING'], 'output_column': 'DAYS_FIRST_DRAWING_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,208 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DUE'], 'output_column': 'DAYS_FIRST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,217 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE_1ST_VERSION and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE_1ST_VERSION'], 'output_column': 'DAYS_LAST_DUE_1ST_VERSION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,227 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE'], 'output_column': 'DAYS_LAST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,238 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_TERMINATION and 640 rows of training data with parameters {'input_columns': ['DAYS_TERMINATION'], 'output_column': 'DAYS_TERMINATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:08:38,247 [INFO]  Building Train Iterator with 640 elements
# 2019-05-01 19:08:38,318 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,323 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:08:38,324 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,335 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,340 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:08:38,342 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,346 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,351 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:08:38,352 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,356 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,362 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:08:38,364 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,368 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,373 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:08:38,374 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,379 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,408 [INFO]  Data Encoding - Encoded 640 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,425 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:08:38,426 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,433 [INFO]  Data Encoding - Encoded 640 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,445 [INFO]  Data Encoding - Encoded 640 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,467 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,475 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:08:38,479 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,486 [INFO]  Data Encoding - Encoded 640 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,504 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,540 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,545 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:08:38,546 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,551 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:38,664 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,690 [INFO]  Data Encoding - Encoded 640 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,756 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,788 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,825 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,839 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,853 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,888 [INFO]  Data Encoding - Encoded 640 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,903 [INFO]  Data Encoding - Encoded 640 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,963 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:38,970 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:08:38,971 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:38,975 [INFO]  Data Encoding - Encoded 640 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:39,004 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:39,089 [INFO]  Data Encoding - Encoded 640 rows of column                         PRODUCT_COMBINATION with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:39,092 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:08:39,094 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,098 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:39,102 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:08:39,105 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,110 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:39,116 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:08:39,118 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,123 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:39,128 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:08:39,129 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,134 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:39,138 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:08:39,140 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,143 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:08:39,159 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:08:39,160 [INFO]  CategoricalEncoder encoding 640 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:08:39,174 [INFO]  Label Encoding - Encoded 640 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (640, 1) and                             then into shape (640, 1)
# 2019-05-01 19:08:39,176 [INFO]  Building Test Iterator with 160 elements
# 2019-05-01 19:08:39,210 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,215 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:08:39,217 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,221 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,226 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:08:39,227 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,232 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,238 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:08:39,239 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,242 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,247 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:08:39,249 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,255 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,263 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:08:39,267 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,272 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,285 [INFO]  Data Encoding - Encoded 160 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,289 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:08:39,291 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,298 [INFO]  Data Encoding - Encoded 160 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,302 [INFO]  Data Encoding - Encoded 160 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,308 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,315 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:08:39,318 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,324 [INFO]  Data Encoding - Encoded 160 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,328 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,339 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,343 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:08:39,345 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,350 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,366 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,372 [INFO]  Data Encoding - Encoded 160 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,379 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,385 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,394 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,398 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,403 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,414 [INFO]  Data Encoding - Encoded 160 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,422 [INFO]  Data Encoding - Encoded 160 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,434 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,438 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:08:39,440 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,443 [INFO]  Data Encoding - Encoded 160 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,452 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,472 [INFO]  Data Encoding - Encoded 160 rows of column                         PRODUCT_COMBINATION with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,476 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:08:39,477 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,482 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,487 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:08:39,488 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,492 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,498 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:08:39,500 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,503 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,508 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:08:39,509 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,514 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,522 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:08:39,523 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:08:39,527 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:08:39,534 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:08:39,535 [INFO]  CategoricalEncoder encoding 160 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:08:39,541 [INFO]  Label Encoding - Encoded 160 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (160, 1) and                             then into shape (160, 1)
# 2019-05-01 19:08:39,543 [WARNING]  Test set does not contain any ocurrences of values [Cash X-Sell: low] in column [PRODUCT_COMBINATION], consider using a more representative test set.
# 2019-05-01 19:08:39,545 [INFO]  Concatenating all 33 latent symbols
# 2019-05-01 19:08:39,547 [INFO]  Constructing categorical loss for column PRODUCT_COMBINATION and 12 labels
# 2019-05-01 19:08:39,550 [INFO]  Building output of label <Symbol PRODUCT_COMBINATION> with 13 classes                      (including missing class)
# 2019-05-01 19:08:39,554 [INFO]  Building output symbols
# 2019-05-01 19:08:39,570 [INFO]
# ========== start: fit model
# 2019-05-01 19:08:39,573 [WARNING]  Already bound, ignoring bind()
# 2019-05-01 19:08:44,304 [INFO]  Epoch[0] Batch [0-20]	Speed: 76.64 samples/sec	cross-entropy=1.163805	PRODUCT_COMBINATION-accuracy=0.633929
# 2019-05-01 19:08:48,204 [INFO]  Epoch[0] Train-cross-entropy=0.865654
# 2019-05-01 19:08:48,205 [INFO]  Epoch[0] Train-PRODUCT_COMBINATION-accuracy=0.737500
# 2019-05-01 19:08:48,206 [INFO]  Epoch[0] Time cost=8.622
# 2019-05-01 19:08:48,453 [INFO]  Saved checkpoint to "imputer_model0/model-0000.params"
# 2019-05-01 19:08:49,788 [INFO]  Epoch[0] Validation-cross-entropy=0.466289
# 2019-05-01 19:08:49,789 [INFO]  Epoch[0] Validation-PRODUCT_COMBINATION-accuracy=0.893750
# 2019-05-01 19:08:53,977 [INFO]  Epoch[1] Batch [0-20]	Speed: 80.45 samples/sec	cross-entropy=0.305338	PRODUCT_COMBINATION-accuracy=0.913690
# 2019-05-01 19:08:57,819 [INFO]  Epoch[1] Train-cross-entropy=0.279383
# 2019-05-01 19:08:57,820 [INFO]  Epoch[1] Train-PRODUCT_COMBINATION-accuracy=0.931250
# 2019-05-01 19:08:57,821 [INFO]  Epoch[1] Time cost=8.030
# 2019-05-01 19:08:58,030 [INFO]  Saved checkpoint to "imputer_model0/model-0001.params"
# 2019-05-01 19:08:59,379 [INFO]  Epoch[1] Validation-cross-entropy=0.252770
# 2019-05-01 19:08:59,380 [INFO]  Epoch[1] Validation-PRODUCT_COMBINATION-accuracy=0.943750
# 2019-05-01 19:09:03,604 [INFO]  Epoch[2] Batch [0-20]	Speed: 79.62 samples/sec	cross-entropy=0.170623	PRODUCT_COMBINATION-accuracy=0.961310
# 2019-05-01 19:09:07,435 [INFO]  Epoch[2] Train-cross-entropy=0.165590
# 2019-05-01 19:09:07,436 [INFO]  Epoch[2] Train-PRODUCT_COMBINATION-accuracy=0.970313
# 2019-05-01 19:09:07,438 [INFO]  Epoch[2] Time cost=8.056
# 2019-05-01 19:09:07,641 [INFO]  Saved checkpoint to "imputer_model0/model-0002.params"
# 2019-05-01 19:09:08,986 [INFO]  Epoch[2] Validation-cross-entropy=0.191280
# 2019-05-01 19:09:08,987 [INFO]  Epoch[2] Validation-PRODUCT_COMBINATION-accuracy=0.956250
# 2019-05-01 19:09:13,135 [INFO]  Epoch[3] Batch [0-20]	Speed: 81.19 samples/sec	cross-entropy=0.114395	PRODUCT_COMBINATION-accuracy=0.979167
# 2019-05-01 19:09:16,920 [INFO]  Epoch[3] Train-cross-entropy=0.114182
# 2019-05-01 19:09:16,921 [INFO]  Epoch[3] Train-PRODUCT_COMBINATION-accuracy=0.982812
# 2019-05-01 19:09:16,922 [INFO]  Epoch[3] Time cost=7.934
# 2019-05-01 19:09:17,129 [INFO]  Saved checkpoint to "imputer_model0/model-0003.params"
# 2019-05-01 19:09:18,465 [INFO]  Epoch[3] Validation-cross-entropy=0.166385
# 2019-05-01 19:09:18,466 [INFO]  Epoch[3] Validation-PRODUCT_COMBINATION-accuracy=0.962500
# 2019-05-01 19:09:22,626 [INFO]  Epoch[4] Batch [0-20]	Speed: 80.90 samples/sec	cross-entropy=0.083724	PRODUCT_COMBINATION-accuracy=0.985119
# 2019-05-01 19:09:26,367 [INFO]  Epoch[4] Train-cross-entropy=0.085031
# 2019-05-01 19:09:26,368 [INFO]  Epoch[4] Train-PRODUCT_COMBINATION-accuracy=0.987500
# 2019-05-01 19:09:26,370 [INFO]  Epoch[4] Time cost=7.902
# 2019-05-01 19:09:26,625 [INFO]  Saved checkpoint to "imputer_model0/model-0004.params"
# 2019-05-01 19:09:27,997 [INFO]  Epoch[4] Validation-cross-entropy=0.153569
# 2019-05-01 19:09:27,998 [INFO]  Epoch[4] Validation-PRODUCT_COMBINATION-accuracy=0.962500
# 2019-05-01 19:09:32,175 [INFO]  Epoch[5] Batch [0-20]	Speed: 80.72 samples/sec	cross-entropy=0.064473	PRODUCT_COMBINATION-accuracy=0.997024
# 2019-05-01 19:09:35,919 [INFO]  Epoch[5] Train-cross-entropy=0.066325
# 2019-05-01 19:09:35,920 [INFO]  Epoch[5] Train-PRODUCT_COMBINATION-accuracy=0.995313
# 2019-05-01 19:09:35,921 [INFO]  Epoch[5] Time cost=7.922
# 2019-05-01 19:09:36,130 [INFO]  Saved checkpoint to "imputer_model0/model-0005.params"
# 2019-05-01 19:09:37,519 [INFO]  Epoch[5] Validation-cross-entropy=0.145318
# 2019-05-01 19:09:37,520 [INFO]  Epoch[5] Validation-PRODUCT_COMBINATION-accuracy=0.962500
# 2019-05-01 19:09:41,924 [INFO]  Epoch[6] Batch [0-20]	Speed: 76.28 samples/sec	cross-entropy=0.051477	PRODUCT_COMBINATION-accuracy=0.997024
# 2019-05-01 19:09:45,677 [INFO]  Epoch[6] Train-cross-entropy=0.053563
# 2019-05-01 19:09:45,679 [INFO]  Epoch[6] Train-PRODUCT_COMBINATION-accuracy=0.995313
# 2019-05-01 19:09:45,680 [INFO]  Epoch[6] Time cost=8.158
# 2019-05-01 19:09:45,882 [INFO]  Saved checkpoint to "imputer_model0/model-0006.params"
# 2019-05-01 19:09:47,256 [INFO]  Epoch[6] Validation-cross-entropy=0.140275
# 2019-05-01 19:09:47,258 [INFO]  Epoch[6] Validation-PRODUCT_COMBINATION-accuracy=0.962500
# 2019-05-01 19:09:51,559 [INFO]  Epoch[7] Batch [0-20]	Speed: 79.69 samples/sec	cross-entropy=0.042249	PRODUCT_COMBINATION-accuracy=1.000000
# 2019-05-01 19:09:55,346 [INFO]  Epoch[7] Train-cross-entropy=0.044461
# 2019-05-01 19:09:55,347 [INFO]  Epoch[7] Train-PRODUCT_COMBINATION-accuracy=0.998437
# 2019-05-01 19:09:55,349 [INFO]  Epoch[7] Time cost=8.090
# 2019-05-01 19:09:55,561 [INFO]  Saved checkpoint to "imputer_model0/model-0007.params"
# 2019-05-01 19:09:56,905 [INFO]  Epoch[7] Validation-cross-entropy=0.137119
# 2019-05-01 19:09:56,906 [INFO]  Epoch[7] Validation-PRODUCT_COMBINATION-accuracy=0.962500
# 2019-05-01 19:10:01,146 [INFO]  Epoch[8] Batch [0-20]	Speed: 79.33 samples/sec	cross-entropy=0.035501	PRODUCT_COMBINATION-accuracy=1.000000
# 2019-05-01 19:10:04,901 [INFO]  Epoch[8] Train-cross-entropy=0.037718
# 2019-05-01 19:10:04,902 [INFO]  Epoch[8] Train-PRODUCT_COMBINATION-accuracy=0.998437
# 2019-05-01 19:10:04,903 [INFO]  Epoch[8] Time cost=7.996
# 2019-05-01 19:10:05,116 [INFO]  Saved checkpoint to "imputer_model0/model-0008.params"
# 2019-05-01 19:10:06,470 [INFO]  Epoch[8] Validation-cross-entropy=0.135212
# 2019-05-01 19:10:06,472 [INFO]  Epoch[8] Validation-PRODUCT_COMBINATION-accuracy=0.962500
# 2019-05-01 19:10:10,660 [INFO]  Epoch[9] Batch [0-20]	Speed: 80.35 samples/sec	cross-entropy=0.030416	PRODUCT_COMBINATION-accuracy=1.000000
# 2019-05-01 19:10:14,386 [INFO]  Epoch[9] Train-cross-entropy=0.032535
# 2019-05-01 19:10:14,387 [INFO]  Epoch[9] Train-PRODUCT_COMBINATION-accuracy=0.998437
# ...
# 2019-05-01 19:12:10,186 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:10,190 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:12:10,194 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:12:10,195 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:10,199 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:12:10,210 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:12:10,212 [INFO]  CategoricalEncoder encoding 640 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:12:10,217 [INFO]  Label Encoding - Encoded 640 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (640, 1) and                             then into shape (640, 1)
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2019-05-01 19:12:16,477 [INFO]  Finished hpo iteration 0
# 2019-05-01 19:12:16,478 [INFO]  Assigning model with highest weighted precision to SimpleImputer object and copying artifacts.
# 2019-05-01 19:12:16,480 [INFO]  Selecting imputer with maximal weighted precision.
# 2019-05-01 19:12:16,562 [INFO]  Output path for loading Imputer imputer_model
# 2019-05-01 19:12:16,570 [INFO]  Loading mxnet model from imputer_model/model
# 2019-05-01 19:12:16,718 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,722 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:12:16,723 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,726 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,730 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:12:16,731 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,735 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,739 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:12:16,740 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,744 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,747 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:12:16,749 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,752 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,756 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:12:16,757 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,761 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,767 [INFO]  Data Encoding - Encoded 208 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,771 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:12:16,772 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,775 [INFO]  Data Encoding - Encoded 208 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,779 [INFO]  Data Encoding - Encoded 208 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,784 [INFO]  Data Encoding - Encoded 208 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,788 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:12:16,789 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,792 [INFO]  Data Encoding - Encoded 208 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,797 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,804 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,807 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:12:16,809 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,812 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,825 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,829 [INFO]  Data Encoding - Encoded 208 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,837 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,843 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,854 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,858 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,863 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,872 [INFO]  Data Encoding - Encoded 208 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,877 [INFO]  Data Encoding - Encoded 208 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,887 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,891 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:12:16,893 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,896 [INFO]  Data Encoding - Encoded 208 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,902 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,921 [INFO]  Data Encoding - Encoded 208 rows of column                         PRODUCT_COMBINATION with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,926 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:12:16,927 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,931 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,934 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:12:16,936 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,940 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,946 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:12:16,947 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,950 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,955 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:12:16,956 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,960 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,964 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:12:16,965 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:12:16,968 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:12:16,974 [INFO]  Data Encoding - Encoded 208 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:12:16,975 [INFO]  CategoricalEncoder encoding 208 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:12:16,981 [INFO]  Label Encoding - Encoded 208 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (208, 1) and                             then into shape (208, 1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-7c80af1eaa47> in <module>
#      24
#      25 # Calculate f1 score for true vs predicted values
# ---> 26 f1 = datawig.f1_score(predictions[output_column], predictions[output_column+'_imputed'], average='weighted')
#      27
#      28 # Print overall classification report
#
# AttributeError: module 'datawig' has no attribute 'f1_score'

# %% [markdown]
# ## Missing Numerical

# %%
# batch: assign each column, select from description
for c in cols:
    dtype = description[c]
    df[c] = df[c].astype(dtype)
    
df.info(versbose=True)
# Out:
#                     Table                          Row         Type
# 175  previous_application           NAME_CONTRACT_TYPE  categorical
# 181  previous_application   WEEKDAY_APPR_PROCESS_START  categorical
# 182  previous_application      HOUR_APPR_PROCESS_START  categorical
# 183  previous_application  FLAG_LAST_APPL_PER_CONTRACT  categorical
# 184  previous_application       NFLAG_LAST_APPL_IN_DAY  categorical

# %% [markdown]
# #### Strategy: Impute Probalistic
#
# * Datawig: https://github.com/awslabs/datawig/blob/master/README.md#imputation-of-numerical-columns

# %%
# fill in some nulls
 ## hmm does not include missing data in th 
#seed = 200
#nullval = df.sample(frac=0.2,random_state=seed)
#test = df.loc[nullval.index,['PRODUCT_COMBINATION']]
nullval.index  
df.loc[nullval.index,['PRODUCT_COMBINATION']] = np.nan
df.loc[nullval.index,['PRODUCT_COMBINATION']].head()


# test set: counts for each value 
test.PRODUCT_COMBINATION.value_counts()

# %%
###### TODO : Assignment of Categoricals is not working!!!

#https://stackoverflow.com/questions/32718639/pandas-filling-nans-in-categorical-data
# update data types : Once you create Categorical Data, you can insert only values in category.
#print('Updating data types')

#table = 'previous_application'

# retriev type from description
#meta = hc_description.loc[hc_description['Table']==table,['Row','Type']]
#dict_types = as_dict(meta)

# set types in data table
#df = df.astype(dict_types)

# %% [markdown]
# # Imputing Categorical Using DataWig

# %% [markdown]
# # Python Imports

# %%
# %config IPCompleter.greedy=True
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelBinarizer
pd.set_option('display.max_columns', 125)
import quilt
from scripts.preprocess import percent_missing, align_dataframes, as_dict
from string import Template
import missingno as msno
import impyute
import datawig
from sklearn.metrics import f1_score, classification_report

# %%
from quilt.data.avare import homecredit

# %%
# avoid parens and copy original data
table = 'previous_application'
df = homecredit[table]().copy(deep=True)
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 0                       15                           Y
# 1                       11                           Y
# 2                       11                           Y
# 3                        7                           Y
# 4                        9                           Y
#
#    NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 0                       1                0.0               0.182832
# 1                       1                NaN                    NaN
# 2                       1                NaN                    NaN
# 3                       1                NaN                    NaN
# 4                       1                NaN                    NaN
#
#    RATE_INTEREST_PRIVILEGED NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  \
# 0                  0.867336                    XAP             Approved
# 1                       NaN                    XNA             Approved
# 2                       NaN                    XNA             Approved
# 3                       NaN                    XNA             Approved
# 4                       NaN                Repairs              Refused
#
#    DAYS_DECISION      NAME_PAYMENT_TYPE CODE_REJECT_REASON  NAME_TYPE_SUITE  \
# 0            -73  Cash through the bank                XAP             None
# 1           -164                    XNA                XAP    Unaccompanied
# 2           -301  Cash through the bank                XAP  Spouse, partner
# 3           -512  Cash through the bank                XAP             None
# 4           -781  Cash through the bank                 HC             None
#
#   NAME_CLIENT_TYPE NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  \
# 0         Repeater              Mobile            POS               XNA
# 1         Repeater                 XNA           Cash            x-sell
# 2         Repeater                 XNA           Cash            x-sell
# 3         Repeater                 XNA           Cash            x-sell
# 4         Repeater                 XNA           Cash           walk-in
#
#               CHANNEL_TYPE  SELLERPLACE_AREA NAME_SELLER_INDUSTRY  \
# 0             Country-wide                35         Connectivity
# 1           Contact center                -1                  XNA
# 2  Credit and cash offices                -1                  XNA
# 3  Credit and cash offices                -1                  XNA
# 4  Credit and cash offices                -1                  XNA
#
#    CNT_PAYMENT NAME_YIELD_GROUP       PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  \
# 0         12.0           middle  POS mobile with interest            365243.0
# 1         36.0       low_action          Cash X-Sell: low            365243.0
# 2         12.0             high         Cash X-Sell: high            365243.0
# 3         12.0           middle       Cash X-Sell: middle            365243.0
# 4         24.0             high         Cash Street: high                 NaN
#
#    DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0           -42.0                      300.0          -42.0             -37.0
# 1          -134.0                      916.0       365243.0          365243.0
# 2          -271.0                       59.0       365243.0          365243.0
# 3          -482.0                     -152.0         -182.0            -177.0
# 4             NaN                        NaN            NaN               NaN
#
#    NFLAG_INSURED_ON_APPROVAL
# 0                        0.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        NaN

# %%
# drop keys and empty columns
dropcols = ['RATE_INTEREST_PRIVILEGED','RATE_INTEREST_PRIMARY','SK_ID_PREV', 'SK_ID_CURR']
df.drop(dropcols, axis=1, inplace=True)

# drop rows containing null, also done by datawig?
df.dropna(axis=0, how='any', inplace=True)

# select random instances
seed = 500
numinstances = 1000
df = df.sample(numinstances,random_state=seed)
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 929166 to 1290315
# Data columns (total 33 columns):
# NAME_CONTRACT_TYPE             1000 non-null object
# AMT_ANNUITY                    1000 non-null float64
# AMT_APPLICATION                1000 non-null float64
# AMT_CREDIT                     1000 non-null float64
# AMT_DOWN_PAYMENT               1000 non-null float64
# AMT_GOODS_PRICE                1000 non-null float64
# WEEKDAY_APPR_PROCESS_START     1000 non-null object
# HOUR_APPR_PROCESS_START        1000 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    1000 non-null object
# NFLAG_LAST_APPL_IN_DAY         1000 non-null int64
# RATE_DOWN_PAYMENT              1000 non-null float64
# NAME_CASH_LOAN_PURPOSE         1000 non-null object
# NAME_CONTRACT_STATUS           1000 non-null object
# DAYS_DECISION                  1000 non-null int64
# NAME_PAYMENT_TYPE              1000 non-null object
# CODE_REJECT_REASON             1000 non-null object
# NAME_TYPE_SUITE                1000 non-null object
# NAME_CLIENT_TYPE               1000 non-null object
# NAME_GOODS_CATEGORY            1000 non-null object
# NAME_PORTFOLIO                 1000 non-null object
# NAME_PRODUCT_TYPE              1000 non-null object
# CHANNEL_TYPE                   1000 non-null object
# SELLERPLACE_AREA               1000 non-null int64
# NAME_SELLER_INDUSTRY           1000 non-null object
# CNT_PAYMENT                    1000 non-null float64
# NAME_YIELD_GROUP               1000 non-null object
# PRODUCT_COMBINATION            1000 non-null object
# DAYS_FIRST_DRAWING             1000 non-null float64
# DAYS_FIRST_DUE                 1000 non-null float64
# DAYS_LAST_DUE_1ST_VERSION      1000 non-null float64
# DAYS_LAST_DUE                  1000 non-null float64
# DAYS_TERMINATION               1000 non-null float64
# NFLAG_INSURED_ON_APPROVAL      1000 non-null float64
# dtypes: float64(13), int64(4), object(16)
# memory usage: 265.6+ KB

# %% [markdown]
# # Preprocessing:  Data Types
#
#
# Types are inferred, but this may not be what you expect.  Go beyond either categorical or numerical data type:
#
# * decide how to encode the data
# * performance : Avoid OneHot for high cardinality columns and decision tree-based algorithms.
# * algorithm restrictions
#
#
# Rule of Thumb:
#
# https://towardsdatascience.com/7-data-types-a-better-way-to-think-about-data-types-for-machine-learning-939fae99a689

# %% [markdown]
# ## Assign Data Types

# %%
# assign data types
description = pd.read_excel('data/HomeCredit_columns_description.xlsx', sheet_name='Sheet1',usecols=[2,3,4])
description.head()
# Out:
#                Table                 Row         Type
# 0  application_train          SK_ID_CURR    numerical
# 1  application_train              TARGET  categorical
# 2  application_train  NAME_CONTRACT_TYPE  categorical
# 3  application_train         CODE_GENDER  categorical
# 4  application_train        FLAG_OWN_CAR  categorical

# %%
# rename to python types
python_cat_dtype = 'object'
python_num_dtype = 'float64'

description.replace('categorical', python_cat_dtype, inplace=True)
description.replace('numerical', python_num_dtype, inplace=True)

# type cols
typecols = description[(description.Table == table)]
typecols.head()
# Out:
#                     Table                 Row     Type
# 173  previous_application         SK_ID_PREV   float64
# 174  previous_application          SK_ID_CURR  float64
# 175  previous_application  NAME_CONTRACT_TYPE   object
# 176  previous_application         AMT_ANNUITY  float64
# 177  previous_application     AMT_APPLICATION  float64

# %%
# get target columns 
targetcols = pd.DataFrame(df.columns, columns=['Row'])
targetcols.head()
# Out:
#                   Row
# 0  NAME_CONTRACT_TYPE
# 1         AMT_ANNUITY
# 2     AMT_APPLICATION
# 3          AMT_CREDIT
# 4    AMT_DOWN_PAYMENT

# %%
# join , ensure col correct -  we dont know which cols are present in the description
targetcols = targetcols.merge(typecols, how='left')
targetcols.head()
# Out:
#                   Row                 Table     Type
# 0  NAME_CONTRACT_TYPE  previous_application   object
# 1         AMT_ANNUITY  previous_application  float64
# 2     AMT_APPLICATION  previous_application  float64
# 3          AMT_CREDIT  previous_application  float64
# 4    AMT_DOWN_PAYMENT  previous_application  float64

# %%
# retrieve all columns of same type 
cat = targetcols.loc[(targetcols.Type == python_cat_dtype),'Row'].values.tolist()
num = targetcols.loc[(targetcols.Type == python_num_dtype),'Row'].values.tolist()

print(cat)
#print(num)
#print(len(cat) + len(num))
# Out:
# ['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION', 'NFLAG_INSURED_ON_APPROVAL']

# %%
## batch update types 
df[cat] = df[cat].astype(python_cat_dtype)
df[num] = df[num].astype(python_num_dtype)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 929166 to 1290315
# Data columns (total 33 columns):
# NAME_CONTRACT_TYPE             1000 non-null object
# AMT_ANNUITY                    1000 non-null float64
# AMT_APPLICATION                1000 non-null float64
# AMT_CREDIT                     1000 non-null float64
# AMT_DOWN_PAYMENT               1000 non-null float64
# AMT_GOODS_PRICE                1000 non-null float64
# WEEKDAY_APPR_PROCESS_START     1000 non-null object
# HOUR_APPR_PROCESS_START        1000 non-null float64
# FLAG_LAST_APPL_PER_CONTRACT    1000 non-null object
# NFLAG_LAST_APPL_IN_DAY         1000 non-null object
# RATE_DOWN_PAYMENT              1000 non-null float64
# NAME_CASH_LOAN_PURPOSE         1000 non-null object
# NAME_CONTRACT_STATUS           1000 non-null object
# DAYS_DECISION                  1000 non-null float64
# NAME_PAYMENT_TYPE              1000 non-null object
# CODE_REJECT_REASON             1000 non-null object
# NAME_TYPE_SUITE                1000 non-null object
# NAME_CLIENT_TYPE               1000 non-null object
# NAME_GOODS_CATEGORY            1000 non-null object
# NAME_PORTFOLIO                 1000 non-null object
# NAME_PRODUCT_TYPE              1000 non-null object
# CHANNEL_TYPE                   1000 non-null object
# SELLERPLACE_AREA               1000 non-null object
# NAME_SELLER_INDUSTRY           1000 non-null object
# CNT_PAYMENT                    1000 non-null float64
# NAME_YIELD_GROUP               1000 non-null object
# PRODUCT_COMBINATION            1000 non-null object
# DAYS_FIRST_DRAWING             1000 non-null float64
# DAYS_FIRST_DUE                 1000 non-null float64
# DAYS_LAST_DUE_1ST_VERSION      1000 non-null float64
# DAYS_LAST_DUE                  1000 non-null float64
# DAYS_TERMINATION               1000 non-null float64
# NFLAG_INSURED_ON_APPROVAL      1000 non-null object
# dtypes: float64(14), object(19)
# memory usage: 265.6+ KB

# %% [markdown]
# ## Encode Categorical
#
# * Article : Exploring Category Encoders
# *  https://towardsdatascience.com/smarter-ways-to-encode-categorical-data-for-machine-learning-part-1-of-3-6dca2f71b159
# * Category Encoders Package http://contrib.scikit-learn.org/categorical-encoding/index.html
#
# Take home message: categoricals should look like strings and not numbers . preprocessing feature should be done: example hours are categorical but look like numbers
#
# * boolean flags that are integers
# * HOUR_APPR_PROCESS_START : Hour of day => made it numerical (ordinal)
# * NFLAG_LAST_APPL_IN_DAY : (0,1) one hot encoded
# * SELLERPLACE_AREA : 2097 instances : numeric code represents categorical ***
# * NFLAG_INSURED_ON_APPROVAL : (0,1)
# * validate nominals : avoid different strings mean the same concept
#
#
# __Below User defined encoding : allows me to reverse encoding, hash sequence of integers to a string_

# %%
prefix = 's_'
df['NFLAG_LAST_APPL_IN_DAY'] =  prefix + df['NFLAG_LAST_APPL_IN_DAY'].astype(str) 
df['SELLERPLACE_AREA'] = prefix + df['SELLERPLACE_AREA'].astype(str) 
df['NFLAG_INSURED_ON_APPROVAL'] = prefix +  df['NFLAG_INSURED_ON_APPROVAL'].astype(str)

# %% [markdown]
# # Train Model

# %%
#%%time
# select a portion of the data for evaluation
df_train, df_test = datawig.utils.random_split(df)

output_column = 'PRODUCT_COMBINATION'
output_path = 'imputer_model'
lst = [*df.columns.values]
lst.remove(output_column)
input_cols = lst


# Initialize a SimpleImputer model
imputer = datawig.SimpleImputer(
    input_columns=lst,  # columns containing information about the column we want to impute
    output_column=output_column,  # the column we'd like to impute values for
    output_path=output_path  # stores model data and metrics
)

# Fit an imputer model with default list of hyperparameters
imputer.fit_hpo(train_df=df_train)
# Out:
# 2019-05-01 19:50:04,123 [INFO]  Assuming 14 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, HOUR_APPR_PROCESS_START, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-01 19:50:04,124 [INFO]  Assuming 18 string input columns: NAME_CONTRACT_TYPE, NAME_PAYMENT_TYPE, NAME_CLIENT_TYPE, NAME_SELLER_INDUSTRY, NAME_TYPE_SUITE, NAME_GOODS_CATEGORY, NFLAG_INSURED_ON_APPROVAL, NAME_PORTFOLIO, SELLERPLACE_AREA, NAME_PRODUCT_TYPE, CODE_REJECT_REASON, NFLAG_LAST_APPL_IN_DAY, NAME_CONTRACT_STATUS, WEEKDAY_APPR_PROCESS_START, NAME_YIELD_GROUP, CHANNEL_TYPE, FLAG_LAST_APPL_PER_CONTRACT, NAME_CASH_LOAN_PURPOSE
# 2019-05-01 19:50:04,126 [INFO]  Assuming 14 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, HOUR_APPR_PROCESS_START, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-01 19:50:04,128 [INFO]  Assuming 18 string input columns: NAME_CONTRACT_TYPE, NAME_PAYMENT_TYPE, NAME_CLIENT_TYPE, NAME_SELLER_INDUSTRY, NAME_TYPE_SUITE, NAME_GOODS_CATEGORY, NFLAG_INSURED_ON_APPROVAL, NAME_PORTFOLIO, SELLERPLACE_AREA, NAME_PRODUCT_TYPE, CODE_REJECT_REASON, NFLAG_LAST_APPL_IN_DAY, NAME_CONTRACT_STATUS, WEEKDAY_APPR_PROCESS_START, NAME_YIELD_GROUP, CHANNEL_TYPE, FLAG_LAST_APPL_PER_CONTRACT, NAME_CASH_LOAN_PURPOSE
# 2019-05-01 19:50:04,153 [INFO]  Training starts for 1hyperparameter configurations.
# 2019-05-01 19:50:04,158 [INFO]  Fitting hpo iteration 0 with parameters
# 	global:batch_size: 16
# 	global:learning_rate: 0.004
# 	global:weight_decay: 0
# 	global:num_epochs: 25
# 	global:patience: 3
# 	global:final_fc_hidden_units: []
# 	NAME_CONTRACT_TYPE:type: string
# 	NAME_CONTRACT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_TYPE:max_tokens: 32768
# 	NAME_CONTRACT_TYPE:tokens: ['chars']
# 	AMT_ANNUITY:type: numeric
# 	AMT_ANNUITY:normalize: True
# 	AMT_ANNUITY:numeric_latent_dim: 10
# 	AMT_ANNUITY:numeric_hidden_layers: 1
# 	AMT_APPLICATION:type: numeric
# 	AMT_APPLICATION:normalize: True
# 	AMT_APPLICATION:numeric_latent_dim: 10
# 	AMT_APPLICATION:numeric_hidden_layers: 1
# 	AMT_CREDIT:type: numeric
# 	AMT_CREDIT:normalize: True
# 	AMT_CREDIT:numeric_latent_dim: 10
# 	AMT_CREDIT:numeric_hidden_layers: 1
# 	AMT_DOWN_PAYMENT:type: numeric
# 	AMT_DOWN_PAYMENT:normalize: True
# 	AMT_DOWN_PAYMENT:numeric_latent_dim: 10
# 	AMT_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	AMT_GOODS_PRICE:type: numeric
# 	AMT_GOODS_PRICE:normalize: True
# 	AMT_GOODS_PRICE:numeric_latent_dim: 10
# 	AMT_GOODS_PRICE:numeric_hidden_layers: 1
# 	WEEKDAY_APPR_PROCESS_START:type: string
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:words: (1, 3)
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:chars: (1, 5)
# 	WEEKDAY_APPR_PROCESS_START:max_tokens: 32768
# 	WEEKDAY_APPR_PROCESS_START:tokens: ['chars']
# 	HOUR_APPR_PROCESS_START:type: numeric
# 	HOUR_APPR_PROCESS_START:normalize: True
# 	HOUR_APPR_PROCESS_START:numeric_latent_dim: 10
# 	HOUR_APPR_PROCESS_START:numeric_hidden_layers: 1
# 	FLAG_LAST_APPL_PER_CONTRACT:type: string
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:words: (1, 3)
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:chars: (1, 5)
# 	FLAG_LAST_APPL_PER_CONTRACT:max_tokens: 32768
# 	FLAG_LAST_APPL_PER_CONTRACT:tokens: ['chars']
# 	NFLAG_LAST_APPL_IN_DAY:type: string
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:words: (1, 3)
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:chars: (1, 5)
# 	NFLAG_LAST_APPL_IN_DAY:max_tokens: 32768
# 	NFLAG_LAST_APPL_IN_DAY:tokens: ['chars']
# 	RATE_DOWN_PAYMENT:type: numeric
# 	RATE_DOWN_PAYMENT:normalize: True
# 	RATE_DOWN_PAYMENT:numeric_latent_dim: 10
# 	RATE_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	NAME_CASH_LOAN_PURPOSE:type: string
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:words: (1, 3)
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:chars: (1, 5)
# 	NAME_CASH_LOAN_PURPOSE:max_tokens: 32768
# 	NAME_CASH_LOAN_PURPOSE:tokens: ['chars']
# 	NAME_CONTRACT_STATUS:type: string
# 	NAME_CONTRACT_STATUS:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_STATUS:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_STATUS:max_tokens: 32768
# 	NAME_CONTRACT_STATUS:tokens: ['chars']
# 	DAYS_DECISION:type: numeric
# 	DAYS_DECISION:normalize: True
# 	DAYS_DECISION:numeric_latent_dim: 10
# 	DAYS_DECISION:numeric_hidden_layers: 1
# 	NAME_PAYMENT_TYPE:type: string
# 	NAME_PAYMENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PAYMENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PAYMENT_TYPE:max_tokens: 32768
# 	NAME_PAYMENT_TYPE:tokens: ['chars']
# 	CODE_REJECT_REASON:type: string
# 	CODE_REJECT_REASON:ngram_range:words: (1, 3)
# 	CODE_REJECT_REASON:ngram_range:chars: (1, 5)
# 	CODE_REJECT_REASON:max_tokens: 32768
# 	CODE_REJECT_REASON:tokens: ['chars']
# 	NAME_TYPE_SUITE:type: string
# 	NAME_TYPE_SUITE:ngram_range:words: (1, 3)
# 	NAME_TYPE_SUITE:ngram_range:chars: (1, 5)
# 	NAME_TYPE_SUITE:max_tokens: 32768
# 	NAME_TYPE_SUITE:tokens: ['chars']
# 	NAME_CLIENT_TYPE:type: string
# 	NAME_CLIENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CLIENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CLIENT_TYPE:max_tokens: 32768
# 	NAME_CLIENT_TYPE:tokens: ['chars']
# 	NAME_GOODS_CATEGORY:type: string
# 	NAME_GOODS_CATEGORY:ngram_range:words: (1, 3)
# 	NAME_GOODS_CATEGORY:ngram_range:chars: (1, 5)
# 	NAME_GOODS_CATEGORY:max_tokens: 32768
# 	NAME_GOODS_CATEGORY:tokens: ['chars']
# 	NAME_PORTFOLIO:type: string
# 	NAME_PORTFOLIO:ngram_range:words: (1, 3)
# 	NAME_PORTFOLIO:ngram_range:chars: (1, 5)
# 	NAME_PORTFOLIO:max_tokens: 32768
# 	NAME_PORTFOLIO:tokens: ['chars']
# 	NAME_PRODUCT_TYPE:type: string
# 	NAME_PRODUCT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PRODUCT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PRODUCT_TYPE:max_tokens: 32768
# 	NAME_PRODUCT_TYPE:tokens: ['chars']
# 	CHANNEL_TYPE:type: string
# 	CHANNEL_TYPE:ngram_range:words: (1, 3)
# 	CHANNEL_TYPE:ngram_range:chars: (1, 5)
# 	CHANNEL_TYPE:max_tokens: 32768
# 	CHANNEL_TYPE:tokens: ['chars']
# 	SELLERPLACE_AREA:type: string
# 	SELLERPLACE_AREA:ngram_range:words: (1, 3)
# 	SELLERPLACE_AREA:ngram_range:chars: (1, 5)
# 	SELLERPLACE_AREA:max_tokens: 32768
# 	SELLERPLACE_AREA:tokens: ['chars']
# 	NAME_SELLER_INDUSTRY:type: string
# 	NAME_SELLER_INDUSTRY:ngram_range:words: (1, 3)
# 	NAME_SELLER_INDUSTRY:ngram_range:chars: (1, 5)
# 	NAME_SELLER_INDUSTRY:max_tokens: 32768
# 	NAME_SELLER_INDUSTRY:tokens: ['chars']
# 	CNT_PAYMENT:type: numeric
# 	CNT_PAYMENT:normalize: True
# 	CNT_PAYMENT:numeric_latent_dim: 10
# 	CNT_PAYMENT:numeric_hidden_layers: 1
# 	NAME_YIELD_GROUP:type: string
# 	NAME_YIELD_GROUP:ngram_range:words: (1, 3)
# 	NAME_YIELD_GROUP:ngram_range:chars: (1, 5)
# 	NAME_YIELD_GROUP:max_tokens: 32768
# 	NAME_YIELD_GROUP:tokens: ['chars']
# 	DAYS_FIRST_DRAWING:type: numeric
# 	DAYS_FIRST_DRAWING:normalize: True
# 	DAYS_FIRST_DRAWING:numeric_latent_dim: 10
# 	DAYS_FIRST_DRAWING:numeric_hidden_layers: 1
# 	DAYS_FIRST_DUE:type: numeric
# 	DAYS_FIRST_DUE:normalize: True
# 	DAYS_FIRST_DUE:numeric_latent_dim: 10
# 	DAYS_FIRST_DUE:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE_1ST_VERSION:type: numeric
# 	DAYS_LAST_DUE_1ST_VERSION:normalize: True
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_latent_dim: 10
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE:type: numeric
# 	DAYS_LAST_DUE:normalize: True
# 	DAYS_LAST_DUE:numeric_latent_dim: 10
# 	DAYS_LAST_DUE:numeric_hidden_layers: 1
# 	DAYS_TERMINATION:type: numeric
# 	DAYS_TERMINATION:normalize: True
# 	DAYS_TERMINATION:numeric_latent_dim: 10
# 	DAYS_TERMINATION:numeric_hidden_layers: 1
# 	NFLAG_INSURED_ON_APPROVAL:type: string
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:words: (1, 3)
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:chars: (1, 5)
# 	NFLAG_INSURED_ON_APPROVAL:max_tokens: 32768
# 	NFLAG_INSURED_ON_APPROVAL:tokens: ['chars']
# 2019-05-01 19:50:04,171 [INFO]  No output column name provided for ColumnEncoder using PRODUCT_COMBINATION
# 2019-05-01 19:50:04,172 [INFO]  Assuming categorical output column: PRODUCT_COMBINATION
# 2019-05-01 19:50:04,178 [INFO]  Using [[cpu(0)]] as the context for training
# 2019-05-01 19:50:04,180 [INFO]  Fitting label encoder <class 'datawig.column_encoders.CategoricalEncoder'> on 640 rows                             of training data
# 2019-05-01 19:50:04,189 [INFO]  12 most often encountered discrete values:                      ['POS household with interest' 'POS mobile with interest'
#  'POS industry with interest' 'POS household without interest'
#  'Cash Street: high' 'POS other with interest' 'Cash X-Sell: high'
#  'POS industry without interest' 'Cash X-Sell: middle'
#  'POS mobile without interest' 'Cash Street: middle' 'Cash X-Sell: low']
# 2019-05-01 19:50:04,191 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 96 occurrences of value POS industry with interest
# 2019-05-01 19:50:04,195 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 79 occurrences of value POS household without interest
# 2019-05-01 19:50:04,197 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 19 occurrences of value Cash Street: high
# 2019-05-01 19:50:04,199 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 17 occurrences of value POS other with interest
# 2019-05-01 19:50:04,203 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 10 occurrences of value Cash X-Sell: high
# 2019-05-01 19:50:04,204 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 6 occurrences of value POS industry without interest
# 2019-05-01 19:50:04,206 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 4 occurrences of value Cash X-Sell: middle
# 2019-05-01 19:50:04,207 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value POS mobile without interest
# 2019-05-01 19:50:04,208 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value Cash Street: middle
# 2019-05-01 19:50:04,210 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 2 occurrences of value Cash X-Sell: low
# 2019-05-01 19:50:04,213 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 19:50:04,215 [INFO]  Dropping 0/640 rows
# 2019-05-01 19:50:04,220 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 19:50:04,222 [INFO]  Dropping 0/160 rows
# 2019-05-01 19:50:04,225 [INFO]  Train: 640, Test: 160
# 2019-05-01 19:50:04,226 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_ANNUITY and 640 rows of training data with parameters {'input_columns': ['AMT_ANNUITY'], 'output_column': 'AMT_ANNUITY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,234 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_APPLICATION and 640 rows of training data with parameters {'input_columns': ['AMT_APPLICATION'], 'output_column': 'AMT_APPLICATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,240 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_CREDIT and 640 rows of training data with parameters {'input_columns': ['AMT_CREDIT'], 'output_column': 'AMT_CREDIT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,247 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['AMT_DOWN_PAYMENT'], 'output_column': 'AMT_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,254 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_GOODS_PRICE and 640 rows of training data with parameters {'input_columns': ['AMT_GOODS_PRICE'], 'output_column': 'AMT_GOODS_PRICE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,268 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns HOUR_APPR_PROCESS_START and 640 rows of training data with parameters {'input_columns': ['HOUR_APPR_PROCESS_START'], 'output_column': 'HOUR_APPR_PROCESS_START_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,275 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['RATE_DOWN_PAYMENT'], 'output_column': 'RATE_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,281 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_DECISION and 640 rows of training data with parameters {'input_columns': ['DAYS_DECISION'], 'output_column': 'DAYS_DECISION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,292 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns CNT_PAYMENT and 640 rows of training data with parameters {'input_columns': ['CNT_PAYMENT'], 'output_column': 'CNT_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,302 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DRAWING and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DRAWING'], 'output_column': 'DAYS_FIRST_DRAWING_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,313 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DUE'], 'output_column': 'DAYS_FIRST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,322 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE_1ST_VERSION and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE_1ST_VERSION'], 'output_column': 'DAYS_LAST_DUE_1ST_VERSION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,330 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE'], 'output_column': 'DAYS_LAST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,340 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_TERMINATION and 640 rows of training data with parameters {'input_columns': ['DAYS_TERMINATION'], 'output_column': 'DAYS_TERMINATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 19:50:04,347 [INFO]  Building Train Iterator with 640 elements
# 2019-05-01 19:50:04,405 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,409 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:50:04,410 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,414 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,418 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:50:04,420 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,423 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,427 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:50:04,429 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,435 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,440 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:50:04,441 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,447 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,452 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:50:04,454 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,459 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,478 [INFO]  Data Encoding - Encoded 640 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,486 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:50:04,487 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,490 [INFO]  Data Encoding - Encoded 640 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,497 [INFO]  Data Encoding - Encoded 640 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,506 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,512 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:50:04,513 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,521 [INFO]  Data Encoding - Encoded 640 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,532 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,556 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,562 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:50:04,563 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,568 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,611 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,619 [INFO]  Data Encoding - Encoded 640 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,641 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,656 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,686 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,694 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,704 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,733 [INFO]  Data Encoding - Encoded 640 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,747 [INFO]  Data Encoding - Encoded 640 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,785 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,791 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:50:04,792 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,797 [INFO]  Data Encoding - Encoded 640 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,814 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,821 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:50:04,822 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,828 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,834 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:50:04,835 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,841 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,849 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:50:04,850 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,858 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,863 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:50:04,865 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,870 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,876 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:50:04,877 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,881 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:50:04,908 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:50:04,910 [INFO]  CategoricalEncoder encoding 640 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:50:04,920 [INFO]  Label Encoding - Encoded 640 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (640, 1) and                             then into shape (640, 1)
# 2019-05-01 19:50:04,923 [INFO]  Building Test Iterator with 160 elements
# 2019-05-01 19:50:04,974 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:04,980 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:50:04,982 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:04,989 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:04,995 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:50:04,998 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,003 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,011 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:50:05,012 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,020 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,026 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:50:05,028 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,033 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,043 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:50:05,045 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,049 [INFO]  Data Encoding - Encoded 160 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,059 [INFO]  Data Encoding - Encoded 160 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,069 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:50:05,071 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,077 [INFO]  Data Encoding - Encoded 160 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,083 [INFO]  Data Encoding - Encoded 160 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,092 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,100 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:50:05,103 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,107 [INFO]  Data Encoding - Encoded 160 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,113 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,125 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,132 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:50:05,136 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,140 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,164 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,171 [INFO]  Data Encoding - Encoded 160 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,186 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,197 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,214 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,223 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,231 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,247 [INFO]  Data Encoding - Encoded 160 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,256 [INFO]  Data Encoding - Encoded 160 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,275 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,284 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:50:05,286 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,291 [INFO]  Data Encoding - Encoded 160 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,303 [INFO]  Data Encoding - Encoded 160 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,309 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:50:05,312 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,317 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,326 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:50:05,327 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,332 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,341 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:50:05,343 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,349 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,360 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:50:05,364 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,376 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,388 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:50:05,390 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:50:05,395 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:50:05,407 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:50:05,409 [INFO]  CategoricalEncoder encoding 160 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:50:05,421 [INFO]  Label Encoding - Encoded 160 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (160, 1) and                             then into shape (160, 1)
# 2019-05-01 19:50:05,426 [WARNING]  Test set does not contain any ocurrences of values [Cash X-Sell: low] in column [PRODUCT_COMBINATION], consider using a more representative test set.
# 2019-05-01 19:50:05,427 [INFO]  Concatenating all 32 latent symbols
# 2019-05-01 19:50:05,431 [INFO]  Constructing categorical loss for column PRODUCT_COMBINATION and 12 labels
# 2019-05-01 19:50:05,433 [INFO]  Building output of label <Symbol PRODUCT_COMBINATION> with 13 classes                      (including missing class)
# 2019-05-01 19:50:05,437 [INFO]  Building output symbols
# 2019-05-01 19:50:05,455 [INFO]
# ========== start: fit model
# 2019-05-01 19:50:05,457 [WARNING]  Already bound, ignoring bind()
# 2019-05-01 19:50:09,819 [INFO]  Epoch[0] Batch [0-20]	Speed: 82.58 samples/sec	cross-entropy=1.261772	PRODUCT_COMBINATION-accuracy=0.583333
# 2019-05-01 19:50:13,403 [INFO]  Epoch[0] Train-cross-entropy=0.984583
# 2019-05-01 19:50:13,404 [INFO]  Epoch[0] Train-PRODUCT_COMBINATION-accuracy=0.678125
# 2019-05-01 19:50:13,405 [INFO]  Epoch[0] Time cost=7.934
# 2019-05-01 19:50:13,648 [INFO]  Saved checkpoint to "imputer_model0/model-0000.params"
# 2019-05-01 19:50:14,937 [INFO]  Epoch[0] Validation-cross-entropy=0.590729
# 2019-05-01 19:50:14,938 [INFO]  Epoch[0] Validation-PRODUCT_COMBINATION-accuracy=0.837500
# 2019-05-01 19:50:19,050 [INFO]  Epoch[1] Batch [0-20]	Speed: 81.68 samples/sec	cross-entropy=0.419733	PRODUCT_COMBINATION-accuracy=0.869048
# 2019-05-01 19:50:22,610 [INFO]  Epoch[1] Train-cross-entropy=0.395694
# 2019-05-01 19:50:22,611 [INFO]  Epoch[1] Train-PRODUCT_COMBINATION-accuracy=0.884375
# 2019-05-01 19:50:22,612 [INFO]  Epoch[1] Time cost=7.673
# 2019-05-01 19:50:22,822 [INFO]  Saved checkpoint to "imputer_model0/model-0001.params"
# 2019-05-01 19:50:24,088 [INFO]  Epoch[1] Validation-cross-entropy=0.376982
# 2019-05-01 19:50:24,089 [INFO]  Epoch[1] Validation-PRODUCT_COMBINATION-accuracy=0.893750
# 2019-05-01 19:50:28,576 [INFO]  Epoch[2] Batch [0-20]	Speed: 74.58 samples/sec	cross-entropy=0.269836	PRODUCT_COMBINATION-accuracy=0.913690
# 2019-05-01 19:50:32,285 [INFO]  Epoch[2] Train-cross-entropy=0.267197
# 2019-05-01 19:50:32,289 [INFO]  Epoch[2] Train-PRODUCT_COMBINATION-accuracy=0.918750
# 2019-05-01 19:50:32,290 [INFO]  Epoch[2] Time cost=8.200
# 2019-05-01 19:50:32,502 [INFO]  Saved checkpoint to "imputer_model0/model-0002.params"
# 2019-05-01 19:50:33,810 [INFO]  Epoch[2] Validation-cross-entropy=0.311181
# 2019-05-01 19:50:33,811 [INFO]  Epoch[2] Validation-PRODUCT_COMBINATION-accuracy=0.906250
# 2019-05-01 19:50:37,933 [INFO]  Epoch[3] Batch [0-20]	Speed: 81.55 samples/sec	cross-entropy=0.202757	PRODUCT_COMBINATION-accuracy=0.946429
# 2019-05-01 19:50:41,539 [INFO]  Epoch[3] Train-cross-entropy=0.204664
# 2019-05-01 19:50:41,540 [INFO]  Epoch[3] Train-PRODUCT_COMBINATION-accuracy=0.950000
# 2019-05-01 19:50:41,541 [INFO]  Epoch[3] Time cost=7.728
# 2019-05-01 19:50:41,760 [INFO]  Saved checkpoint to "imputer_model0/model-0003.params"
# 2019-05-01 19:50:43,058 [INFO]  Epoch[3] Validation-cross-entropy=0.279452
# 2019-05-01 19:50:43,059 [INFO]  Epoch[3] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:50:47,185 [INFO]  Epoch[4] Batch [0-20]	Speed: 81.57 samples/sec	cross-entropy=0.161985	PRODUCT_COMBINATION-accuracy=0.961310
# 2019-05-01 19:50:50,755 [INFO]  Epoch[4] Train-cross-entropy=0.165588
# 2019-05-01 19:50:50,756 [INFO]  Epoch[4] Train-PRODUCT_COMBINATION-accuracy=0.967187
# 2019-05-01 19:50:50,757 [INFO]  Epoch[4] Time cost=7.697
# 2019-05-01 19:50:50,983 [INFO]  Saved checkpoint to "imputer_model0/model-0004.params"
# 2019-05-01 19:50:52,295 [INFO]  Epoch[4] Validation-cross-entropy=0.263425
# 2019-05-01 19:50:52,297 [INFO]  Epoch[4] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:50:56,259 [INFO]  Epoch[5] Batch [0-20]	Speed: 85.24 samples/sec	cross-entropy=0.134395	PRODUCT_COMBINATION-accuracy=0.961310
# 2019-05-01 19:50:59,888 [INFO]  Epoch[5] Train-cross-entropy=0.138708
# 2019-05-01 19:50:59,889 [INFO]  Epoch[5] Train-PRODUCT_COMBINATION-accuracy=0.968750
# 2019-05-01 19:50:59,891 [INFO]  Epoch[5] Time cost=7.593
# 2019-05-01 19:51:00,100 [INFO]  Saved checkpoint to "imputer_model0/model-0005.params"
# 2019-05-01 19:51:01,395 [INFO]  Epoch[5] Validation-cross-entropy=0.254152
# 2019-05-01 19:51:01,401 [INFO]  Epoch[5] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:51:05,330 [INFO]  Epoch[6] Batch [0-20]	Speed: 85.64 samples/sec	cross-entropy=0.114752	PRODUCT_COMBINATION-accuracy=0.970238
# 2019-05-01 19:51:09,109 [INFO]  Epoch[6] Train-cross-entropy=0.119314
# 2019-05-01 19:51:09,110 [INFO]  Epoch[6] Train-PRODUCT_COMBINATION-accuracy=0.973437
# 2019-05-01 19:51:09,111 [INFO]  Epoch[6] Time cost=7.709
# 2019-05-01 19:51:09,368 [INFO]  Saved checkpoint to "imputer_model0/model-0006.params"
# 2019-05-01 19:51:10,668 [INFO]  Epoch[6] Validation-cross-entropy=0.248702
# 2019-05-01 19:51:10,669 [INFO]  Epoch[6] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:51:14,596 [INFO]  Epoch[7] Batch [0-20]	Speed: 85.87 samples/sec	cross-entropy=0.099959	PRODUCT_COMBINATION-accuracy=0.979167
# 2019-05-01 19:51:18,244 [INFO]  Epoch[7] Train-cross-entropy=0.104631
# 2019-05-01 19:51:18,246 [INFO]  Epoch[7] Train-PRODUCT_COMBINATION-accuracy=0.981250
# 2019-05-01 19:51:18,247 [INFO]  Epoch[7] Time cost=7.576
# 2019-05-01 19:51:18,446 [INFO]  Saved checkpoint to "imputer_model0/model-0007.params"
# 2019-05-01 19:51:19,748 [INFO]  Epoch[7] Validation-cross-entropy=0.246153
# 2019-05-01 19:51:19,749 [INFO]  Epoch[7] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:51:23,706 [INFO]  Epoch[8] Batch [0-20]	Speed: 85.42 samples/sec	cross-entropy=0.088322	PRODUCT_COMBINATION-accuracy=0.982143
# 2019-05-01 19:51:27,300 [INFO]  Epoch[8] Train-cross-entropy=0.093123
# 2019-05-01 19:51:27,301 [INFO]  Epoch[8] Train-PRODUCT_COMBINATION-accuracy=0.985938
# 2019-05-01 19:51:27,302 [INFO]  Epoch[8] Time cost=7.552
# 2019-05-01 19:51:27,452 [INFO]  Saved checkpoint to "imputer_model0/model-0008.params"
# 2019-05-01 19:51:28,850 [INFO]  Epoch[8] Validation-cross-entropy=0.245662
# 2019-05-01 19:51:28,851 [INFO]  Epoch[8] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:51:33,802 [INFO]  Epoch[9] Batch [0-20]	Speed: 67.90 samples/sec	cross-entropy=0.078932	PRODUCT_COMBINATION-accuracy=0.982143
# 2019-05-01 19:51:38,785 [INFO]  Epoch[9] Train-cross-entropy=0.083878
# 2019-05-01 19:51:38,786 [INFO]  Epoch[9] Train-PRODUCT_COMBINATION-accuracy=0.985938
# 2019-05-01 19:51:38,787 [INFO]  Epoch[9] Time cost=9.935
# 2019-05-01 19:51:39,003 [INFO]  Saved checkpoint to "imputer_model0/model-0009.params"
# 2019-05-01 19:51:40,286 [INFO]  Epoch[9] Validation-cross-entropy=0.246492
# 2019-05-01 19:51:40,287 [INFO]  Epoch[9] Validation-PRODUCT_COMBINATION-accuracy=0.925000
# 2019-05-01 19:51:44,467 [INFO]  Epoch[10] Batch [0-20]	Speed: 80.38 samples/sec	cross-entropy=0.071231	PRODUCT_COMBINATION-accuracy=0.982143
# 2019-05-01 19:51:48,031 [INFO]  Epoch[10] Train-cross-entropy=0.076310
# 2019-05-01 19:51:48,032 [INFO]  Epoch[10] Train-PRODUCT_COMBINATION-accuracy=0.987500
# 2019-05-01 19:51:48,033 [INFO]  Epoch[10] Time cost=7.745
# 2019-05-01 19:51:48,233 [INFO]  Saved checkpoint to "imputer_model0/model-0010.params"
# 2019-05-01 19:51:49,661 [INFO]  No improvement detected for 3 epochs compared to 0.2461525909602642 last error obtained: 0.2482275538146496, stopping here
# ...
# 2019-05-01 19:51:54,385 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:51:54,387 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:54,393 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:51:54,396 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:51:54,399 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:54,406 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:51:54,411 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:51:54,412 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:54,416 [INFO]  Data Encoding - Encoded 160 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (160, 1)                         and then into shape (160, 1)
# 2019-05-01 19:51:54,424 [INFO]  Data Encoding - Encoded 160 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (160, 32768)                         and then into shape (160, 32768)
# 2019-05-01 19:51:54,426 [INFO]  CategoricalEncoder encoding 160 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:51:54,431 [INFO]  Label Encoding - Encoded 160 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (160, 1) and                             then into shape (160, 1)
# 2019-05-01 19:51:55,778 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:55,783 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:51:55,785 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,788 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,792 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:51:55,794 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,798 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,805 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:51:55,806 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,811 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,816 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:51:55,817 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,822 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,829 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:51:55,830 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,833 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,852 [INFO]  Data Encoding - Encoded 640 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:55,858 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:51:55,860 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,863 [INFO]  Data Encoding - Encoded 640 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,870 [INFO]  Data Encoding - Encoded 640 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:55,880 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:55,887 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:51:55,888 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,893 [INFO]  Data Encoding - Encoded 640 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,909 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:55,947 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:55,952 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:51:55,953 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:55,957 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:55,998 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,006 [INFO]  Data Encoding - Encoded 640 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,033 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,046 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,076 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,084 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,095 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,124 [INFO]  Data Encoding - Encoded 640 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,136 [INFO]  Data Encoding - Encoded 640 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,170 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,176 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:51:56,177 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:56,181 [INFO]  Data Encoding - Encoded 640 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:56,195 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,200 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:51:56,201 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:56,204 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:56,210 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:51:56,213 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:56,217 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:56,221 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:51:56,223 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:56,227 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:56,234 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:51:56,236 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:56,242 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:56,249 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:51:56,259 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:51:56,266 [INFO]  Data Encoding - Encoded 640 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 19:51:56,289 [INFO]  Data Encoding - Encoded 640 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 19:51:56,290 [INFO]  CategoricalEncoder encoding 640 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:51:56,303 [INFO]  Label Encoding - Encoded 640 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (640, 1) and                             then into shape (640, 1)
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 2019-05-01 19:52:01,440 [INFO]  Finished hpo iteration 0
# 2019-05-01 19:52:01,441 [INFO]  Assigning model with highest weighted precision to SimpleImputer object and copying artifacts.
# 2019-05-01 19:52:01,444 [INFO]  Selecting imputer with maximal weighted precision.
# 2019-05-01 19:52:01,518 [INFO]  Output path for loading Imputer imputer_model
# 2019-05-01 19:52:01,524 [INFO]  Loading mxnet model from imputer_model/model

# %% [markdown]
# # Evaluate Performance

# %%
# Impute missing values and return original dataframe with predictions
predictions = imputer.predict(df_test)

predictions.head()

# Calculate f1 score for true vs predicted values
f1 = f1_score(predictions[output_column], predictions[output_column+'_imputed'], average='weighted')

# Print overall classification report
print(classification_report(predictions[output_column], predictions[output_column+'_imputed']))
# Out:
# 2019-05-01 19:52:47,614 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,619 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 19:52:47,621 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,635 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,642 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 19:52:47,644 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,648 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,656 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 19:52:47,659 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,663 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,670 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 19:52:47,672 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,677 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,683 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 19:52:47,684 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,690 [INFO]  Data Encoding - Encoded 208 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,702 [INFO]  Data Encoding - Encoded 208 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,706 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 19:52:47,708 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,716 [INFO]  Data Encoding - Encoded 208 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,722 [INFO]  Data Encoding - Encoded 208 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,730 [INFO]  Data Encoding - Encoded 208 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,736 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 19:52:47,737 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,741 [INFO]  Data Encoding - Encoded 208 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,751 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,759 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,765 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 19:52:47,767 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,772 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,790 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,801 [INFO]  Data Encoding - Encoded 208 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,814 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,820 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,830 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,838 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,846 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,860 [INFO]  Data Encoding - Encoded 208 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,868 [INFO]  Data Encoding - Encoded 208 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,886 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,891 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 19:52:47,893 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,900 [INFO]  Data Encoding - Encoded 208 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,909 [INFO]  Data Encoding - Encoded 208 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,915 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 19:52:47,917 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,921 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,924 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 19:52:47,925 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,930 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,936 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 19:52:47,938 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,944 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,950 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 19:52:47,952 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,956 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,963 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 19:52:47,967 [INFO]  Normalizing with StandardScaler
# 2019-05-01 19:52:47,974 [INFO]  Data Encoding - Encoded 208 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (208, 1)                         and then into shape (208, 1)
# 2019-05-01 19:52:47,983 [INFO]  Data Encoding - Encoded 208 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (208, 32768)                         and then into shape (208, 32768)
# 2019-05-01 19:52:47,984 [INFO]  CategoricalEncoder encoding 208 rows with                     12 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 19:52:47,990 [INFO]  Label Encoding - Encoded 208 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (208, 1) and                             then into shape (208, 1)
#                                 precision    recall  f1-score   support
#
#              Cash Street: high       1.00      0.75      0.86         4
#              Cash X-Sell: high       0.89      1.00      0.94         8
#            Cash X-Sell: middle       1.00      1.00      1.00         1
#    POS household with interest       0.86      0.99      0.92        76
# POS household without interest       0.95      0.69      0.80        29
#     POS industry with interest       0.93      0.96      0.94        26
#       POS mobile with interest       0.96      0.98      0.97        49
#    POS mobile without interest       0.00      0.00      0.00         2
#        POS other with interest       1.00      0.40      0.57         5
#
#                      micro avg       0.91      0.91      0.91       200
#                      macro avg       0.84      0.75      0.78       200
#                   weighted avg       0.91      0.91      0.90       200
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
predictions.head()
# Out:
#         NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  \
# 265076      Consumer loans    16529.310         172332.0    141228.0
# 1529698     Consumer loans    10223.640          58455.0     57663.0
# 788943      Consumer loans    25204.815         129681.0    136530.0
# 69679       Consumer loans    15988.140         127782.0    125122.5
# 420487      Consumer loans     7208.460          58959.0     57438.0
#
#          AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 265076            44595.0         172332.0                     MONDAY
# 1529698            3510.0          58455.0                   SATURDAY
# 788943                0.0         129681.0                    TUESDAY
# 69679             12780.0         127782.0                   SATURDAY
# 420487             5899.5          58959.0                   SATURDAY
#
#          HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 265076                      10.0                           Y
# 1529698                     20.0                           Y
# 788943                      10.0                           Y
# 69679                       14.0                           Y
# 420487                       9.0                           Y
#
#         NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT NAME_CASH_LOAN_PURPOSE  \
# 265076                     s_1           0.261367                    XAP
# 1529698                    s_1           0.062490                    XAP
# 788943                     s_1           0.000000                    XAP
# 69679                      s_1           0.100931                    XAP
# 420487                     s_1           0.101442                    XAP
#
#         NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE  \
# 265076              Approved         -316.0  Cash through the bank
# 1529698             Approved        -2586.0  Cash through the bank
# 788943              Approved         -662.0  Cash through the bank
# 69679               Approved         -637.0                    XNA
# 420487              Approved        -2323.0  Cash through the bank
#
#         CODE_REJECT_REASON NAME_TYPE_SUITE NAME_CLIENT_TYPE  \
# 265076                 XAP   Unaccompanied              New
# 1529698                XAP          Family         Repeater
# 788943                 XAP   Unaccompanied        Refreshed
# 69679                  XAP   Unaccompanied         Repeater
# 420487                 XAP          Family         Repeater
#
#           NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  CHANNEL_TYPE  \
# 265076                 Mobile            POS               XNA  Country-wide
# 1529698           Audio/Video            POS               XNA  Country-wide
# 788943   Consumer Electronics            POS               XNA  Country-wide
# 69679                  Mobile            POS               XNA  Country-wide
# 420487            Audio/Video            POS               XNA         Stone
#
#         SELLERPLACE_AREA  NAME_SELLER_INDUSTRY  CNT_PAYMENT NAME_YIELD_GROUP  \
# 265076              s_36          Connectivity         12.0             high
# 1529698           s_2300  Consumer electronics          6.0       low_normal
# 788943            s_2000  Consumer electronics          6.0           middle
# 69679               s_50          Connectivity         10.0             high
# 420487             s_100              Industry         10.0             high
#
#                     PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  \
# 265076         POS mobile with interest            365243.0          -286.0
# 1529698  POS household without interest            365243.0         -2555.0
# 788943      POS household with interest            365243.0          -631.0
# 69679          POS mobile with interest            365243.0          -606.0
# 420487       POS industry with interest            365243.0         -2292.0
#
#          DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 265076                        44.0          -46.0             -44.0
# 1529698                    -2405.0        -2405.0           -2396.0
# 788943                      -481.0         -511.0            -503.0
# 69679                       -336.0         -576.0            -572.0
# 420487                     -2022.0        -2022.0           -2021.0
#
#         NFLAG_INSURED_ON_APPROVAL  PRODUCT_COMBINATION_imputed  \
# 265076                      s_1.0     POS mobile with interest
# 1529698                     s_1.0  POS household with interest
# 788943                      s_0.0  POS household with interest
# 69679                       s_0.0     POS mobile with interest
# 420487                      s_1.0  POS household with interest
#
#          PRODUCT_COMBINATION_imputed_proba
# 265076                            0.994247
# 1529698                           0.542133
# 788943                            0.993616
# 69679                             0.953899
# 420487                            0.480864

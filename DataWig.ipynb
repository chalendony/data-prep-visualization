# %% [markdown]
# # DataWig
#
# [Exploratory Data Analysis](https://en.wikipedia.org/wiki/Exploratory_data_analysis) (EDA) is an approach to analyzing data sets to summarize and understand their main characteristics, often with visual methods.
#
# Starting with your *Machine Learning Checklist* you will see that a crucial step is **preparing and understanding** the data. It is a step where you will spend most of your time.  Here is an example checklists from [Aurélien Géron](10_20_2018_Machine-Learning-Project-Checklist.txt) that you can adapt to your needs.
#
# In these series of notebooks, we explore the Home Credit data set. We clean, preprocess and visualize the data for downstream processes in the Data Science Workflow.  All notebooks can be obtained from Github : https://github.com/chalendony/data-prep-visualization

# %% [markdown]
# # Python Imports

# %%
# %config IPCompleter.greedy=True
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelBinarizer
pd.set_option('display.max_columns', 125)
import quilt
from scripts.preprocess import percent_missing, align_dataframes, as_dict
from string import Template
import missingno as msno
# %matplotlib inline
import impyute
import datawig

# %% [markdown]
# ## Import Quilt Packages from Local Repository

# %%
from quilt.data.avare import homecredit

# %%
# avoid parens and copy original data
table = 'previous_application'
df = homecredit[table]().copy(deep=True)
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 0                       15                           Y
# 1                       11                           Y
# 2                       11                           Y
# 3                        7                           Y
# 4                        9                           Y
#
#    NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 0                       1                0.0               0.182832
# 1                       1                NaN                    NaN
# 2                       1                NaN                    NaN
# 3                       1                NaN                    NaN
# 4                       1                NaN                    NaN
#
#    RATE_INTEREST_PRIVILEGED NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  \
# 0                  0.867336                    XAP             Approved
# 1                       NaN                    XNA             Approved
# 2                       NaN                    XNA             Approved
# 3                       NaN                    XNA             Approved
# 4                       NaN                Repairs              Refused
#
#    DAYS_DECISION      NAME_PAYMENT_TYPE CODE_REJECT_REASON  NAME_TYPE_SUITE  \
# 0            -73  Cash through the bank                XAP             None
# 1           -164                    XNA                XAP    Unaccompanied
# 2           -301  Cash through the bank                XAP  Spouse, partner
# 3           -512  Cash through the bank                XAP             None
# 4           -781  Cash through the bank                 HC             None
#
#   NAME_CLIENT_TYPE NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  \
# 0         Repeater              Mobile            POS               XNA
# 1         Repeater                 XNA           Cash            x-sell
# 2         Repeater                 XNA           Cash            x-sell
# 3         Repeater                 XNA           Cash            x-sell
# 4         Repeater                 XNA           Cash           walk-in
#
#               CHANNEL_TYPE  SELLERPLACE_AREA NAME_SELLER_INDUSTRY  \
# 0             Country-wide                35         Connectivity
# 1           Contact center                -1                  XNA
# 2  Credit and cash offices                -1                  XNA
# 3  Credit and cash offices                -1                  XNA
# 4  Credit and cash offices                -1                  XNA
#
#    CNT_PAYMENT NAME_YIELD_GROUP       PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  \
# 0         12.0           middle  POS mobile with interest            365243.0
# 1         36.0       low_action          Cash X-Sell: low            365243.0
# 2         12.0             high         Cash X-Sell: high            365243.0
# 3         12.0           middle       Cash X-Sell: middle            365243.0
# 4         24.0             high         Cash Street: high                 NaN
#
#    DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0           -42.0                      300.0          -42.0             -37.0
# 1          -134.0                      916.0       365243.0          365243.0
# 2          -271.0                       59.0       365243.0          365243.0
# 3          -482.0                     -152.0         -182.0            -177.0
# 4             NaN                        NaN            NaN               NaN
#
#    NFLAG_INSURED_ON_APPROVAL
# 0                        0.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        NaN

# %%
# drop keys and empty columns
dropcols = ['RATE_INTEREST_PRIVILEGED','RATE_INTEREST_PRIMARY','SK_ID_PREV', 'SK_ID_CURR']
df.drop(dropcols, axis=1, inplace=True)

# drop rows containing null, also done by datawig?
df.dropna(axis=0, how='any', inplace=True)

# select random instances
seed = 500
numinstances = 1000
df = df.sample(numinstances,random_state=seed)
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 929166 to 1290315
# Data columns (total 33 columns):
# NAME_CONTRACT_TYPE             1000 non-null object
# AMT_ANNUITY                    1000 non-null float64
# AMT_APPLICATION                1000 non-null float64
# AMT_CREDIT                     1000 non-null float64
# AMT_DOWN_PAYMENT               1000 non-null float64
# AMT_GOODS_PRICE                1000 non-null float64
# WEEKDAY_APPR_PROCESS_START     1000 non-null object
# HOUR_APPR_PROCESS_START        1000 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    1000 non-null object
# NFLAG_LAST_APPL_IN_DAY         1000 non-null int64
# RATE_DOWN_PAYMENT              1000 non-null float64
# NAME_CASH_LOAN_PURPOSE         1000 non-null object
# NAME_CONTRACT_STATUS           1000 non-null object
# DAYS_DECISION                  1000 non-null int64
# NAME_PAYMENT_TYPE              1000 non-null object
# CODE_REJECT_REASON             1000 non-null object
# NAME_TYPE_SUITE                1000 non-null object
# NAME_CLIENT_TYPE               1000 non-null object
# NAME_GOODS_CATEGORY            1000 non-null object
# NAME_PORTFOLIO                 1000 non-null object
# NAME_PRODUCT_TYPE              1000 non-null object
# CHANNEL_TYPE                   1000 non-null object
# SELLERPLACE_AREA               1000 non-null int64
# NAME_SELLER_INDUSTRY           1000 non-null object
# CNT_PAYMENT                    1000 non-null float64
# NAME_YIELD_GROUP               1000 non-null object
# PRODUCT_COMBINATION            1000 non-null object
# DAYS_FIRST_DRAWING             1000 non-null float64
# DAYS_FIRST_DUE                 1000 non-null float64
# DAYS_LAST_DUE_1ST_VERSION      1000 non-null float64
# DAYS_LAST_DUE                  1000 non-null float64
# DAYS_TERMINATION               1000 non-null float64
# NFLAG_INSURED_ON_APPROVAL      1000 non-null float64
# dtypes: float64(13), int64(4), object(16)
# memory usage: 265.6+ KB

# %%
# assign data types
description = pd.read_excel('data/HomeCredit_columns_description.xlsx', sheet_name='Sheet1',usecols=[2,3,4])
description.head()
# Out:
#                Table                 Row         Type
# 0  application_train          SK_ID_CURR    numerical
# 1  application_train              TARGET  categorical
# 2  application_train  NAME_CONTRACT_TYPE  categorical
# 3  application_train         CODE_GENDER  categorical
# 4  application_train        FLAG_OWN_CAR  categorical

# %%
# rename to python types: category , float
python_cat_dtype = 'object'
python_num_dtype = 'float64'

description.replace('categorical', python_cat_dtype, inplace=True)
description.replace('numerical', python_num_dtype, inplace=True)

# type cols
typecols = description[(description.Table == table)]
typecols.head()
# Out:
#                     Table                 Row     Type
# 173  previous_application         SK_ID_PREV   float64
# 174  previous_application          SK_ID_CURR  float64
# 175  previous_application  NAME_CONTRACT_TYPE   object
# 176  previous_application         AMT_ANNUITY  float64
# 177  previous_application     AMT_APPLICATION  float64

# %%
# get target columns 
targetcols = pd.DataFrame(df.columns, columns=['Row'])
targetcols.head()
# Out:
#                   Row
# 0  NAME_CONTRACT_TYPE
# 1         AMT_ANNUITY
# 2     AMT_APPLICATION
# 3          AMT_CREDIT
# 4    AMT_DOWN_PAYMENT

# %%
# join , ensure col correct -  we dont know which cols are present in the description
targetcols = targetcols.merge(typecols, how='left')
targetcols.head()
# Out:
#                   Row                 Table     Type
# 0  NAME_CONTRACT_TYPE  previous_application   object
# 1         AMT_ANNUITY  previous_application  float64
# 2     AMT_APPLICATION  previous_application  float64
# 3          AMT_CREDIT  previous_application  float64
# 4    AMT_DOWN_PAYMENT  previous_application  float64

# %%
# retrieve all columns of same type 
cat = targetcols.loc[(targetcols.Type == python_cat_dtype),'Row'].values.tolist()
num = targetcols.loc[(targetcols.Type == python_num_dtype),'Row'].values.tolist()

print(cat)
print(num)
#print(len(cat) + len(num))
# Out:
# ['NAME_CONTRACT_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION', 'NFLAG_INSURED_ON_APPROVAL']
# ['AMT_ANNUITY', 'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE', 'RATE_DOWN_PAYMENT', 'DAYS_DECISION', 'CNT_PAYMENT', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION']

# %%
## batch update types 
df[cat] = df[cat].astype(python_cat_dtype)
df[num] = df[num].astype(python_num_dtype)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 929166 to 1290315
# Data columns (total 33 columns):
# NAME_CONTRACT_TYPE             1000 non-null object
# AMT_ANNUITY                    1000 non-null float64
# AMT_APPLICATION                1000 non-null float64
# AMT_CREDIT                     1000 non-null float64
# AMT_DOWN_PAYMENT               1000 non-null float64
# AMT_GOODS_PRICE                1000 non-null float64
# WEEKDAY_APPR_PROCESS_START     1000 non-null object
# HOUR_APPR_PROCESS_START        1000 non-null object
# FLAG_LAST_APPL_PER_CONTRACT    1000 non-null object
# NFLAG_LAST_APPL_IN_DAY         1000 non-null object
# RATE_DOWN_PAYMENT              1000 non-null float64
# NAME_CASH_LOAN_PURPOSE         1000 non-null object
# NAME_CONTRACT_STATUS           1000 non-null object
# DAYS_DECISION                  1000 non-null float64
# NAME_PAYMENT_TYPE              1000 non-null object
# CODE_REJECT_REASON             1000 non-null object
# NAME_TYPE_SUITE                1000 non-null object
# NAME_CLIENT_TYPE               1000 non-null object
# NAME_GOODS_CATEGORY            1000 non-null object
# NAME_PORTFOLIO                 1000 non-null object
# NAME_PRODUCT_TYPE              1000 non-null object
# CHANNEL_TYPE                   1000 non-null object
# SELLERPLACE_AREA               1000 non-null object
# NAME_SELLER_INDUSTRY           1000 non-null object
# CNT_PAYMENT                    1000 non-null float64
# NAME_YIELD_GROUP               1000 non-null object
# PRODUCT_COMBINATION            1000 non-null object
# DAYS_FIRST_DRAWING             1000 non-null float64
# DAYS_FIRST_DUE                 1000 non-null float64
# DAYS_LAST_DUE_1ST_VERSION      1000 non-null float64
# DAYS_LAST_DUE                  1000 non-null float64
# DAYS_TERMINATION               1000 non-null float64
# NFLAG_INSURED_ON_APPROVAL      1000 non-null object
# dtypes: float64(13), object(20)
# memory usage: 265.6+ KB

# %%
# out categoricals dont look like categoricals

df[cat]
# Out:
#         NAME_CONTRACT_TYPE WEEKDAY_APPR_PROCESS_START HOUR_APPR_PROCESS_START  \
# 929166      Consumer loans                   SATURDAY                       8
# 1053922     Consumer loans                  WEDNESDAY                      17
# 218963      Consumer loans                   SATURDAY                      11
# 1593438     Consumer loans                   THURSDAY                      17
# 1346827         Cash loans                    TUESDAY                      17
# 897815      Consumer loans                   SATURDAY                      14
# 24666       Consumer loans                  WEDNESDAY                      18
# 577624      Consumer loans                   SATURDAY                      11
# 1408920     Consumer loans                    TUESDAY                       3
# 613751      Consumer loans                     MONDAY                      10
# 368387      Consumer loans                     FRIDAY                       6
# 1074254     Consumer loans                   SATURDAY                      12
# 134304      Consumer loans                     MONDAY                      20
# 403716      Consumer loans                     MONDAY                      14
# 878893          Cash loans                     FRIDAY                      14
# 1640035     Consumer loans                  WEDNESDAY                      10
# 252374      Consumer loans                   THURSDAY                      17
# 1241248     Consumer loans                     FRIDAY                      11
# 1073401     Consumer loans                     MONDAY                      10
# 1152806     Consumer loans                    TUESDAY                      15
# 1073397     Consumer loans                     FRIDAY                      14
# 654591      Consumer loans                    TUESDAY                      12
# 1519699     Consumer loans                    TUESDAY                      13
# 1661773     Consumer loans                    TUESDAY                      15
# 975256      Consumer loans                     FRIDAY                      18
# 1515810     Consumer loans                   SATURDAY                       5
# 1460099     Consumer loans                  WEDNESDAY                      17
# 692517      Consumer loans                     SUNDAY                       9
# 1026234     Consumer loans                   THURSDAY                      10
# 519429      Consumer loans                     FRIDAY                      14
# ...                    ...                        ...                     ...
# 645065      Consumer loans                     SUNDAY                      17
# 1273993     Consumer loans                     FRIDAY                      14
# 367540      Consumer loans                     MONDAY                      18
# 189655      Consumer loans                   SATURDAY                      16
# 1213456     Consumer loans                    TUESDAY                      12
# 328654      Consumer loans                   THURSDAY                      12
# 1259310     Consumer loans                     MONDAY                      18
# 445694      Consumer loans                  WEDNESDAY                      10
# 649317      Consumer loans                    TUESDAY                      12
# 1661390     Consumer loans                     MONDAY                      14
# 464019      Consumer loans                    TUESDAY                      13
# 866534      Consumer loans                    TUESDAY                      14
# 1081516     Consumer loans                    TUESDAY                       7
# 83280       Consumer loans                   THURSDAY                      14
# 1054168     Consumer loans                     FRIDAY                       9
# 1346723     Consumer loans                     MONDAY                      17
# 1586616     Consumer loans                    TUESDAY                      16
# 533219      Consumer loans                     MONDAY                      12
# 1189020     Consumer loans                     FRIDAY                      13
# 1058158     Consumer loans                   SATURDAY                      18
# 82397           Cash loans                     FRIDAY                      11
# 720903      Consumer loans                     SUNDAY                      12
# 560213      Consumer loans                     MONDAY                      18
# 265076      Consumer loans                     MONDAY                      10
# 956757      Consumer loans                   SATURDAY                      11
# 1027716     Consumer loans                     FRIDAY                      15
# 838592      Consumer loans                    TUESDAY                      18
# 583182      Consumer loans                   SATURDAY                      15
# 47200       Consumer loans                  WEDNESDAY                      10
# 1290315     Consumer loans                  WEDNESDAY                       8
#
#         FLAG_LAST_APPL_PER_CONTRACT NFLAG_LAST_APPL_IN_DAY  \
# 929166                            Y                      1
# 1053922                           Y                      1
# 218963                            Y                      1
# 1593438                           Y                      1
# 1346827                           Y                      1
# 897815                            Y                      1
# 24666                             Y                      1
# 577624                            Y                      1
# 1408920                           Y                      1
# 613751                            Y                      1
# 368387                            Y                      1
# 1074254                           Y                      1
# 134304                            Y                      1
# 403716                            Y                      1
# 878893                            Y                      1
# 1640035                           Y                      1
# 252374                            Y                      1
# 1241248                           Y                      1
# 1073401                           Y                      1
# 1152806                           Y                      1
# 1073397                           Y                      1
# 654591                            Y                      1
# 1519699                           Y                      1
# 1661773                           Y                      1
# 975256                            Y                      1
# 1515810                           Y                      1
# 1460099                           Y                      1
# 692517                            Y                      1
# 1026234                           Y                      1
# 519429                            Y                      1
# ...                             ...                    ...
# 645065                            Y                      1
# 1273993                           Y                      1
# 367540                            Y                      1
# 189655                            Y                      1
# 1213456                           Y                      1
# 328654                            Y                      1
# 1259310                           Y                      1
# 445694                            Y                      1
# 649317                            Y                      1
# 1661390                           Y                      1
# 464019                            Y                      1
# 866534                            Y                      1
# 1081516                           Y                      1
# 83280                             Y                      1
# 1054168                           Y                      1
# 1346723                           Y                      1
# 1586616                           Y                      1
# 533219                            Y                      1
# 1189020                           Y                      1
# 1058158                           Y                      1
# 82397                             Y                      1
# 720903                            Y                      1
# 560213                            Y                      1
# 265076                            Y                      1
# 956757                            Y                      1
# 1027716                           Y                      1
# 838592                            Y                      1
# 583182                            Y                      1
# 47200                             Y                      1
# 1290315                           Y                      1
#
#         NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS      NAME_PAYMENT_TYPE  \
# 929166                     XAP             Approved  Cash through the bank
# 1053922                    XAP             Approved  Cash through the bank
# 218963                     XAP             Approved  Cash through the bank
# 1593438                    XAP             Approved  Cash through the bank
# 1346827                    XNA             Approved  Cash through the bank
# 897815                     XAP             Approved  Cash through the bank
# 24666                      XAP             Approved                    XNA
# 577624                     XAP             Approved  Cash through the bank
# 1408920                    XAP             Approved                    XNA
# 613751                     XAP             Approved                    XNA
# 368387                     XAP             Approved                    XNA
# 1074254                    XAP             Approved  Cash through the bank
# 134304                     XAP             Approved  Cash through the bank
# 403716                     XAP             Approved  Cash through the bank
# 878893                     XNA             Approved  Cash through the bank
# 1640035                    XAP             Approved  Cash through the bank
# 252374                     XAP             Approved                    XNA
# 1241248                    XAP             Approved  Cash through the bank
# 1073401                    XAP             Approved  Cash through the bank
# 1152806                    XAP             Approved  Cash through the bank
# 1073397                    XAP             Approved  Cash through the bank
# 654591                     XAP             Approved                    XNA
# 1519699                    XAP             Approved  Cash through the bank
# 1661773                    XAP             Approved  Cash through the bank
# 975256                     XAP             Approved  Cash through the bank
# 1515810                    XAP             Approved                    XNA
# 1460099                    XAP             Approved  Cash through the bank
# 692517                     XAP             Approved                    XNA
# 1026234                    XAP             Approved  Cash through the bank
# 519429                     XAP             Approved  Cash through the bank
# ...                        ...                  ...                    ...
# 645065                     XAP             Approved  Cash through the bank
# 1273993                    XAP             Approved                    XNA
# 367540                     XAP             Approved  Cash through the bank
# 189655                     XAP             Approved  Cash through the bank
# 1213456                    XAP             Approved  Cash through the bank
# 328654                     XAP             Approved  Cash through the bank
# 1259310                    XAP             Approved  Cash through the bank
# 445694                     XAP             Approved  Cash through the bank
# 649317                     XAP             Approved  Cash through the bank
# 1661390                    XAP             Approved  Cash through the bank
# 464019                     XAP             Approved  Cash through the bank
# 866534                     XAP             Approved                    XNA
# 1081516                    XAP             Approved                    XNA
# 83280                      XAP             Approved  Cash through the bank
# 1054168                    XAP             Approved  Cash through the bank
# 1346723                    XAP             Approved                    XNA
# 1586616                    XAP             Approved  Cash through the bank
# 533219                     XAP             Approved  Cash through the bank
# 1189020                    XAP             Approved  Cash through the bank
# 1058158                    XAP             Approved  Cash through the bank
# 82397                      XNA             Approved  Cash through the bank
# 720903                     XAP             Approved  Cash through the bank
# 560213                     XAP             Approved  Cash through the bank
# 265076                     XAP             Approved  Cash through the bank
# 956757                     XAP             Approved  Cash through the bank
# 1027716                    XAP             Approved  Cash through the bank
# 838592                     XAP             Approved  Cash through the bank
# 583182                     XAP             Approved  Cash through the bank
# 47200                      XAP             Approved                    XNA
# 1290315                    XAP             Approved                    XNA
#
#         CODE_REJECT_REASON  NAME_TYPE_SUITE NAME_CLIENT_TYPE  \
# 929166                 XAP    Unaccompanied         Repeater
# 1053922                XAP           Family         Repeater
# 218963                 XAP           Family              New
# 1593438                XAP           Family         Repeater
# 1346827                XAP           Family         Repeater
# 897815                 XAP    Unaccompanied        Refreshed
# 24666                  XAP  Spouse, partner              New
# 577624                 XAP          Other_B              New
# 1408920                XAP         Children              New
# 613751                 XAP    Unaccompanied              New
# 368387                 XAP           Family              New
# 1074254                XAP    Unaccompanied         Repeater
# 134304                 XAP         Children         Repeater
# 403716                 XAP    Unaccompanied              New
# 878893                 XAP    Unaccompanied         Repeater
# 1640035                XAP           Family        Refreshed
# 252374                 XAP    Unaccompanied              New
# 1241248                XAP           Family              New
# 1073401                XAP           Family              New
# 1152806                XAP           Family              New
# 1073397                XAP    Unaccompanied        Refreshed
# 654591                 XAP    Unaccompanied              New
# 1519699                XAP    Unaccompanied              New
# 1661773                XAP           Family         Repeater
# 975256                 XAP    Unaccompanied         Repeater
# 1515810                XAP    Unaccompanied              New
# 1460099                XAP    Unaccompanied         Repeater
# 692517                 XAP  Spouse, partner         Repeater
# 1026234                XAP           Family         Repeater
# 519429                 XAP    Unaccompanied              New
# ...                    ...              ...              ...
# 645065                 XAP    Unaccompanied              New
# 1273993                XAP  Spouse, partner         Repeater
# 367540                 XAP           Family         Repeater
# 189655                 XAP    Unaccompanied              New
# 1213456                XAP         Children              New
# 328654                 XAP  Spouse, partner              New
# 1259310                XAP           Family              New
# 445694                 XAP           Family              New
# 649317                 XAP    Unaccompanied         Repeater
# 1661390                XAP         Children              New
# 464019                 XAP           Family        Refreshed
# 866534                 XAP           Family         Repeater
# 1081516                XAP          Other_B         Repeater
# 83280                  XAP    Unaccompanied              New
# 1054168                XAP    Unaccompanied              New
# 1346723                XAP  Spouse, partner              New
# 1586616                XAP    Unaccompanied        Refreshed
# 533219                 XAP    Unaccompanied        Refreshed
# 1189020                XAP    Unaccompanied              New
# 1058158                XAP           Family              New
# 82397                  XAP    Unaccompanied         Repeater
# 720903                 XAP           Family         Repeater
# 560213                 XAP           Family         Repeater
# 265076                 XAP    Unaccompanied              New
# 956757                 XAP         Children         Repeater
# 1027716                XAP           Family        Refreshed
# 838592                 XAP           Family         Repeater
# 583182                 XAP           Family         Repeater
# 47200                  XAP    Unaccompanied              New
# 1290315                XAP    Unaccompanied         Repeater
#
#               NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  \
# 929166                Audio/Video            POS               XNA
# 1053922                 Computers            POS               XNA
# 218963   Clothing and Accessories            POS               XNA
# 1593438    Construction Materials            POS               XNA
# 1346827                       XNA           Cash            x-sell
# 897815                  Computers            POS               XNA
# 24666                   Computers            POS               XNA
# 577624                  Computers            POS               XNA
# 1408920                 Computers            POS               XNA
# 613751       Consumer Electronics            POS               XNA
# 368387       Consumer Electronics            POS               XNA
# 1074254         Office Appliances            POS               XNA
# 134304                     Mobile            POS               XNA
# 403716       Consumer Electronics            POS               XNA
# 878893                        XNA           Cash            x-sell
# 1640035                 Furniture            POS               XNA
# 252374                Audio/Video            POS               XNA
# 1241248                 Computers            POS               XNA
# 1073401               Audio/Video            POS               XNA
# 1152806               Audio/Video            POS               XNA
# 1073397               Audio/Video            POS               XNA
# 654591                    Jewelry            POS               XNA
# 1519699                 Furniture            POS               XNA
# 1661773                    Mobile            POS               XNA
# 975256                     Mobile            POS               XNA
# 1515810                    Mobile            POS               XNA
# 1460099      Consumer Electronics            POS               XNA
# 692517          Sport and Leisure            POS               XNA
# 1026234         Sport and Leisure            POS               XNA
# 519429                  Furniture            POS               XNA
# ...                           ...            ...               ...
# 645065                  Computers            POS               XNA
# 1273993                    Mobile            POS               XNA
# 367540                  Computers            POS               XNA
# 189655                Audio/Video            POS               XNA
# 1213456                    Mobile            POS               XNA
# 328654                     Mobile            POS               XNA
# 1259310                    Mobile            POS               XNA
# 445694                  Furniture            POS               XNA
# 649317                  Furniture            POS               XNA
# 1661390                   Tourism            POS               XNA
# 464019                  Furniture            POS               XNA
# 866534                Audio/Video            POS               XNA
# 1081516                    Mobile            POS               XNA
# 83280                 Audio/Video            POS               XNA
# 1054168                 Furniture            POS               XNA
# 1346723               Audio/Video            POS               XNA
# 1586616      Consumer Electronics            POS               XNA
# 533219                Audio/Video            POS               XNA
# 1189020                 Computers            POS               XNA
# 1058158               Audio/Video            POS               XNA
# 82397                         XNA           Cash            x-sell
# 720903                  Homewares            POS               XNA
# 560213                Audio/Video            POS               XNA
# 265076                     Mobile            POS               XNA
# 956757                     Mobile            POS               XNA
# 1027716                 Computers            POS               XNA
# 838592   Clothing and Accessories            POS               XNA
# 583182       Consumer Electronics            POS               XNA
# 47200            Auto Accessories            POS               XNA
# 1290315      Consumer Electronics            POS               XNA
#
#                     CHANNEL_TYPE SELLERPLACE_AREA  NAME_SELLER_INDUSTRY  \
# 929166              Country-wide             4000  Consumer electronics
# 1053922             Country-wide             1200  Consumer electronics
# 218963                     Stone               35              Clothing
# 1593438         Regional / Local             4000          Construction
# 1346827  Credit and cash offices                0                   XNA
# 897815          Regional / Local               50  Consumer electronics
# 24666               Country-wide             2170  Consumer electronics
# 577624              Country-wide             1378  Consumer electronics
# 1408920                    Stone              312  Consumer electronics
# 613751                     Stone               60  Consumer electronics
# 368387          Regional / Local              150  Consumer electronics
# 1074254         Regional / Local              100  Consumer electronics
# 134304              Country-wide            12000  Consumer electronics
# 403716              Country-wide                5  Consumer electronics
# 878893   Credit and cash offices               -1                   XNA
# 1640035                    Stone              150             Furniture
# 252374              Country-wide             2170  Consumer electronics
# 1241248         Regional / Local               40  Consumer electronics
# 1073401             Country-wide              110  Consumer electronics
# 1152806             Country-wide             1500  Consumer electronics
# 1073397                    Stone               25  Consumer electronics
# 654591                     Stone              171              Industry
# 1519699                    Stone              350             Furniture
# 1661773             Country-wide               58          Connectivity
# 975256              Country-wide               20          Connectivity
# 1515810         Regional / Local               26          Connectivity
# 1460099             Country-wide             1550  Consumer electronics
# 692517          Regional / Local              150  Consumer electronics
# 1026234                    Stone              350             Furniture
# 519429                     Stone               20             Furniture
# ...                          ...              ...                   ...
# 645065              Country-wide               85          Connectivity
# 1273993                    Stone              140  Consumer electronics
# 367540          Regional / Local               72  Consumer electronics
# 189655                     Stone              150  Consumer electronics
# 1213456             Country-wide               25          Connectivity
# 328654              Country-wide               50          Connectivity
# 1259310             Country-wide               20          Connectivity
# 445694                     Stone                4             Furniture
# 649317                     Stone               50             Furniture
# 1661390                    Stone              100               Tourism
# 464019                     Stone               38             Furniture
# 866534          Regional / Local              151  Consumer electronics
# 1081516             Country-wide               55          Connectivity
# 83280               Country-wide               -1  Consumer electronics
# 1054168                    Stone              488             Furniture
# 1346723             Country-wide               50          Connectivity
# 1586616                    Stone              240          Construction
# 533219              Country-wide               80  Consumer electronics
# 1189020                    Stone               70  Consumer electronics
# 1058158             Country-wide             1786  Consumer electronics
# 82397    Credit and cash offices                0                   XNA
# 720903              Country-wide             1450  Consumer electronics
# 560213              Country-wide             1455  Consumer electronics
# 265076              Country-wide               36          Connectivity
# 956757              Country-wide               27          Connectivity
# 1027716             Country-wide              575  Consumer electronics
# 838592                     Stone               50              Clothing
# 583182              Country-wide             2112  Consumer electronics
# 47200                      Stone               70              Industry
# 1290315             Country-wide             2334  Consumer electronics
#
#         NAME_YIELD_GROUP             PRODUCT_COMBINATION  \
# 929166              high     POS household with interest
# 1053922       low_normal     POS household with interest
# 218963            middle      POS industry with interest
# 1593438       low_normal      POS industry with interest
# 1346827             high               Cash X-Sell: high
# 897815              high     POS household with interest
# 24666             middle     POS household with interest
# 577624            middle     POS household with interest
# 1408920           middle     POS household with interest
# 613751            middle     POS household with interest
# 368387            middle     POS household with interest
# 1074254             high     POS household with interest
# 134304              high     POS household with interest
# 403716            middle        POS mobile with interest
# 878893              high               Cash Street: high
# 1640035       low_normal      POS industry with interest
# 252374              high     POS household with interest
# 1241248           middle     POS household with interest
# 1073401             high     POS household with interest
# 1152806       low_action  POS household without interest
# 1073397           middle     POS household with interest
# 654591        low_normal         POS other with interest
# 1519699           middle      POS industry with interest
# 1661773             high        POS mobile with interest
# 975256            middle        POS mobile with interest
# 1515810             high        POS mobile with interest
# 1460099       low_normal     POS household with interest
# 692517        low_normal     POS household with interest
# 1026234             high      POS industry with interest
# 519429        low_normal      POS industry with interest
# ...                  ...                             ...
# 645065              high        POS mobile with interest
# 1273993             high     POS household with interest
# 367540            middle  POS household without interest
# 189655            middle     POS household with interest
# 1213456             high        POS mobile with interest
# 328654              high        POS mobile with interest
# 1259310             high        POS mobile with interest
# 445694            middle      POS industry with interest
# 649317            middle      POS industry with interest
# 1661390           middle         POS other with interest
# 464019        low_normal      POS industry with interest
# 866534        low_normal     POS household with interest
# 1081516             high        POS mobile with interest
# 83280               high     POS household with interest
# 1054168           middle      POS industry with interest
# 1346723             high        POS mobile with interest
# 1586616       low_normal      POS industry with interest
# 533219            middle     POS household with interest
# 1189020             high     POS household with interest
# 1058158       low_normal  POS household without interest
# 82397               high               Cash X-Sell: high
# 720903            middle     POS household with interest
# 560213            middle     POS household with interest
# 265076              high        POS mobile with interest
# 956757        low_normal        POS mobile with interest
# 1027716           middle     POS household with interest
# 838592            middle      POS industry with interest
# 583182        low_normal     POS household with interest
# 47200             middle         POS other with interest
# 1290315             high     POS household with interest
#
#         NFLAG_INSURED_ON_APPROVAL
# 929166                          0
# 1053922                         0
# 218963                          0
# 1593438                         0
# 1346827                         1
# 897815                          1
# 24666                           0
# 577624                          0
# 1408920                         0
# 613751                          0
# 368387                          0
# 1074254                         0
# 134304                          0
# 403716                          1
# 878893                          1
# 1640035                         0
# 252374                          0
# 1241248                         0
# 1073401                         0
# 1152806                         0
# 1073397                         0
# 654591                          0
# 1519699                         0
# 1661773                         0
# 975256                          0
# 1515810                         0
# 1460099                         0
# 692517                          0
# 1026234                         0
# 519429                          0
# ...                           ...
# 645065                          0
# 1273993                         0
# 367540                          0
# 189655                          0
# 1213456                         0
# 328654                          0
# 1259310                         1
# 445694                          1
# 649317                          0
# 1661390                         0
# 464019                          0
# 866534                          0
# 1081516                         0
# 83280                           1
# 1054168                         0
# 1346723                         1
# 1586616                         0
# 533219                          0
# 1189020                         0
# 1058158                         1
# 82397                           1
# 720903                          0
# 560213                          0
# 265076                          1
# 956757                          1
# 1027716                         0
# 838592                          0
# 583182                          0
# 47200                           0
# 1290315                         0
#
# [1000 rows x 20 columns]

# %%
# select a portion of the data for evaluation
df_train, df_test = datawig.utils.random_split(df)


output_column = 'PRODUCT_COMBINATION'
output_path = 'imputer_model'
lst = [*df.columns.values]
lst.remove(output_column)
input_cols = lst

# Initialize a SimpleImputer model
imputer = datawig.SimpleImputer(
    input_columns=input_cols,  # columns containing information about the column we want to impute
    output_column='PRODUCT_COMBINATION',  # the column we'd like to impute values for
    output_path=output_path  # stores model data and metrics
)

# Fit an imputer model on the train data
#imputer.fit(train_df=df_train, num_epochs=5)

# Fit an imputer model with default list of hyperparameters
imputer.fit_hpo(train_df=df_train)

# Impute missing values and return original dataframe with predictions
predictions = imputer.predict(df_test)

# Calculate f1 score for true vs predicted values
f1 = datawig.f1_score(predictions[output_column], predictions[output_column+'_imputed'], average='weighted')

# Print overall classification report
print(datawig.classification_report(predictions[output_column], predictions[output_column+'_imputed']))


# fit an imputer model with customized hyperparameters
#imputer.fit_hpo(
#    train_df=df_train,
#    num_epochs=100,
#    patience=3,
#    learning_rate_candidates=[1e-3, 3e-4, 1e-4]
#)
# Out:
# 2019-05-01 16:49:04,377 [INFO]  Assuming 13 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-01 16:49:04,379 [INFO]  Assuming 19 string input columns: SELLERPLACE_AREA, NAME_PAYMENT_TYPE, NAME_TYPE_SUITE, NAME_PRODUCT_TYPE, NAME_SELLER_INDUSTRY, NAME_CASH_LOAN_PURPOSE, HOUR_APPR_PROCESS_START, NAME_PORTFOLIO, CHANNEL_TYPE, FLAG_LAST_APPL_PER_CONTRACT, NFLAG_LAST_APPL_IN_DAY, NAME_CONTRACT_TYPE, NAME_GOODS_CATEGORY, NAME_YIELD_GROUP, NAME_CONTRACT_STATUS, NFLAG_INSURED_ON_APPROVAL, NAME_CLIENT_TYPE, CODE_REJECT_REASON, WEEKDAY_APPR_PROCESS_START
# 2019-05-01 16:49:04,380 [INFO]  Assuming 13 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, RATE_DOWN_PAYMENT, DAYS_DECISION, CNT_PAYMENT, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_LAST_DUE, DAYS_TERMINATION
# 2019-05-01 16:49:04,382 [INFO]  Assuming 19 string input columns: SELLERPLACE_AREA, NAME_PAYMENT_TYPE, NAME_TYPE_SUITE, NAME_PRODUCT_TYPE, NAME_SELLER_INDUSTRY, NAME_CASH_LOAN_PURPOSE, HOUR_APPR_PROCESS_START, NAME_PORTFOLIO, CHANNEL_TYPE, FLAG_LAST_APPL_PER_CONTRACT, NFLAG_LAST_APPL_IN_DAY, NAME_CONTRACT_TYPE, NAME_GOODS_CATEGORY, NAME_YIELD_GROUP, NAME_CONTRACT_STATUS, NFLAG_INSURED_ON_APPROVAL, NAME_CLIENT_TYPE, CODE_REJECT_REASON, WEEKDAY_APPR_PROCESS_START
# 2019-05-01 16:49:04,410 [INFO]  Training starts for 1hyperparameter configurations.
# 2019-05-01 16:49:04,413 [INFO]  Fitting hpo iteration 0 with parameters
# 	global:batch_size: 16
# 	global:learning_rate: 0.004
# 	global:weight_decay: 0
# 	global:num_epochs: 25
# 	global:patience: 3
# 	global:final_fc_hidden_units: []
# 	NAME_CONTRACT_TYPE:type: string
# 	NAME_CONTRACT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_TYPE:max_tokens: 32768
# 	NAME_CONTRACT_TYPE:tokens: ['chars']
# 	AMT_ANNUITY:type: numeric
# 	AMT_ANNUITY:normalize: True
# 	AMT_ANNUITY:numeric_latent_dim: 10
# 	AMT_ANNUITY:numeric_hidden_layers: 1
# 	AMT_APPLICATION:type: numeric
# 	AMT_APPLICATION:normalize: True
# 	AMT_APPLICATION:numeric_latent_dim: 10
# 	AMT_APPLICATION:numeric_hidden_layers: 1
# 	AMT_CREDIT:type: numeric
# 	AMT_CREDIT:normalize: True
# 	AMT_CREDIT:numeric_latent_dim: 10
# 	AMT_CREDIT:numeric_hidden_layers: 1
# 	AMT_DOWN_PAYMENT:type: numeric
# 	AMT_DOWN_PAYMENT:normalize: True
# 	AMT_DOWN_PAYMENT:numeric_latent_dim: 10
# 	AMT_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	AMT_GOODS_PRICE:type: numeric
# 	AMT_GOODS_PRICE:normalize: True
# 	AMT_GOODS_PRICE:numeric_latent_dim: 10
# 	AMT_GOODS_PRICE:numeric_hidden_layers: 1
# 	WEEKDAY_APPR_PROCESS_START:type: string
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:words: (1, 3)
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:chars: (1, 5)
# 	WEEKDAY_APPR_PROCESS_START:max_tokens: 32768
# 	WEEKDAY_APPR_PROCESS_START:tokens: ['chars']
# 	HOUR_APPR_PROCESS_START:type: string
# 	HOUR_APPR_PROCESS_START:ngram_range:words: (1, 3)
# 	HOUR_APPR_PROCESS_START:ngram_range:chars: (1, 5)
# 	HOUR_APPR_PROCESS_START:max_tokens: 32768
# 	HOUR_APPR_PROCESS_START:tokens: ['chars']
# 	FLAG_LAST_APPL_PER_CONTRACT:type: string
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:words: (1, 3)
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:chars: (1, 5)
# 	FLAG_LAST_APPL_PER_CONTRACT:max_tokens: 32768
# 	FLAG_LAST_APPL_PER_CONTRACT:tokens: ['chars']
# 	NFLAG_LAST_APPL_IN_DAY:type: string
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:words: (1, 3)
# 	NFLAG_LAST_APPL_IN_DAY:ngram_range:chars: (1, 5)
# 	NFLAG_LAST_APPL_IN_DAY:max_tokens: 32768
# 	NFLAG_LAST_APPL_IN_DAY:tokens: ['chars']
# 	RATE_DOWN_PAYMENT:type: numeric
# 	RATE_DOWN_PAYMENT:normalize: True
# 	RATE_DOWN_PAYMENT:numeric_latent_dim: 10
# 	RATE_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	NAME_CASH_LOAN_PURPOSE:type: string
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:words: (1, 3)
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:chars: (1, 5)
# 	NAME_CASH_LOAN_PURPOSE:max_tokens: 32768
# 	NAME_CASH_LOAN_PURPOSE:tokens: ['chars']
# 	NAME_CONTRACT_STATUS:type: string
# 	NAME_CONTRACT_STATUS:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_STATUS:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_STATUS:max_tokens: 32768
# 	NAME_CONTRACT_STATUS:tokens: ['chars']
# 	DAYS_DECISION:type: numeric
# 	DAYS_DECISION:normalize: True
# 	DAYS_DECISION:numeric_latent_dim: 10
# 	DAYS_DECISION:numeric_hidden_layers: 1
# 	NAME_PAYMENT_TYPE:type: string
# 	NAME_PAYMENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PAYMENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PAYMENT_TYPE:max_tokens: 32768
# 	NAME_PAYMENT_TYPE:tokens: ['chars']
# 	CODE_REJECT_REASON:type: string
# 	CODE_REJECT_REASON:ngram_range:words: (1, 3)
# 	CODE_REJECT_REASON:ngram_range:chars: (1, 5)
# 	CODE_REJECT_REASON:max_tokens: 32768
# 	CODE_REJECT_REASON:tokens: ['chars']
# 	NAME_TYPE_SUITE:type: string
# 	NAME_TYPE_SUITE:ngram_range:words: (1, 3)
# 	NAME_TYPE_SUITE:ngram_range:chars: (1, 5)
# 	NAME_TYPE_SUITE:max_tokens: 32768
# 	NAME_TYPE_SUITE:tokens: ['chars']
# 	NAME_CLIENT_TYPE:type: string
# 	NAME_CLIENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CLIENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CLIENT_TYPE:max_tokens: 32768
# 	NAME_CLIENT_TYPE:tokens: ['chars']
# 	NAME_GOODS_CATEGORY:type: string
# 	NAME_GOODS_CATEGORY:ngram_range:words: (1, 3)
# 	NAME_GOODS_CATEGORY:ngram_range:chars: (1, 5)
# 	NAME_GOODS_CATEGORY:max_tokens: 32768
# 	NAME_GOODS_CATEGORY:tokens: ['chars']
# 	NAME_PORTFOLIO:type: string
# 	NAME_PORTFOLIO:ngram_range:words: (1, 3)
# 	NAME_PORTFOLIO:ngram_range:chars: (1, 5)
# 	NAME_PORTFOLIO:max_tokens: 32768
# 	NAME_PORTFOLIO:tokens: ['chars']
# 	NAME_PRODUCT_TYPE:type: string
# 	NAME_PRODUCT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PRODUCT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PRODUCT_TYPE:max_tokens: 32768
# 	NAME_PRODUCT_TYPE:tokens: ['chars']
# 	CHANNEL_TYPE:type: string
# 	CHANNEL_TYPE:ngram_range:words: (1, 3)
# 	CHANNEL_TYPE:ngram_range:chars: (1, 5)
# 	CHANNEL_TYPE:max_tokens: 32768
# 	CHANNEL_TYPE:tokens: ['chars']
# 	SELLERPLACE_AREA:type: string
# 	SELLERPLACE_AREA:ngram_range:words: (1, 3)
# 	SELLERPLACE_AREA:ngram_range:chars: (1, 5)
# 	SELLERPLACE_AREA:max_tokens: 32768
# 	SELLERPLACE_AREA:tokens: ['chars']
# 	NAME_SELLER_INDUSTRY:type: string
# 	NAME_SELLER_INDUSTRY:ngram_range:words: (1, 3)
# 	NAME_SELLER_INDUSTRY:ngram_range:chars: (1, 5)
# 	NAME_SELLER_INDUSTRY:max_tokens: 32768
# 	NAME_SELLER_INDUSTRY:tokens: ['chars']
# 	CNT_PAYMENT:type: numeric
# 	CNT_PAYMENT:normalize: True
# 	CNT_PAYMENT:numeric_latent_dim: 10
# 	CNT_PAYMENT:numeric_hidden_layers: 1
# 	NAME_YIELD_GROUP:type: string
# 	NAME_YIELD_GROUP:ngram_range:words: (1, 3)
# 	NAME_YIELD_GROUP:ngram_range:chars: (1, 5)
# 	NAME_YIELD_GROUP:max_tokens: 32768
# 	NAME_YIELD_GROUP:tokens: ['chars']
# 	DAYS_FIRST_DRAWING:type: numeric
# 	DAYS_FIRST_DRAWING:normalize: True
# 	DAYS_FIRST_DRAWING:numeric_latent_dim: 10
# 	DAYS_FIRST_DRAWING:numeric_hidden_layers: 1
# 	DAYS_FIRST_DUE:type: numeric
# 	DAYS_FIRST_DUE:normalize: True
# 	DAYS_FIRST_DUE:numeric_latent_dim: 10
# 	DAYS_FIRST_DUE:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE_1ST_VERSION:type: numeric
# 	DAYS_LAST_DUE_1ST_VERSION:normalize: True
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_latent_dim: 10
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE:type: numeric
# 	DAYS_LAST_DUE:normalize: True
# 	DAYS_LAST_DUE:numeric_latent_dim: 10
# 	DAYS_LAST_DUE:numeric_hidden_layers: 1
# 	DAYS_TERMINATION:type: numeric
# 	DAYS_TERMINATION:normalize: True
# 	DAYS_TERMINATION:numeric_latent_dim: 10
# 	DAYS_TERMINATION:numeric_hidden_layers: 1
# 	NFLAG_INSURED_ON_APPROVAL:type: string
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:words: (1, 3)
# 	NFLAG_INSURED_ON_APPROVAL:ngram_range:chars: (1, 5)
# 	NFLAG_INSURED_ON_APPROVAL:max_tokens: 32768
# 	NFLAG_INSURED_ON_APPROVAL:tokens: ['chars']
# 2019-05-01 16:49:04,423 [INFO]  No output column name provided for ColumnEncoder using PRODUCT_COMBINATION
# 2019-05-01 16:49:04,426 [INFO]  Assuming categorical output column: PRODUCT_COMBINATION
# 2019-05-01 16:49:04,434 [INFO]  Using [[cpu(0)]] as the context for training
# 2019-05-01 16:49:04,436 [INFO]  Fitting label encoder <class 'datawig.column_encoders.CategoricalEncoder'> on 640 rows                             of training data
# 2019-05-01 16:49:04,442 [INFO]  12 most often encountered discrete values:                      ['POS household with interest' 'POS mobile with interest'
#  'POS industry with interest' 'POS household without interest'
#  'Cash Street: high' 'POS other with interest' 'Cash X-Sell: high'
#  'POS industry without interest' 'Cash X-Sell: middle'
#  'Cash Street: middle' 'POS mobile without interest' 'Cash X-Sell: low']
# 2019-05-01 16:49:04,443 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 96 occurrences of value POS industry with interest
# 2019-05-01 16:49:04,447 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 79 occurrences of value POS household without interest
# 2019-05-01 16:49:04,449 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 19 occurrences of value Cash Street: high
# 2019-05-01 16:49:04,451 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 17 occurrences of value POS other with interest
# 2019-05-01 16:49:04,452 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 10 occurrences of value Cash X-Sell: high
# 2019-05-01 16:49:04,454 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 6 occurrences of value POS industry without interest
# 2019-05-01 16:49:04,456 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 4 occurrences of value Cash X-Sell: middle
# 2019-05-01 16:49:04,457 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value Cash Street: middle
# 2019-05-01 16:49:04,459 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 3 occurrences of value POS mobile without interest
# 2019-05-01 16:49:04,461 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 2 occurrences of value Cash X-Sell: low
# 2019-05-01 16:49:04,465 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 16:49:04,467 [INFO]  Dropping 0/640 rows
# 2019-05-01 16:49:04,472 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 16:49:04,473 [INFO]  Dropping 0/160 rows
# 2019-05-01 16:49:04,475 [INFO]  Train: 640, Test: 160
# 2019-05-01 16:49:04,477 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_ANNUITY and 640 rows of training data with parameters {'input_columns': ['AMT_ANNUITY'], 'output_column': 'AMT_ANNUITY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,485 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_APPLICATION and 640 rows of training data with parameters {'input_columns': ['AMT_APPLICATION'], 'output_column': 'AMT_APPLICATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,492 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_CREDIT and 640 rows of training data with parameters {'input_columns': ['AMT_CREDIT'], 'output_column': 'AMT_CREDIT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,498 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['AMT_DOWN_PAYMENT'], 'output_column': 'AMT_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,511 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_GOODS_PRICE and 640 rows of training data with parameters {'input_columns': ['AMT_GOODS_PRICE'], 'output_column': 'AMT_GOODS_PRICE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,520 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_DOWN_PAYMENT and 640 rows of training data with parameters {'input_columns': ['RATE_DOWN_PAYMENT'], 'output_column': 'RATE_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,530 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_DECISION and 640 rows of training data with parameters {'input_columns': ['DAYS_DECISION'], 'output_column': 'DAYS_DECISION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,543 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns CNT_PAYMENT and 640 rows of training data with parameters {'input_columns': ['CNT_PAYMENT'], 'output_column': 'CNT_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,553 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DRAWING and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DRAWING'], 'output_column': 'DAYS_FIRST_DRAWING_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,563 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DUE'], 'output_column': 'DAYS_FIRST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,570 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE_1ST_VERSION and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE_1ST_VERSION'], 'output_column': 'DAYS_LAST_DUE_1ST_VERSION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,580 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE and 640 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE'], 'output_column': 'DAYS_LAST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,589 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_TERMINATION and 640 rows of training data with parameters {'input_columns': ['DAYS_TERMINATION'], 'output_column': 'DAYS_TERMINATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# 2019-05-01 16:49:04,597 [INFO]  Building Train Iterator with 640 elements
# 2019-05-01 16:49:04,647 [INFO]  Data Encoding - Encoded 640 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# 2019-05-01 16:49:04,651 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 16:49:04,653 [INFO]  Normalizing with StandardScaler
# 2019-05-01 16:49:04,670 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 16:49:04,674 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 16:49:04,676 [INFO]  Normalizing with StandardScaler
# 2019-05-01 16:49:04,679 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 16:49:04,683 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 16:49:04,685 [INFO]  Normalizing with StandardScaler
# 2019-05-01 16:49:04,688 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 16:49:04,692 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 16:49:04,694 [INFO]  Normalizing with StandardScaler
# 2019-05-01 16:49:04,697 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 16:49:04,701 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 16:49:04,703 [INFO]  Normalizing with StandardScaler
# 2019-05-01 16:49:04,708 [INFO]  Data Encoding - Encoded 640 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (640, 1)                         and then into shape (640, 1)
# 2019-05-01 16:49:04,725 [INFO]  Data Encoding - Encoded 640 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (640, 32768)                         and then into shape (640, 32768)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-7044c1951083> in <module>
#      21
#      22 # Fit an imputer model with default list of hyperparameters
# ---> 23 imputer.fit_hpo(train_df=df_train)
#      24
#      25 # Impute missing values and return original dataframe with predictions
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/simple_imputer.py in fit_hpo(self, train_df, test_df, hps, num_evals, max_running_hours, hpo_run_name, user_defined_scores, num_epochs, patience, test_split, weight_decay, batch_size, num_hash_bucket_candidates, tokens_candidates, numeric_latent_dim_candidates, numeric_hidden_layers_candidates, final_fc_hidden_units, learning_rate_candidates, normalize_numeric, hpo_max_train_samples, ctx)
#     288
#     289         self.check_data_types(train_df)  # infer data types, saved self.string_columns, self.numeric_columns
# --> 290         self.hpo.tune(train_df, test_df, hps, num_evals, max_running_hours, user_defined_scores, hpo_run_name, self)
#     291         self.save()
#     292
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/_hpo.py in tune(self, train_df, test_df, hps, num_evals, max_running_hours, user_defined_scores, hpo_run_name, simple_imputer)
#     368                                simple_imputer,
#     369                                name,
# --> 370                                user_defined_scores)
#     371
#     372             # append output to results data frame
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/_hpo.py in __fit_hp(self, train_df, test_df, hp, simple_imputer, name, user_defined_scores)
#     255                        batch_size=global_parms['batch_size'],
#     256                        final_fc_hidden_units=global_parms['final_fc_hidden_units'],
# --> 257                        calibrate=True)
#     258
#     259         # add suitable metrics to hp series
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/imputer.py in fit(self, train_df, test_df, ctx, learning_rate, num_epochs, patience, test_split, weight_decay, batch_size, final_fc_hidden_units, calibrate)
#     255             train_df, test_df = random_split(train_df, [1.0 - test_split, test_split])
#     256
# --> 257         iter_train, iter_test = self.__build_iterators(train_df, test_df, test_split)
#     258
#     259         self.__check_data(test_df)
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/imputer.py in __build_iterators(self, train_df, test_df, test_split)
#     586             data_columns=self.data_encoders,
#     587             label_columns=self.label_encoders,
# --> 588             batch_size=self.batch_size
#     589         )
#     590
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/iterators.py in __init__(self, data_frame, data_columns, label_columns, batch_size)
#     225                 column_encoder.fit(data_frame)
#     226
# --> 227         self.df_iterator = self.mxnet_iterator_from_df(data_frame)
#     228         self.df_iterator.reset()
#     229         self._provide_data = self.df_iterator.provide_data
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/iterators.py in mxnet_iterator_from_df(self, data_frame)
#     105         data = {}
#     106         for col_enc in self.data_columns:
# --> 107             data_array_numpy = col_enc.transform(data_frame)
#     108             data[col_enc.output_column] = mx.nd.array(data_array_numpy[:n_samples, :])
#     109             logger.info("Data Encoding - Encoded {} rows of column \
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/datawig/column_encoders.py in transform(self, data_frame)
#     618             logger.info(logstr)
#     619
# --> 620         return self.vectorizer.transform(tmp_col).astype(np.float32)
#     621
#     622     def decode(self, col: pd.Series) -> pd.Series:
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in transform(self, X)
#     622
#     623         analyzer = self.build_analyzer()
# --> 624         X = self._get_hasher().transform(analyzer(doc) for doc in X)
#     625         if self.binary:
#     626             X.data.fill(1)
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/feature_extraction/hashing.py in transform(self, raw_X)
#     166         indices, indptr, values = \
#     167             _hashing_transform(raw_X, self.n_features, self.dtype,
# --> 168                                self.alternate_sign)
#     169         n_samples = indptr.shape[0] - 1
#     170
#
# sklearn/feature_extraction/_hashing.pyx in sklearn.feature_extraction._hashing.transform()
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/feature_extraction/hashing.py in <genexpr>(.0)
#     163             raw_X = (_iteritems(d) for d in raw_X)
#     164         elif self.input_type == "string":
# --> 165             raw_X = (((f, 1) for f in x) for x in raw_X)
#     166         indices, indptr, values = \
#     167             _hashing_transform(raw_X, self.n_features, self.dtype,
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <genexpr>(.0)
#     622
#     623         analyzer = self.build_analyzer()
# --> 624         X = self._get_hasher().transform(analyzer(doc) for doc in X)
#     625         if self.binary:
#     626             X.data.fill(1)
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     315
#     316         if self.analyzer == 'char':
# --> 317             return lambda doc: self._char_ngrams(preprocess(self.decode(doc)))
#     318
#     319         elif self.analyzer == 'char_wb':
#
# ~/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(x)
#     255
#     256         if self.lowercase:
# --> 257             return lambda x: strip_accents(x.lower())
#     258         else:
#     259             return strip_accents
#
# AttributeError: 'int' object has no attribute 'lower'

# %% [markdown]
# ## Missing Numerical

# %%
# batch: assign each column, select from description
for c in cols:
    dtype = description[c]
    df[c] = df[c].astype(dtype)
    
df.info(versbose=True)
# Out:
#                     Table                          Row         Type
# 175  previous_application           NAME_CONTRACT_TYPE  categorical
# 181  previous_application   WEEKDAY_APPR_PROCESS_START  categorical
# 182  previous_application      HOUR_APPR_PROCESS_START  categorical
# 183  previous_application  FLAG_LAST_APPL_PER_CONTRACT  categorical
# 184  previous_application       NFLAG_LAST_APPL_IN_DAY  categorical

# %% [markdown]
# #### Strategy: Impute Probalistic
#
# * Datawig: https://github.com/awslabs/datawig/blob/master/README.md#imputation-of-numerical-columns

# %%
# fill in some nulls
 ## hmm does not include missing data in th 
#seed = 200
#nullval = df.sample(frac=0.2,random_state=seed)
#test = df.loc[nullval.index,['PRODUCT_COMBINATION']]
nullval.index  
df.loc[nullval.index,['PRODUCT_COMBINATION']] = np.nan
df.loc[nullval.index,['PRODUCT_COMBINATION']].head()


# test set: counts for each value 
test.PRODUCT_COMBINATION.value_counts()

# %%
###### TODO : Assignment of Categoricals is not working!!!

#https://stackoverflow.com/questions/32718639/pandas-filling-nans-in-categorical-data
# update data types : Once you create Categorical Data, you can insert only values in category.
#print('Updating data types')

#table = 'previous_application'

# retriev type from description
#meta = hc_description.loc[hc_description['Table']==table,['Row','Type']]
#dict_types = as_dict(meta)

# set types in data table
#df = df.astype(dict_types)

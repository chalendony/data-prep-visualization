# %% [markdown]
# # DataWig
#
# [Exploratory Data Analysis](https://en.wikipedia.org/wiki/Exploratory_data_analysis) (EDA) is an approach to analyzing data sets to summarize and understand their main characteristics, often with visual methods.
#
# Starting with your *Machine Learning Checklist* you will see that a crucial step is **preparing and understanding** the data. It is a step where you will spend most of your time.  Here is an example checklists from [Aurélien Géron](10_20_2018_Machine-Learning-Project-Checklist.txt) that you can adapt to your needs.
#
# In these series of notebooks, we explore the Home Credit data set. We clean, preprocess and visualize the data for downstream processes in the Data Science Workflow.  All notebooks can be obtained from Github : https://github.com/chalendony/data-prep-visualization

# %% [markdown]
# # Python Imports

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelBinarizer
pd.set_option('display.max_columns', 125)
import quilt
from scripts.preprocess import percent_missing, align_dataframes, as_dict
from string import Template
import missingno as msno
# %matplotlib inline
import impyute
import datawig

# %% [markdown]
# ## Import Quilt Packages from Local Repository

# %%
from quilt.data.avare import homecredit
homecredit
# Out:
# <GroupNode>
# POS_CASH_balance
# application_train
# bureau
# bureau_balance
# credit_card_balance
# installments_payments
# previous_application

# %%
# avoid parens and copy original data

#### TODO dont need this loop
frames = {}
for key, val in homecredit._items():
    frames[key] = val().copy(deep=True)

#  data types
hc_description = pd.read_excel('data/HomeCredit_columns_description.xlsx', sheet_name='Sheet1',usecols=[2,3,4])
hc_description.head()

# fix error
idx = hc_description[(hc_description.Row == 'NFLAG_MICRO_CASH') & (hc_description.Table == 'previous_application')].index
hc_description.drop(idx, inplace=True)

# make copy ...
table = 'previous_application'
df = frames[table].copy(deep=True)

# %%
df.shape
# Out:
# (1670214, 37)

# %%
df.PRODUCT_COMBINATION.value_counts()
# Out:
# Cash                              285990
# POS household with interest       263622
# POS mobile with interest          220670
# Cash X-Sell: middle               143883
# Cash X-Sell: low                  130248
# Card Street                       112582
# POS industry with interest         98833
# POS household without interest     82908
# Card X-Sell                        80582
# Cash Street: high                  59639
# Cash X-Sell: high                  59301
# Cash Street: middle                34658
# Cash Street: low                   33834
# POS mobile without interest        24082
# POS other with interest            23879
# POS industry without interest      12602
# POS others without interest         2555
# Name: PRODUCT_COMBINATION, dtype: int64

# %%
# select random instances
seed = 300
numinstances = 10000
df = df.sample(numinstances,random_state=seed)

# %%
# overall: counts for each value
df.PRODUCT_COMBINATION.value_counts()
# Out:
# Cash                              1696
# POS household with interest       1532
# POS mobile with interest          1359
# Cash X-Sell: middle                854
# Cash X-Sell: low                   753
# Card Street                        724
# POS industry with interest         603
# POS household without interest     496
# Card X-Sell                        477
# Cash X-Sell: high                  372
# Cash Street: high                  340
# Cash Street: low                   207
# Cash Street: middle                179
# POS other with interest            155
# POS mobile without interest        149
# POS industry without interest       84
# POS others without interest         14
# Name: PRODUCT_COMBINATION, dtype: int64

# %%
###### TODO : Assignment of Categoricals is not working!!!

#https://stackoverflow.com/questions/32718639/pandas-filling-nans-in-categorical-data
# update data types : Once you create Categorical Data, you can insert only values in category.
#print('Updating data types')

#table = 'previous_application'

# retriev type from description
#meta = hc_description.loc[hc_description['Table']==table,['Row','Type']]
#dict_types = as_dict(meta)

# set types in data table
#df = df.astype(dict_types)

## Drop the empty columns
#dropcols = ['RATE_INTEREST_PRIVILEGED','RATE_INTEREST_PRIMARY']
#df.drop(dropcols, axis=1, inplace=True)
# Out:
# Updating data types
# {'SK_ID_PREV': 'float64', 'SK_ID_CURR': 'float64', 'NAME_CONTRACT_TYPE': 'category', 'AMT_ANNUITY': 'float64', 'AMT_APPLICATION': 'float64', 'AMT_CREDIT': 'float64', 'AMT_DOWN_PAYMENT': 'float64', 'AMT_GOODS_PRICE': 'float64', 'WEEKDAY_APPR_PROCESS_START': 'category', 'HOUR_APPR_PROCESS_START': 'category', 'FLAG_LAST_APPL_PER_CONTRACT': 'category', 'NFLAG_LAST_APPL_IN_DAY': 'category', 'RATE_DOWN_PAYMENT': 'float64', 'RATE_INTEREST_PRIMARY': 'float64', 'RATE_INTEREST_PRIVILEGED': 'float64', 'NAME_CASH_LOAN_PURPOSE': 'category', 'NAME_CONTRACT_STATUS': 'category', 'DAYS_DECISION': 'float64', 'NAME_PAYMENT_TYPE': 'category', 'CODE_REJECT_REASON': 'category', 'NAME_TYPE_SUITE': 'category', 'NAME_CLIENT_TYPE': 'category', 'NAME_GOODS_CATEGORY': 'category', 'NAME_PORTFOLIO': 'category', 'NAME_PRODUCT_TYPE': 'category', 'CHANNEL_TYPE': 'category', 'SELLERPLACE_AREA': 'category', 'NAME_SELLER_INDUSTRY': 'category', 'CNT_PAYMENT': 'float64', 'NAME_YIELD_GROUP': 'category', 'PRODUCT_COMBINATION': 'category', 'DAYS_FIRST_DRAWING': 'float64', 'DAYS_FIRST_DUE': 'float64', 'DAYS_LAST_DUE_1ST_VERSION': 'float64', 'DAYS_LAST_DUE': 'float64', 'DAYS_TERMINATION': 'float64', 'NFLAG_INSURED_ON_APPROVAL': 'category'}

# %%
# %%time

# select a portion of the data for evaluation
df_train, df_test = datawig.utils.random_split(df)

input_cols = [*df.columns.difference(['SK_ID_PREV', 'SK_ID_CURR']).values]
output_column = 'PRODUCT_COMBINATION'
output_path = 'imputer_model'

# Initialize a SimpleImputer model
imputer = datawig.SimpleImputer(
    input_columns=input_cols,  # columns containing information about the column we want to impute
    output_column='PRODUCT_COMBINATION',  # the column we'd like to impute values for
    output_path=output_path  # stores model data and metrics
)

# Fit an imputer model on the train data
#imputer.fit(train_df=df_train, num_epochs=5)

# Fit an imputer model with default list of hyperparameters
imputer.fit_hpo(train_df=df_train)

# Impute missing values and return original dataframe with predictions
predictions = imputer.predict(df_test)

# Calculate f1 score for true vs predicted values
f1 = datawig.f1_score(predictions[output_column], predictions[output_column+'_imputed'], average='weighted')

# Print overall classification report
print(datawig.classification_report(predictions[output_column], predictions[output_column+'_imputed']))


# fit an imputer model with customized hyperparameters
#imputer.fit_hpo(
#    train_df=df_train,
#    num_epochs=100,
#    patience=3,
#    learning_rate_candidates=[1e-3, 3e-4, 1e-4]
#)
# Out:
# 2019-05-01 03:27:32,258 [INFO]  Assuming 19 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, CNT_PAYMENT, DAYS_DECISION, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_TERMINATION, HOUR_APPR_PROCESS_START, NFLAG_INSURED_ON_APPROVAL, NFLAG_LAST_APPL_IN_DAY, RATE_DOWN_PAYMENT, RATE_INTEREST_PRIMARY, RATE_INTEREST_PRIVILEGED, SELLERPLACE_AREA
# 2019-05-01 03:27:32,260 [INFO]  Assuming 16 string input columns: NAME_PRODUCT_TYPE, CODE_REJECT_REASON, NAME_YIELD_GROUP, NAME_SELLER_INDUSTRY, NAME_PORTFOLIO, NAME_CONTRACT_TYPE, NAME_TYPE_SUITE, PRODUCT_COMBINATION, NAME_GOODS_CATEGORY, NAME_CASH_LOAN_PURPOSE, FLAG_LAST_APPL_PER_CONTRACT, CHANNEL_TYPE, NAME_CLIENT_TYPE, WEEKDAY_APPR_PROCESS_START, NAME_PAYMENT_TYPE, NAME_CONTRACT_STATUS
# 2019-05-01 03:27:32,262 [INFO]  Assuming 19 numeric input columns: AMT_ANNUITY, AMT_APPLICATION, AMT_CREDIT, AMT_DOWN_PAYMENT, AMT_GOODS_PRICE, CNT_PAYMENT, DAYS_DECISION, DAYS_FIRST_DRAWING, DAYS_FIRST_DUE, DAYS_LAST_DUE, DAYS_LAST_DUE_1ST_VERSION, DAYS_TERMINATION, HOUR_APPR_PROCESS_START, NFLAG_INSURED_ON_APPROVAL, NFLAG_LAST_APPL_IN_DAY, RATE_DOWN_PAYMENT, RATE_INTEREST_PRIMARY, RATE_INTEREST_PRIVILEGED, SELLERPLACE_AREA
# 2019-05-01 03:27:32,264 [INFO]  Assuming 16 string input columns: NAME_PRODUCT_TYPE, CODE_REJECT_REASON, NAME_YIELD_GROUP, NAME_SELLER_INDUSTRY, NAME_PORTFOLIO, NAME_CONTRACT_TYPE, NAME_TYPE_SUITE, PRODUCT_COMBINATION, NAME_GOODS_CATEGORY, NAME_CASH_LOAN_PURPOSE, FLAG_LAST_APPL_PER_CONTRACT, CHANNEL_TYPE, NAME_CLIENT_TYPE, WEEKDAY_APPR_PROCESS_START, NAME_PAYMENT_TYPE, NAME_CONTRACT_STATUS
# 2019-05-01 03:27:32,293 [INFO]  Training starts for 1hyperparameter configurations.
# 2019-05-01 03:27:32,295 [INFO]  Fitting hpo iteration 0 with parameters
# 	global:batch_size: 16
# 	global:learning_rate: 0.004
# 	global:weight_decay: 0
# 	global:num_epochs: 25
# 	global:patience: 3
# 	global:final_fc_hidden_units: []
# 	AMT_ANNUITY:type: numeric
# 	AMT_ANNUITY:normalize: True
# 	AMT_ANNUITY:numeric_latent_dim: 10
# 	AMT_ANNUITY:numeric_hidden_layers: 1
# 	AMT_APPLICATION:type: numeric
# 	AMT_APPLICATION:normalize: True
# 	AMT_APPLICATION:numeric_latent_dim: 10
# 	AMT_APPLICATION:numeric_hidden_layers: 1
# 	AMT_CREDIT:type: numeric
# 	AMT_CREDIT:normalize: True
# 	AMT_CREDIT:numeric_latent_dim: 10
# 	AMT_CREDIT:numeric_hidden_layers: 1
# 	AMT_DOWN_PAYMENT:type: numeric
# 	AMT_DOWN_PAYMENT:normalize: True
# 	AMT_DOWN_PAYMENT:numeric_latent_dim: 10
# 	AMT_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	AMT_GOODS_PRICE:type: numeric
# 	AMT_GOODS_PRICE:normalize: True
# 	AMT_GOODS_PRICE:numeric_latent_dim: 10
# 	AMT_GOODS_PRICE:numeric_hidden_layers: 1
# 	CHANNEL_TYPE:type: string
# 	CHANNEL_TYPE:ngram_range:words: (1, 3)
# 	CHANNEL_TYPE:ngram_range:chars: (1, 5)
# 	CHANNEL_TYPE:max_tokens: 32768
# 	CHANNEL_TYPE:tokens: ['chars']
# 	CNT_PAYMENT:type: numeric
# 	CNT_PAYMENT:normalize: True
# 	CNT_PAYMENT:numeric_latent_dim: 10
# 	CNT_PAYMENT:numeric_hidden_layers: 1
# 	CODE_REJECT_REASON:type: string
# 	CODE_REJECT_REASON:ngram_range:words: (1, 3)
# 	CODE_REJECT_REASON:ngram_range:chars: (1, 5)
# 	CODE_REJECT_REASON:max_tokens: 32768
# 	CODE_REJECT_REASON:tokens: ['chars']
# 	DAYS_DECISION:type: numeric
# 	DAYS_DECISION:normalize: True
# 	DAYS_DECISION:numeric_latent_dim: 10
# 	DAYS_DECISION:numeric_hidden_layers: 1
# 	DAYS_FIRST_DRAWING:type: numeric
# 	DAYS_FIRST_DRAWING:normalize: True
# 	DAYS_FIRST_DRAWING:numeric_latent_dim: 10
# 	DAYS_FIRST_DRAWING:numeric_hidden_layers: 1
# 	DAYS_FIRST_DUE:type: numeric
# 	DAYS_FIRST_DUE:normalize: True
# 	DAYS_FIRST_DUE:numeric_latent_dim: 10
# 	DAYS_FIRST_DUE:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE:type: numeric
# 	DAYS_LAST_DUE:normalize: True
# 	DAYS_LAST_DUE:numeric_latent_dim: 10
# 	DAYS_LAST_DUE:numeric_hidden_layers: 1
# 	DAYS_LAST_DUE_1ST_VERSION:type: numeric
# 	DAYS_LAST_DUE_1ST_VERSION:normalize: True
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_latent_dim: 10
# 	DAYS_LAST_DUE_1ST_VERSION:numeric_hidden_layers: 1
# 	DAYS_TERMINATION:type: numeric
# 	DAYS_TERMINATION:normalize: True
# 	DAYS_TERMINATION:numeric_latent_dim: 10
# 	DAYS_TERMINATION:numeric_hidden_layers: 1
# 	FLAG_LAST_APPL_PER_CONTRACT:type: string
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:words: (1, 3)
# 	FLAG_LAST_APPL_PER_CONTRACT:ngram_range:chars: (1, 5)
# 	FLAG_LAST_APPL_PER_CONTRACT:max_tokens: 32768
# 	FLAG_LAST_APPL_PER_CONTRACT:tokens: ['chars']
# 	HOUR_APPR_PROCESS_START:type: numeric
# 	HOUR_APPR_PROCESS_START:normalize: True
# 	HOUR_APPR_PROCESS_START:numeric_latent_dim: 10
# 	HOUR_APPR_PROCESS_START:numeric_hidden_layers: 1
# 	NAME_CASH_LOAN_PURPOSE:type: string
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:words: (1, 3)
# 	NAME_CASH_LOAN_PURPOSE:ngram_range:chars: (1, 5)
# 	NAME_CASH_LOAN_PURPOSE:max_tokens: 32768
# 	NAME_CASH_LOAN_PURPOSE:tokens: ['chars']
# 	NAME_CLIENT_TYPE:type: string
# 	NAME_CLIENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CLIENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CLIENT_TYPE:max_tokens: 32768
# 	NAME_CLIENT_TYPE:tokens: ['chars']
# 	NAME_CONTRACT_STATUS:type: string
# 	NAME_CONTRACT_STATUS:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_STATUS:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_STATUS:max_tokens: 32768
# 	NAME_CONTRACT_STATUS:tokens: ['chars']
# 	NAME_CONTRACT_TYPE:type: string
# 	NAME_CONTRACT_TYPE:ngram_range:words: (1, 3)
# 	NAME_CONTRACT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_CONTRACT_TYPE:max_tokens: 32768
# 	NAME_CONTRACT_TYPE:tokens: ['chars']
# 	NAME_GOODS_CATEGORY:type: string
# 	NAME_GOODS_CATEGORY:ngram_range:words: (1, 3)
# 	NAME_GOODS_CATEGORY:ngram_range:chars: (1, 5)
# 	NAME_GOODS_CATEGORY:max_tokens: 32768
# 	NAME_GOODS_CATEGORY:tokens: ['chars']
# 	NAME_PAYMENT_TYPE:type: string
# 	NAME_PAYMENT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PAYMENT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PAYMENT_TYPE:max_tokens: 32768
# 	NAME_PAYMENT_TYPE:tokens: ['chars']
# 	NAME_PORTFOLIO:type: string
# 	NAME_PORTFOLIO:ngram_range:words: (1, 3)
# 	NAME_PORTFOLIO:ngram_range:chars: (1, 5)
# 	NAME_PORTFOLIO:max_tokens: 32768
# 	NAME_PORTFOLIO:tokens: ['chars']
# 	NAME_PRODUCT_TYPE:type: string
# 	NAME_PRODUCT_TYPE:ngram_range:words: (1, 3)
# 	NAME_PRODUCT_TYPE:ngram_range:chars: (1, 5)
# 	NAME_PRODUCT_TYPE:max_tokens: 32768
# 	NAME_PRODUCT_TYPE:tokens: ['chars']
# 	NAME_SELLER_INDUSTRY:type: string
# 	NAME_SELLER_INDUSTRY:ngram_range:words: (1, 3)
# 	NAME_SELLER_INDUSTRY:ngram_range:chars: (1, 5)
# 	NAME_SELLER_INDUSTRY:max_tokens: 32768
# 	NAME_SELLER_INDUSTRY:tokens: ['chars']
# 	NAME_TYPE_SUITE:type: string
# 	NAME_TYPE_SUITE:ngram_range:words: (1, 3)
# 	NAME_TYPE_SUITE:ngram_range:chars: (1, 5)
# 	NAME_TYPE_SUITE:max_tokens: 32768
# 	NAME_TYPE_SUITE:tokens: ['chars']
# 	NAME_YIELD_GROUP:type: string
# 	NAME_YIELD_GROUP:ngram_range:words: (1, 3)
# 	NAME_YIELD_GROUP:ngram_range:chars: (1, 5)
# 	NAME_YIELD_GROUP:max_tokens: 32768
# 	NAME_YIELD_GROUP:tokens: ['chars']
# 	NFLAG_INSURED_ON_APPROVAL:type: numeric
# 	NFLAG_INSURED_ON_APPROVAL:normalize: True
# 	NFLAG_INSURED_ON_APPROVAL:numeric_latent_dim: 10
# 	NFLAG_INSURED_ON_APPROVAL:numeric_hidden_layers: 1
# 	NFLAG_LAST_APPL_IN_DAY:type: numeric
# 	NFLAG_LAST_APPL_IN_DAY:normalize: True
# 	NFLAG_LAST_APPL_IN_DAY:numeric_latent_dim: 10
# 	NFLAG_LAST_APPL_IN_DAY:numeric_hidden_layers: 1
# 	PRODUCT_COMBINATION:type: string
# 	PRODUCT_COMBINATION:ngram_range:words: (1, 3)
# 	PRODUCT_COMBINATION:ngram_range:chars: (1, 5)
# 	PRODUCT_COMBINATION:max_tokens: 32768
# 	PRODUCT_COMBINATION:tokens: ['chars']
# 	RATE_DOWN_PAYMENT:type: numeric
# 	RATE_DOWN_PAYMENT:normalize: True
# 	RATE_DOWN_PAYMENT:numeric_latent_dim: 10
# 	RATE_DOWN_PAYMENT:numeric_hidden_layers: 1
# 	RATE_INTEREST_PRIMARY:type: numeric
# 	RATE_INTEREST_PRIMARY:normalize: True
# 	RATE_INTEREST_PRIMARY:numeric_latent_dim: 10
# 	RATE_INTEREST_PRIMARY:numeric_hidden_layers: 1
# 	RATE_INTEREST_PRIVILEGED:type: numeric
# 	RATE_INTEREST_PRIVILEGED:normalize: True
# 	RATE_INTEREST_PRIVILEGED:numeric_latent_dim: 10
# 	RATE_INTEREST_PRIVILEGED:numeric_hidden_layers: 1
# 	SELLERPLACE_AREA:type: numeric
# 	SELLERPLACE_AREA:normalize: True
# 	SELLERPLACE_AREA:numeric_latent_dim: 10
# 	SELLERPLACE_AREA:numeric_hidden_layers: 1
# 	WEEKDAY_APPR_PROCESS_START:type: string
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:words: (1, 3)
# 	WEEKDAY_APPR_PROCESS_START:ngram_range:chars: (1, 5)
# 	WEEKDAY_APPR_PROCESS_START:max_tokens: 32768
# 	WEEKDAY_APPR_PROCESS_START:tokens: ['chars']
# 2019-05-01 03:27:32,311 [INFO]  No output column name provided for ColumnEncoder using PRODUCT_COMBINATION
# 2019-05-01 03:27:32,312 [INFO]  Assuming categorical output column: PRODUCT_COMBINATION
# 2019-05-01 03:27:32,318 [INFO]  Using [[cpu(0)]] as the context for training
# 2019-05-01 03:27:32,321 [INFO]  Fitting label encoder <class 'datawig.column_encoders.CategoricalEncoder'> on 6400 rows                             of training data
# 2019-05-01 03:27:32,329 [INFO]  17 most often encountered discrete values:                      ['Cash' 'POS household with interest' 'POS mobile with interest'
#  'Cash X-Sell: middle' 'Cash X-Sell: low' 'Card Street'
#  'POS industry with interest' 'Card X-Sell'
#  'POS household without interest' 'Cash X-Sell: high' 'Cash Street: high'
#  'Cash Street: low' 'Cash Street: middle' 'POS other with interest'
#  'POS mobile without interest' 'POS industry without interest'
#  'POS others without interest']
# 2019-05-01 03:27:32,331 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 97 occurrences of value POS other with interest
# 2019-05-01 03:27:32,332 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 90 occurrences of value POS mobile without interest
# 2019-05-01 03:27:32,334 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 54 occurrences of value POS industry without interest
# 2019-05-01 03:27:32,335 [WARNING]  CategoricalEncoder for column PRODUCT_COMBINATION                                found only 9 occurrences of value POS others without interest
# 2019-05-01 03:27:32,339 [INFO]  Detected 6 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 03:27:32,341 [INFO]  Dropping 6/6400 rows
# 2019-05-01 03:27:32,347 [INFO]  Detected 0 rows with missing labels                         for column PRODUCT_COMBINATION
# 2019-05-01 03:27:32,349 [INFO]  Dropping 0/1600 rows
# 2019-05-01 03:27:32,352 [INFO]  Train: 6394, Test: 1600
# 2019-05-01 03:27:32,353 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_ANNUITY and 6394 rows of training data with parameters {'input_columns': ['AMT_ANNUITY'], 'output_column': 'AMT_ANNUITY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,440 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_APPLICATION and 6394 rows of training data with parameters {'input_columns': ['AMT_APPLICATION'], 'output_column': 'AMT_APPLICATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,503 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_CREDIT and 6394 rows of training data with parameters {'input_columns': ['AMT_CREDIT'], 'output_column': 'AMT_CREDIT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,566 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_DOWN_PAYMENT and 6394 rows of training data with parameters {'input_columns': ['AMT_DOWN_PAYMENT'], 'output_column': 'AMT_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,627 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns AMT_GOODS_PRICE and 6394 rows of training data with parameters {'input_columns': ['AMT_GOODS_PRICE'], 'output_column': 'AMT_GOODS_PRICE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,688 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns CNT_PAYMENT and 6394 rows of training data with parameters {'input_columns': ['CNT_PAYMENT'], 'output_column': 'CNT_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,750 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_DECISION and 6394 rows of training data with parameters {'input_columns': ['DAYS_DECISION'], 'output_column': 'DAYS_DECISION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:32,814 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DRAWING and 6394 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DRAWING'], 'output_column': 'DAYS_FIRST_DRAWING_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,876 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_FIRST_DUE and 6394 rows of training data with parameters {'input_columns': ['DAYS_FIRST_DUE'], 'output_column': 'DAYS_FIRST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:32,941 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE and 6394 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE'], 'output_column': 'DAYS_LAST_DUE_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,005 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_LAST_DUE_1ST_VERSION and 6394 rows of training data with parameters {'input_columns': ['DAYS_LAST_DUE_1ST_VERSION'], 'output_column': 'DAYS_LAST_DUE_1ST_VERSION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,068 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns DAYS_TERMINATION and 6394 rows of training data with parameters {'input_columns': ['DAYS_TERMINATION'], 'output_column': 'DAYS_TERMINATION_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,131 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns HOUR_APPR_PROCESS_START and 6394 rows of training data with parameters {'input_columns': ['HOUR_APPR_PROCESS_START'], 'output_column': 'HOUR_APPR_PROCESS_START_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:33,192 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns NFLAG_INSURED_ON_APPROVAL and 6394 rows of training data with parameters {'input_columns': ['NFLAG_INSURED_ON_APPROVAL'], 'output_column': 'NFLAG_INSURED_ON_APPROVAL_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,265 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns NFLAG_LAST_APPL_IN_DAY and 6394 rows of training data with parameters {'input_columns': ['NFLAG_LAST_APPL_IN_DAY'], 'output_column': 'NFLAG_LAST_APPL_IN_DAY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:33,353 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_DOWN_PAYMENT and 6394 rows of training data with parameters {'input_columns': ['RATE_DOWN_PAYMENT'], 'output_column': 'RATE_DOWN_PAYMENT_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,425 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_INTEREST_PRIMARY and 6394 rows of training data with parameters {'input_columns': ['RATE_INTEREST_PRIMARY'], 'output_column': 'RATE_INTEREST_PRIMARY_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,498 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns RATE_INTEREST_PRIVILEGED and 6394 rows of training data with parameters {'input_columns': ['RATE_INTEREST_PRIVILEGED'], 'output_column': 'RATE_INTEREST_PRIVILEGED_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2019-05-01 03:27:33,581 [INFO]  Fitting data encoder <class 'datawig.column_encoders.NumericalEncoder'> on columns SELLERPLACE_AREA and 6394 rows of training data with parameters {'input_columns': ['SELLERPLACE_AREA'], 'output_column': 'SELLERPLACE_AREA_numeric', 'output_dim': 1, 'normalize': True, 'scaler': None}
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:33,658 [INFO]  Building Train Iterator with 6394 elements
# 2019-05-01 03:27:33,801 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 03:27:33,803 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:33,807 [INFO]  Data Encoding - Encoded 6400 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:33,811 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 03:27:33,813 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:33,817 [INFO]  Data Encoding - Encoded 6400 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:33,823 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 03:27:33,826 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:33,831 [INFO]  Data Encoding - Encoded 6400 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:33,837 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 03:27:33,842 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:33,848 [INFO]  Data Encoding - Encoded 6400 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:33,855 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 03:27:33,858 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:33,864 [INFO]  Data Encoding - Encoded 6400 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,193 [INFO]  Data Encoding - Encoded 6400 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:34,197 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 03:27:34,198 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,208 [INFO]  Data Encoding - Encoded 6400 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,285 [INFO]  Data Encoding - Encoded 6400 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:34,291 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 03:27:34,292 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,296 [INFO]  Data Encoding - Encoded 6400 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,300 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 03:27:34,301 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,306 [INFO]  Data Encoding - Encoded 6400 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,312 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 03:27:34,314 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,318 [INFO]  Data Encoding - Encoded 6400 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,327 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 03:27:34,329 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,334 [INFO]  Data Encoding - Encoded 6400 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,341 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 03:27:34,342 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,347 [INFO]  Data Encoding - Encoded 6400 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,353 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 03:27:34,355 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,361 [INFO]  Data Encoding - Encoded 6400 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,397 [INFO]  Data Encoding - Encoded 6400 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:34,403 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 03:27:34,405 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:34,409 [INFO]  Data Encoding - Encoded 6400 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:34,467 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:34,592 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:34,737 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:34,978 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,094 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,336 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,397 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,470 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,632 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,741 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,841 [INFO]  Data Encoding - Encoded 6400 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:35,845 [INFO]  Concatenating numeric columns ['NFLAG_INSURED_ON_APPROVAL'] into NFLAG_INSURED_ON_APPROVAL_numeric
# 2019-05-01 03:27:35,846 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:35,852 [INFO]  Data Encoding - Encoded 6400 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:35,859 [INFO]  Concatenating numeric columns ['NFLAG_LAST_APPL_IN_DAY'] into NFLAG_LAST_APPL_IN_DAY_numeric
# 2019-05-01 03:27:35,861 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:35,865 [INFO]  Data Encoding - Encoded 6400 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:36,197 [INFO]  Data Encoding - Encoded 6400 rows of column                         PRODUCT_COMBINATION with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:36,201 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 03:27:36,202 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,209 [INFO]  Data Encoding - Encoded 6400 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:36,214 [INFO]  Concatenating numeric columns ['RATE_INTEREST_PRIMARY'] into RATE_INTEREST_PRIMARY_numeric
# 2019-05-01 03:27:36,215 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,220 [INFO]  Data Encoding - Encoded 6400 rows of column                         RATE_INTEREST_PRIMARY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:36,228 [INFO]  Concatenating numeric columns ['RATE_INTEREST_PRIVILEGED'] into RATE_INTEREST_PRIVILEGED_numeric
# 2019-05-01 03:27:36,229 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,233 [INFO]  Data Encoding - Encoded 6400 rows of column                         RATE_INTEREST_PRIVILEGED with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:36,241 [INFO]  Concatenating numeric columns ['SELLERPLACE_AREA'] into SELLERPLACE_AREA_numeric
# 2019-05-01 03:27:36,243 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,248 [INFO]  Data Encoding - Encoded 6400 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (6400, 1)                         and then into shape (6400, 1)
# 2019-05-01 03:27:36,408 [INFO]  Data Encoding - Encoded 6400 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (6400, 32768)                         and then into shape (6400, 32768)
# 2019-05-01 03:27:36,410 [INFO]  CategoricalEncoder encoding 6400 rows with                     17 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 03:27:36,419 [INFO]  Label Encoding - Encoded 6400 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (6400, 1) and                             then into shape (6400, 1)
# 2019-05-01 03:27:36,422 [INFO]  Building Test Iterator with 1600 elements
# 2019-05-01 03:27:36,456 [INFO]  Concatenating numeric columns ['AMT_ANNUITY'] into AMT_ANNUITY_numeric
# 2019-05-01 03:27:36,458 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,463 [INFO]  Data Encoding - Encoded 1600 rows of column                         AMT_ANNUITY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,469 [INFO]  Concatenating numeric columns ['AMT_APPLICATION'] into AMT_APPLICATION_numeric
# 2019-05-01 03:27:36,470 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,475 [INFO]  Data Encoding - Encoded 1600 rows of column                         AMT_APPLICATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,481 [INFO]  Concatenating numeric columns ['AMT_CREDIT'] into AMT_CREDIT_numeric
# 2019-05-01 03:27:36,482 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,487 [INFO]  Data Encoding - Encoded 1600 rows of column                         AMT_CREDIT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,493 [INFO]  Concatenating numeric columns ['AMT_DOWN_PAYMENT'] into AMT_DOWN_PAYMENT_numeric
# 2019-05-01 03:27:36,494 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,497 [INFO]  Data Encoding - Encoded 1600 rows of column                         AMT_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,502 [INFO]  Concatenating numeric columns ['AMT_GOODS_PRICE'] into AMT_GOODS_PRICE_numeric
# 2019-05-01 03:27:36,504 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,509 [INFO]  Data Encoding - Encoded 1600 rows of column                         AMT_GOODS_PRICE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,593 [INFO]  Data Encoding - Encoded 1600 rows of column                         CHANNEL_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,597 [INFO]  Concatenating numeric columns ['CNT_PAYMENT'] into CNT_PAYMENT_numeric
# 2019-05-01 03:27:36,598 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,601 [INFO]  Data Encoding - Encoded 1600 rows of column                         CNT_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,628 [INFO]  Data Encoding - Encoded 1600 rows of column                         CODE_REJECT_REASON with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,633 [INFO]  Concatenating numeric columns ['DAYS_DECISION'] into DAYS_DECISION_numeric
# 2019-05-01 03:27:36,634 [INFO]  Normalizing with StandardScaler
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:36,641 [INFO]  Data Encoding - Encoded 1600 rows of column                         DAYS_DECISION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,645 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DRAWING'] into DAYS_FIRST_DRAWING_numeric
# 2019-05-01 03:27:36,646 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,650 [INFO]  Data Encoding - Encoded 1600 rows of column                         DAYS_FIRST_DRAWING with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,661 [INFO]  Concatenating numeric columns ['DAYS_FIRST_DUE'] into DAYS_FIRST_DUE_numeric
# 2019-05-01 03:27:36,662 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,665 [INFO]  Data Encoding - Encoded 1600 rows of column                         DAYS_FIRST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,676 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE'] into DAYS_LAST_DUE_numeric
# 2019-05-01 03:27:36,678 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,681 [INFO]  Data Encoding - Encoded 1600 rows of column                         DAYS_LAST_DUE with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,686 [INFO]  Concatenating numeric columns ['DAYS_LAST_DUE_1ST_VERSION'] into DAYS_LAST_DUE_1ST_VERSION_numeric
# 2019-05-01 03:27:36,689 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,696 [INFO]  Data Encoding - Encoded 1600 rows of column                         DAYS_LAST_DUE_1ST_VERSION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,701 [INFO]  Concatenating numeric columns ['DAYS_TERMINATION'] into DAYS_TERMINATION_numeric
# 2019-05-01 03:27:36,708 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:36,713 [INFO]  Data Encoding - Encoded 1600 rows of column                         DAYS_TERMINATION with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,728 [INFO]  Data Encoding - Encoded 1600 rows of column                         FLAG_LAST_APPL_PER_CONTRACT with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,732 [INFO]  Concatenating numeric columns ['HOUR_APPR_PROCESS_START'] into HOUR_APPR_PROCESS_START_numeric
# 2019-05-01 03:27:36,733 [INFO]  Normalizing with StandardScaler
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:36,739 [INFO]  Data Encoding - Encoded 1600 rows of column                         HOUR_APPR_PROCESS_START with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:36,761 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_CASH_LOAN_PURPOSE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,803 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_CLIENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,851 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_CONTRACT_STATUS with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,914 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_CONTRACT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:36,948 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_GOODS_CATEGORY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,016 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_PAYMENT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,033 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_PORTFOLIO with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,059 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_PRODUCT_TYPE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,102 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_SELLER_INDUSTRY with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,133 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_TYPE_SUITE with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,163 [INFO]  Data Encoding - Encoded 1600 rows of column                         NAME_YIELD_GROUP with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,167 [INFO]  Concatenating numeric columns ['NFLAG_INSURED_ON_APPROVAL'] into NFLAG_INSURED_ON_APPROVAL_numeric
# 2019-05-01 03:27:37,168 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:37,172 [INFO]  Data Encoding - Encoded 1600 rows of column                         NFLAG_INSURED_ON_APPROVAL with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:37,180 [INFO]  Concatenating numeric columns ['NFLAG_LAST_APPL_IN_DAY'] into NFLAG_LAST_APPL_IN_DAY_numeric
# 2019-05-01 03:27:37,182 [INFO]  Normalizing with StandardScaler
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:37,187 [INFO]  Data Encoding - Encoded 1600 rows of column                         NFLAG_LAST_APPL_IN_DAY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:37,281 [INFO]  Data Encoding - Encoded 1600 rows of column                         PRODUCT_COMBINATION with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,285 [INFO]  Concatenating numeric columns ['RATE_DOWN_PAYMENT'] into RATE_DOWN_PAYMENT_numeric
# 2019-05-01 03:27:37,286 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:37,290 [INFO]  Data Encoding - Encoded 1600 rows of column                         RATE_DOWN_PAYMENT with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:37,294 [INFO]  Concatenating numeric columns ['RATE_INTEREST_PRIMARY'] into RATE_INTEREST_PRIMARY_numeric
# 2019-05-01 03:27:37,296 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:37,302 [INFO]  Data Encoding - Encoded 1600 rows of column                         RATE_INTEREST_PRIMARY with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:37,306 [INFO]  Concatenating numeric columns ['RATE_INTEREST_PRIVILEGED'] into RATE_INTEREST_PRIVILEGED_numeric
# 2019-05-01 03:27:37,308 [INFO]  Normalizing with StandardScaler
# 2019-05-01 03:27:37,317 [INFO]  Data Encoding - Encoded 1600 rows of column                         RATE_INTEREST_PRIVILEGED with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:37,322 [INFO]  Concatenating numeric columns ['SELLERPLACE_AREA'] into SELLERPLACE_AREA_numeric
# 2019-05-01 03:27:37,323 [INFO]  Normalizing with StandardScaler
# /Users/stewarta/repos/data-prep-visualization/data-prep-env/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2019-05-01 03:27:37,330 [INFO]  Data Encoding - Encoded 1600 rows of column                         SELLERPLACE_AREA with <class 'datawig.column_encoders.NumericalEncoder'> into                         <class 'numpy.ndarray'> of shape (1600, 1)                         and then into shape (1600, 1)
# 2019-05-01 03:27:37,374 [INFO]  Data Encoding - Encoded 1600 rows of column                         WEEKDAY_APPR_PROCESS_START with <class 'datawig.column_encoders.BowEncoder'> into                         <class 'scipy.sparse.csr.csr_matrix'> of shape (1600, 32768)                         and then into shape (1600, 32768)
# 2019-05-01 03:27:37,376 [INFO]  CategoricalEncoder encoding 1600 rows with                     17 tokens from column PRODUCT_COMBINATION to                     column PRODUCT_COMBINATION
# 2019-05-01 03:27:37,387 [INFO]  Label Encoding - Encoded 1600 rows of column                             PRODUCT_COMBINATION with <class 'datawig.column_encoders.CategoricalEncoder'> into                             <class 'numpy.ndarray'> of shape (1600, 1) and                             then into shape (1600, 1)
# 2019-05-01 03:27:37,392 [WARNING]  Test set does not contain any ocurrences of values [] in column [PRODUCT_COMBINATION], consider using a more representative test set.
# 2019-05-01 03:27:37,394 [INFO]  Concatenating all 35 latent symbols
# 2019-05-01 03:27:37,396 [INFO]  Constructing categorical loss for column PRODUCT_COMBINATION and 17 labels
# 2019-05-01 03:27:37,398 [INFO]  Building output of label <Symbol PRODUCT_COMBINATION> with 18 classes                      (including missing class)
# 2019-05-01 03:27:37,401 [INFO]  Building output symbols
# 2019-05-01 03:27:37,424 [INFO]
# ========== start: fit model
# 2019-05-01 03:27:37,428 [WARNING]  Already bound, ignoring bind()
# 2019-05-01 03:28:16,680 [INFO]  Epoch[0] Batch [0-200]	Speed: 82.92 samples/sec	cross-entropy=0.377846	PRODUCT_COMBINATION-accuracy=0.909826
# 2019-05-01 03:28:54,981 [INFO]  Epoch[0] Train-cross-entropy=0.236746
# 2019-05-01 03:28:54,983 [INFO]  Epoch[0] Train-PRODUCT_COMBINATION-accuracy=0.943438
# 2019-05-01 03:28:54,984 [INFO]  Epoch[0] Time cost=77.526
# 2019-05-01 03:28:55,288 [INFO]  Saved checkpoint to "imputer_model0/model-0000.params"
# 2019-05-01 03:29:07,309 [INFO]  Epoch[0] Validation-cross-entropy=0.073368
# 2019-05-01 03:29:07,310 [INFO]  Epoch[0] Validation-PRODUCT_COMBINATION-accuracy=0.978750
# 2019-05-01 03:29:46,265 [INFO]  Epoch[1] Batch [0-200]	Speed: 82.57 samples/sec	cross-entropy=0.041883	PRODUCT_COMBINATION-accuracy=0.993470
# 2019-05-01 03:30:24,618 [INFO]  Epoch[1] Train-cross-entropy=0.038251
# 2019-05-01 03:30:24,619 [INFO]  Epoch[1] Train-PRODUCT_COMBINATION-accuracy=0.992812
# 2019-05-01 03:30:24,621 [INFO]  Epoch[1] Time cost=77.309
# 2019-05-01 03:30:24,858 [INFO]  Saved checkpoint to "imputer_model0/model-0001.params"
# 2019-05-01 03:30:36,825 [INFO]  Epoch[1] Validation-cross-entropy=0.037676
# 2019-05-01 03:30:36,826 [INFO]  Epoch[1] Validation-PRODUCT_COMBINATION-accuracy=0.988125
# 2019-05-01 03:31:16,407 [INFO]  Epoch[2] Batch [0-200]	Speed: 81.27 samples/sec	cross-entropy=0.017845	PRODUCT_COMBINATION-accuracy=0.997512
# 2019-05-01 03:31:57,166 [INFO]  Epoch[2] Train-cross-entropy=0.017444
# 2019-05-01 03:31:57,167 [INFO]  Epoch[2] Train-PRODUCT_COMBINATION-accuracy=0.997812
# 2019-05-01 03:31:57,168 [INFO]  Epoch[2] Time cost=80.341
# 2019-05-01 03:31:57,431 [INFO]  Saved checkpoint to "imputer_model0/model-0002.params"
# 2019-05-01 03:32:09,706 [INFO]  Epoch[2] Validation-cross-entropy=0.023238
# 2019-05-01 03:32:09,707 [INFO]  Epoch[2] Validation-PRODUCT_COMBINATION-accuracy=0.992500

# %% [markdown]
# ## Missing Numerical

# %% [markdown]
# #### Strategy: Impute Probalistic
#
# * Datawig: https://github.com/awslabs/datawig/blob/master/README.md#imputation-of-numerical-columns

# %%
# fill in some nulls
 ## hmm does not include missing data in th 
#seed = 200
#nullval = df.sample(frac=0.2,random_state=seed)
#test = df.loc[nullval.index,['PRODUCT_COMBINATION']]
nullval.index  
df.loc[nullval.index,['PRODUCT_COMBINATION']] = np.nan
df.loc[nullval.index,['PRODUCT_COMBINATION']].head()


# test set: counts for each value 
test.PRODUCT_COMBINATION.value_counts()
